# %% [markdown]
# <a href="https://colab.research.google.com/github/tumblingdice512/Research/blob/master/hyoumen_kyoudo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
for l in range(6):
  for m in range(6):
    F = (np.abs(1 + np.exp(np.pi* 1j*(l/3 + m)) + np.exp(np.pi* 1j*(l + 5*m/3))+ np.exp(np.pi* 1j*(4*l/3 + 2*m/3))))**2
    print(l,m,F)
# Out:
# 0 0 16.0
# 0 1 1.60237371373018e-31
# 0 2 3.999999999999999
# 0 3 5.3991352175826865e-31
# 0 4 4.0
# 0 5 2.7733391199176196e-30
# 1 0 3.0814879110195774e-31
# 1 1 0.9999999999999976
# 1 2 9.000000000000009
# 1 3 3.9999999999999973
# 1 4 9.00000000000001
# 1 5 1.0000000000000009
# 2 0 4.000000000000002
# 2 1 8.999999999999993
# 2 2 1.0000000000000044
# 2 3 6.335539145056251e-30
# 2 4 1.000000000000003
# 2 5 9.000000000000016
# 3 0 0.0
# 3 1 3.9999999999999956
# 3 2 1.3105568085566263e-29
# 3 3 16.0
# 3 4 5.149782596895918e-29
# 3 5 4.000000000000011
# 4 0 3.999999999999993
# 4 1 9.00000000000001
# 4 2 0.9999999999999942
# 4 3 1.97215226305253e-30
# 4 4 0.9999999999999909
# 4 5 9.00000000000002
# 5 0 4.190823558986625e-31
# 5 1 0.9999999999999976
# 5 2 8.999999999999998
# 5 3 3.9999999999999813
# 5 4 9.000000000000005
# 5 5 1.0000000000000004

# %%
for l in range(4):
  for m in range(4):
    F = (np.abs(1 + np.exp(np.pi* 1j*(l/2 + m)) + np.exp(np.pi* 1j*(l + 3*m/2))+ np.exp(np.pi* 1j*(3*l/2 + 1*m/2))))**2
    print(l,m,F)
# Out:
# 0 0 16.0
# 0 1 2.732354947069688e-32
# 0 2 5.999039130647428e-32
# 0 3 3.321936067448201e-31
# 1 0 8.304840168620503e-32
# 1 1 4.0
# 1 2 8.000000000000002
# 1 3 3.9999999999999982
# 2 0 5.999039130647428e-32
# 2 1 7.9999999999999964
# 2 2 2.399615652258972e-31
# 2 3 7.9999999999999964
# 3 0 2.1920513414160383e-31
# 3 1 4.000000000000002
# 3 2 7.999999999999991
# 3 3 3.999999999999991

# %%
for l in range(6):
  for m in range(6):
    F = (np.abs(1 + np.exp(np.pi* 1j*(2*l/3 + 2*m/3))))**2
    print(l,m,F)
# Out:
# 0 0 4.0
# 0 1 1.0000000000000004
# 0 2 0.9999999999999991
# 0 3 4.0
# 0 4 1.0000000000000013
# 0 5 1.0000000000000004
# 1 0 1.0000000000000004
# 1 1 0.9999999999999991
# 1 2 4.0
# 1 3 1.0000000000000013
# 1 4 0.9999999999999971
# 1 5 4.0
# 2 0 0.9999999999999991
# 2 1 4.0
# 2 2 1.0000000000000013
# 2 3 0.9999999999999971
# 2 4 4.0
# 2 5 0.9999999999999989
# 3 0 4.0
# 3 1 1.0000000000000013
# 3 2 0.9999999999999971
# 3 3 4.0
# 3 4 1.0000000000000049
# 3 5 1.000000000000003
# 4 0 1.0000000000000013
# 4 1 0.9999999999999971
# 4 2 4.0
# 4 3 1.0000000000000049
# 4 4 0.9999999999999967
# 4 5 4.0
# 5 0 1.0000000000000004
# 5 1 4.0
# 5 2 0.9999999999999989
# 5 3 1.000000000000003
# 5 4 4.0
# 5 5 0.9999999999999993

# %%
for l in range(4):
  for m in range(4):
    F = (np.abs(1 + np.exp(np.pi* 1j*(l/2 + m))))**2
    print(l,m,F)
# Out:
# 0 0 4.0
# 0 1 1.4997597826618576e-32
# 0 2 4.0
# 0 3 1.3497838043956716e-31
# 1 0 2.0000000000000004
# 1 1 1.9999999999999996
# 1 2 2.0000000000000004
# 1 3 1.9999999999999991
# 2 0 1.4997597826618576e-32
# 2 1 4.0
# 2 2 1.3497838043956716e-31
# 2 3 4.0
# 3 0 1.9999999999999996
# 3 1 2.0000000000000004
# 3 2 1.9999999999999991
# 3 3 2.000000000000001
