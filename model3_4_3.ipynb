# %% [markdown]
# <a href="https://colab.research.google.com/github/tumblingdice512/Research/blob/master/model3_4_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# モデル3 シンプルなnumpyによる実装(tanhの使用)

# %% [markdown]
# モデルについて
#
# 幅N、深さL+1(l=0,1,･･･,L)のネットワーク
#
# 各パーセプトロンはM成分を持つスピンで各成分は+1か-1を取る
#
# 第l層と第l+1層の各パーセプトロンの同一成分は全て結合→重みJ
#
# 各層の重みJはΣJ^2 = Nと正規化されている
#
# 第l層のスピンの値に重みをかけた値に対して符号関数をかませたものが第l+1層の値(0に対して+1か-1にする)
#
# ただし学習の際には、tanhを使っている
# 第l+1層の学習用の出力 = tanh(第l層の出力)
# 第l+1層のスピンの値 = sign(第l層の出力)
#
# 初期条件としては、入力層と出力層のスピンの値を与える
#
# 入力層のスピンの値と、初期の重みの条件から、出力層を予想して、損失関数(平均2乗誤差)を小さくするために重みを更新する

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
np.random.seed(100)

# %%
N = 10
L = 5

# %%
#S0 = np.array([random.choice([1,-1]) for i in range(N)])
#SL = np.array([random.choice([1,-1]) for i in range(N)])

#print(S0)
#print("S0の要素数は",len(S0))

#print(SL)
#print("SLの要素数は",len(SL))

#初期条件として与えるスピンを生成
#各パーセプトロンのスピンの成分数を増やすときは、SOとSLを行列の形式にすればよい。

# %%
S0 = np.sign(np.random.randn(30,N))

SL = np.sign(np.random.randn(30,N))


M = len(S0)
print(M)
print(N)
print(S0.shape)
print(S0[0].shape)
# Out:
# 10
# 10
# (10, 10)
# (10,)

# %%
alpha = M / N
print(alpha)
# Out:
# 1.0

# %%
D = np.array([[1,2,3],[2,3,4]])
print(D.shape)
print(len(D)) #M
print(len(D[0])) #N
# Out:
# (2, 3)
# 2
# 3

# %%
def spin_overlap(x,y):
  spin_overlap = 0
  for i in range (len(x[0])) :

    spin_overlap = spin_overlap + np.dot(x.T[i],y.T[i])
  return np.abs(spin_overlap/(len(x)*len(x[0])))

print(spin_overlap(S0,S0))
# Out:
# 1.0

# %%
def bond_overlap(x,y):
  bond_overlap = 0
  for i in range (len(x[0])) :

    bond_overlap = bond_overlap + np.dot(x.T[i],y.T[i])
  return np.abs(bond_overlap/(len(x[0])*len(x[0])))

# %%
S_a = np.array([[1,-1],[1,1],[1,-1]])
S_b = np.array([[1,-1],[1,1],[1,1]])
print(spin_overlap(S_a,S_b))
print(spin_overlap(S_a,S_a))
# Out:
# 0.6666666666666666
# 1.0

# %%
a1 = np.dot(S_a.T[0],S_b.T[0])
a2 = np.dot(S_a.T[1],S_b.T[1])
a3 = (a1 + a2)/(2*3)
print(a3)
# Out:
# 0.6666666666666666

# %%
def MSE(t, y):
    mse = np.mean(np.sum(np.square(t-y),axis =1),axis = 0)
    return mse

# %%
A = np.array([[3,5,1],[4,12,1]])
print(A**2)
A_norm = (np.sum(np.square(A),axis=0))**(1/2)

A_normalized = A / A_norm
A_normalized_2 = A / A_norm * (N**(1/2))

print(A_norm)

print(A_normalized)
print(A_normalized_2)
# Out:
# [[  9  25   1]
#  [ 16 144   1]]
# [ 5.         13.          1.41421356]
# [[0.6        0.38461538 0.70710678]
#  [0.8        0.92307692 0.70710678]]
# [[1.8973666  1.21626064 2.23606798]
#  [2.52982213 2.91902553 2.23606798]]

# %%
def weight_norm(x):
    x_norm = (np.sum(np.square(x),axis=0)**(1/2))
    return x_norm

# %%
w_a = np.array([[0,0,1],[1,0,0],[0,1,0]]) 
w_b = np.array([[1,0,0],[0,1,0],[0,0,1]]) 
J_a = w_a / (weight_norm(w_a)) * (3**(1/2))
J_b = w_b / (weight_norm(w_b)) * (3**(1/2))


print(J_a)
print(J_b)
print(len(J_a[0]))

print(bond_overlap(J_a,J_b))
print(bond_overlap(J_a,J_a))
# Out:
# [[0.         0.         1.73205081]
#  [1.73205081 0.         0.        ]
#  [0.         1.73205081 0.        ]]
# [[1.73205081 0.         0.        ]
#  [0.         1.73205081 0.        ]
#  [0.         0.         1.73205081]]
# 3
# 0.0
# 0.9999999999999998

# %%
class Network1():
  #ネットワークを定義する
  #構成[入力層, 第1層, 第2層, 第3層, 第4層, 第5層]
  #全結合

  def __init__(self):
    #重みの定義
    self.w1_1 = np.random.randn(N,N)
    self.w2_1 = np.random.randn(N,N)
    self.w3_1 = np.random.randn(N,N)
    self.w4_1 = np.random.randn(N,N)
    self.w5_1 = np.random.randn(N,N)

    #重みの正規化
    self.J1_1 = self.w1_1 / (weight_norm(self.w1_1)) * (N**(1/2))
    self.J2_1 = self.w2_1 / (weight_norm(self.w2_1)) * (N**(1/2))
    self.J3_1 = self.w3_1 / (weight_norm(self.w3_1)) * (N**(1/2))
    self.J4_1 = self.w4_1 / (weight_norm(self.w4_1)) * (N**(1/2))
    self.J5_1 = self.w5_1 / (weight_norm(self.w5_1)) * (N**(1/2))

  def forward(self, x):

    self.layer0_1 = x
    self.layer1_1 = np.tanh(np.dot(self.layer0_1, self.J1_1))
    self.layer2_1 = np.tanh(np.dot(self.layer1_1, self.J2_1))
    self.layer3_1 = np.tanh(np.dot(self.layer2_1, self.J3_1))
    self.layer4_1 = np.tanh(np.dot(self.layer3_1, self.J4_1))
    self.out_1 = np.tanh(np.dot(self.layer4_1, self.J5_1))

    S1_1 = np.sign(self.layer1_1)
    S2_1 = np.sign(self.layer2_1)
    S3_1 = np.sign(self.layer3_1)
    S4_1 = np.sign(self.layer4_1)
    

    return self.out_1, S1_1, S2_1, S3_1, S4_1
    

  def backward(self, t, y):
    #誤差逆伝播
    delta5_1 = -2*(t-y)
    delta4_1 = np.dot(delta5_1 * (1 - self.out_1**2),self.J5_1.T)
    delta3_1 = np.dot(delta4_1 * (1 - self.layer4_1**2),self.J4_1.T) 
    delta2_1 = np.dot(delta3_1 * (1 - self.layer3_1**2),self.J3_1.T)
    delta1_1 = np.dot(delta2_1 * (1 - self.layer2_1**2),self.J2_1.T)

    #重みの勾配
    self.dedJ5_1 = np.dot(self.layer4_1.T, delta5_1 * (1 - self.out_1**2)) / delta5_1.shape[0]
    self.dedJ4_1 = np.dot(self.layer3_1.T, delta4_1 * (1 - self.layer4_1**2)) / delta4_1.shape[0]
    self.dedJ3_1 = np.dot(self.layer2_1.T, delta3_1 * (1 - self.layer3_1**2)) / delta3_1.shape[0]
    self.dedJ2_1 = np.dot(self.layer1_1.T, delta2_1 * (1 - self.layer2_1**2)) / delta2_1.shape[0]
    self.dedJ1_1 = np.dot(self.layer0_1.T, delta1_1 * (1 - self.layer1_1**2)) / delta1_1.shape[0]

  def optimize_GradientDecent(self, lr):
    #重みの更新    
    self.J1_1 -= lr * self.dedJ1_1
    self.J2_1 -= lr * self.dedJ2_1
    self.J3_1 -= lr * self.dedJ3_1
    self.J4_1 -= lr * self.dedJ4_1
    self.J5_1 -= lr * self.dedJ5_1

    #重みの正規化
    self.J1_1 = self.J1_1 / (weight_norm(self.J1_1)) * (N**(1/2))
    self.J2_1 = self.J2_1 / (weight_norm(self.J2_1)) * (N**(1/2))
    self.J3_1 = self.J3_1 / (weight_norm(self.J3_1)) * (N**(1/2))
    self.J4_1 = self.J4_1 / (weight_norm(self.J4_1)) * (N**(1/2))
    self.J5_1 = self.J5_1 / (weight_norm(self.J5_1)) * (N**(1/2))

    return self.J1_1, self.J2_1, self.J3_1, self.J4_1, self.J5_1

# %%
class Network2():
  #ネットワークを定義する
  #構成[入力層, 第1層, 第2層, 第3層, 第4層, 第5層]
  #全結合

  def __init__(self):
    #重みの定義
    self.w1_2 = np.random.randn(N,N)
    self.w2_2 = np.random.randn(N,N)
    self.w3_2 = np.random.randn(N,N)
    self.w4_2 = np.random.randn(N,N)
    self.w5_2 = np.random.randn(N,N)

    #重みの正規化
    self.J1_2 = self.w1_2 / (weight_norm(self.w1_2)) * (N**(1/2))
    self.J2_2 = self.w2_2 / (weight_norm(self.w2_2)) * (N**(1/2))
    self.J3_2 = self.w3_2 / (weight_norm(self.w3_2)) * (N**(1/2))
    self.J4_2 = self.w4_2 / (weight_norm(self.w4_2)) * (N**(1/2))
    self.J5_2 = self.w5_2 / (weight_norm(self.w5_2)) * (N**(1/2))

  def forward(self, x):

    self.layer0_2 = x
    self.layer1_2 = np.tanh(np.dot(self.layer0_2, self.J1_2))
    self.layer2_2 = np.tanh(np.dot(self.layer1_2, self.J2_2))
    self.layer3_2 = np.tanh(np.dot(self.layer2_2, self.J3_2))
    self.layer4_2 = np.tanh(np.dot(self.layer3_2, self.J4_2))
    self.out_2 = np.tanh(np.dot(self.layer4_2, self.J5_2))

    S1_2 = np.sign(self.layer1_2)
    S2_2 = np.sign(self.layer2_2)
    S3_2 = np.sign(self.layer3_2)
    S4_2 = np.sign(self.layer4_2)

    return self.out_2, S1_2, S2_2, S3_2, S4_2
    

  def backward(self, t, y):
    #誤差逆伝播
    delta5_2 = -2*(t-y)
    delta4_2 = np.dot(delta5_2 * (1 - self.out_2**2),self.J5_2.T)
    delta3_2 = np.dot(delta4_2 * (1 - self.layer4_2**2),self.J4_2.T) 
    delta2_2 = np.dot(delta3_2 * (1 - self.layer3_2**2),self.J3_2.T)
    delta1_2 = np.dot(delta2_2 * (1 - self.layer2_2**2),self.J2_2.T)

    #重みの勾配
    self.dedJ5_2 = np.dot(self.layer4_2.T, delta5_2 * (1 - self.out_2**2)) / delta5_2.shape[0]
    self.dedJ4_2 = np.dot(self.layer3_2.T, delta4_2 * (1 - self.layer4_2**2)) / delta4_2.shape[0]
    self.dedJ3_2 = np.dot(self.layer2_2.T, delta3_2 * (1 - self.layer3_2**2)) / delta3_2.shape[0]
    self.dedJ2_2 = np.dot(self.layer1_2.T, delta2_2 * (1 - self.layer2_2**2)) / delta2_2.shape[0]
    self.dedJ1_2 = np.dot(self.layer0_2.T, delta1_2 * (1 - self.layer1_2**2)) / delta1_2.shape[0]

  def optimize_GradientDecent(self, lr):
    #重みの更新    
    self.J1_2 -= lr * self.dedJ1_2
    self.J2_2 -= lr * self.dedJ2_2
    self.J3_2 -= lr * self.dedJ3_2
    self.J4_2 -= lr * self.dedJ4_2
    self.J5_2 -= lr * self.dedJ5_2

    #重みの正規化
    self.J1_2 = self.J1_2 / (weight_norm(self.J1_2)) * (N**(1/2))
    self.J2_2 = self.J2_2 / (weight_norm(self.J2_2)) * (N**(1/2))
    self.J3_2 = self.J3_2 / (weight_norm(self.J3_2)) * (N**(1/2))
    self.J4_2 = self.J4_2 / (weight_norm(self.J4_2)) * (N**(1/2))
    self.J5_2 = self.J5_2 / (weight_norm(self.J5_2)) * (N**(1/2))

    return self.J1_2, self.J2_2, self.J3_2, self.J4_2, self.J5_2

# %%
class Network3():
  #ネットワークを定義する
  #構成[入力層, 第1層, 第2層, 第3層, 第4層, 第5層]
  #全結合

  def __init__(self):
    #重みの定義
    self.w1_3 = np.random.randn(N,N)
    self.w2_3 = np.random.randn(N,N)
    self.w3_3 = np.random.randn(N,N)
    self.w4_3 = np.random.randn(N,N)
    self.w5_3 = np.random.randn(N,N)

    #重みの正規化
    self.J1_3 = self.w1_3 / (weight_norm(self.w1_3)) * (N**(1/2))
    self.J2_3 = self.w2_3 / (weight_norm(self.w2_3)) * (N**(1/2))
    self.J3_3 = self.w3_3 / (weight_norm(self.w3_3)) * (N**(1/2))
    self.J4_3 = self.w4_3 / (weight_norm(self.w4_3)) * (N**(1/2))
    self.J5_3 = self.w5_3 / (weight_norm(self.w5_3)) * (N**(1/2))

  def forward(self, x):

    self.layer0_3 = x
    self.layer1_3 = np.tanh(np.dot(self.layer0_3, self.J1_3))
    self.layer2_3 = np.tanh(np.dot(self.layer1_3, self.J2_3))
    self.layer3_3 = np.tanh(np.dot(self.layer2_3, self.J3_3))
    self.layer4_3 = np.tanh(np.dot(self.layer3_3, self.J4_3))
    self.out_3 = np.tanh(np.dot(self.layer4_3, self.J5_3))

    S1_3 = np.sign(self.layer1_3)
    S2_3 = np.sign(self.layer2_3)
    S3_3 = np.sign(self.layer3_3)
    S4_3 = np.sign(self.layer4_3)

    return self.out_3, S1_3, S2_3, S3_3, S4_3
    

  def backward(self, t, y):
    #誤差逆伝播
    delta5_3 = -2*(t-y)
    delta4_3 = np.dot(delta5_3 * (1 - self.out_3**2),self.J5_3.T)
    delta3_3 = np.dot(delta4_3 * (1 - self.layer4_3**2),self.J4_3.T) 
    delta2_3 = np.dot(delta3_3 * (1 - self.layer3_3**2),self.J3_3.T)
    delta1_3 = np.dot(delta2_3 * (1 - self.layer2_3**2),self.J2_3.T)

    #重みの勾配
    self.dedJ5_3 = np.dot(self.layer4_3.T, delta5_3 * (1 - self.out_3**2)) / delta5_3.shape[0]
    self.dedJ4_3 = np.dot(self.layer3_3.T, delta4_3 * (1 - self.layer4_3**2)) / delta4_3.shape[0]
    self.dedJ3_3 = np.dot(self.layer2_3.T, delta3_3 * (1 - self.layer3_3**2)) / delta3_3.shape[0]
    self.dedJ2_3 = np.dot(self.layer1_3.T, delta2_3 * (1 - self.layer2_3**2)) / delta2_3.shape[0]
    self.dedJ1_3 = np.dot(self.layer0_3.T, delta1_3 * (1 - self.layer1_3**2)) / delta1_3.shape[0]

  def optimize_GradientDecent(self, lr):
    #重みの更新    
    self.J1_3 -= lr * self.dedJ1_3
    self.J2_3 -= lr * self.dedJ2_3
    self.J3_3 -= lr * self.dedJ3_3
    self.J4_3 -= lr * self.dedJ4_3
    self.J5_3 -= lr * self.dedJ5_3

    #重みの正規化
    self.J1_3 = self.J1_3 / (weight_norm(self.J1_3)) * (N**(1/2))
    self.J2_3 = self.J2_3 / (weight_norm(self.J2_3)) * (N**(1/2))
    self.J3_3 = self.J3_3 / (weight_norm(self.J3_3)) * (N**(1/2))
    self.J4_3 = self.J4_3 / (weight_norm(self.J4_3)) * (N**(1/2))
    self.J5_3 = self.J5_3 / (weight_norm(self.J5_3)) * (N**(1/2))

    return self.J1_3, self.J2_3, self.J3_3, self.J4_3, self.J5_3

# %%
class Network4():
  #ネットワークを定義する
  #構成[入力層, 第1層, 第2層, 第3層, 第4層, 第5層]
  #全結合

  def __init__(self):
    #重みの定義
    self.w1_4 = np.random.randn(N,N)
    self.w2_4 = np.random.randn(N,N)
    self.w3_4 = np.random.randn(N,N)
    self.w4_4 = np.random.randn(N,N)
    self.w5_4 = np.random.randn(N,N)

    #重みの正規化
    self.J1_4 = self.w1_4 / (weight_norm(self.w1_4)) * (N**(1/2))
    self.J2_4 = self.w2_4 / (weight_norm(self.w2_4)) * (N**(1/2))
    self.J3_4 = self.w3_4 / (weight_norm(self.w3_4)) * (N**(1/2))
    self.J4_4 = self.w4_4 / (weight_norm(self.w4_4)) * (N**(1/2))
    self.J5_4 = self.w5_4 / (weight_norm(self.w5_4)) * (N**(1/2))

  def forward(self, x):

    self.layer0_4 = x
    self.layer1_4 = np.tanh(np.dot(self.layer0_4, self.J1_4))
    self.layer2_4 = np.tanh(np.dot(self.layer1_4, self.J2_4))
    self.layer3_4 = np.tanh(np.dot(self.layer2_4, self.J3_4))
    self.layer4_4 = np.tanh(np.dot(self.layer3_4, self.J4_4))
    self.out_4 = np.tanh(np.dot(self.layer4_4, self.J5_4))

    S1_4 = np.sign(self.layer1_4)
    S2_4 = np.sign(self.layer2_4)
    S3_4 = np.sign(self.layer3_4)
    S4_4 = np.sign(self.layer4_4)

    return self.out_4, S1_4, S2_4, S3_4, S4_4
    

  def backward(self, t, y):
    #誤差逆伝播
    delta5_4 = -2*(t-y)
    delta4_4 = np.dot(delta5_4 * (1 - self.out_4**2),self.J5_4.T)
    delta3_4 = np.dot(delta4_4 * (1 - self.layer4_4**2),self.J4_4.T) 
    delta2_4 = np.dot(delta3_4 * (1 - self.layer3_4**2),self.J3_4.T)
    delta1_4 = np.dot(delta2_4 * (1 - self.layer2_4**2),self.J2_4.T)

    #重みの勾配
    self.dedJ5_4 = np.dot(self.layer4_4.T, delta5_4 * (1 - self.out_4**2)) / delta5_4.shape[0]
    self.dedJ4_4 = np.dot(self.layer3_4.T, delta4_4 * (1 - self.layer4_4**2)) / delta4_4.shape[0]
    self.dedJ3_4 = np.dot(self.layer2_4.T, delta3_4 * (1 - self.layer3_4**2)) / delta3_4.shape[0]
    self.dedJ2_4 = np.dot(self.layer1_4.T, delta2_4 * (1 - self.layer2_4**2)) / delta2_4.shape[0]
    self.dedJ1_4 = np.dot(self.layer0_4.T, delta1_4 * (1 - self.layer1_4**2)) / delta1_4.shape[0]

  def optimize_GradientDecent(self, lr):
    #重みの更新    
    self.J1_4 -= lr * self.dedJ1_4
    self.J2_4 -= lr * self.dedJ2_4
    self.J3_4 -= lr * self.dedJ3_4
    self.J4_4 -= lr * self.dedJ4_4
    self.J5_4 -= lr * self.dedJ5_4

    #重みの正規化
    self.J1_4 = self.J1_4 / (weight_norm(self.J1_4)) * (N**(1/2))
    self.J2_4 = self.J2_4 / (weight_norm(self.J2_4)) * (N**(1/2))
    self.J3_4 = self.J3_4 / (weight_norm(self.J3_4)) * (N**(1/2))
    self.J4_4 = self.J4_4 / (weight_norm(self.J4_4)) * (N**(1/2))
    self.J5_4 = self.J5_4 / (weight_norm(self.J5_4)) * (N**(1/2))

    return self.J1_4, self.J2_4, self.J3_4, self.J4_4, self.J5_4

# %%
class Network5():
  #ネットワークを定義する
  #構成[入力層, 第1層, 第2層, 第3層, 第4層, 第5層]
  #全結合

  def __init__(self):
    #重みの定義
    self.w1_5 = np.random.randn(N,N)
    self.w2_5 = np.random.randn(N,N)
    self.w3_5 = np.random.randn(N,N)
    self.w4_5 = np.random.randn(N,N)
    self.w5_5 = np.random.randn(N,N)

    #重みの正規化
    self.J1_5 = self.w1_5 / (weight_norm(self.w1_5)) * (N**(1/2))
    self.J2_5 = self.w2_5 / (weight_norm(self.w2_5)) * (N**(1/2))
    self.J3_5 = self.w3_5 / (weight_norm(self.w3_5)) * (N**(1/2))
    self.J4_5 = self.w4_5 / (weight_norm(self.w4_5)) * (N**(1/2))
    self.J5_5 = self.w5_5 / (weight_norm(self.w5_5)) * (N**(1/2))

  def forward(self, x):

    self.layer0_5 = x
    self.layer1_5 = np.tanh(np.dot(self.layer0_5, self.J1_5))
    self.layer2_5 = np.tanh(np.dot(self.layer1_5, self.J2_5))
    self.layer3_5 = np.tanh(np.dot(self.layer2_5, self.J3_5))
    self.layer4_5 = np.tanh(np.dot(self.layer3_5, self.J4_5))
    self.out_5 = np.tanh(np.dot(self.layer4_5, self.J5_5))

    S1_5 = np.sign(self.layer1_5)
    S2_5 = np.sign(self.layer2_5)
    S3_5 = np.sign(self.layer3_5)
    S4_5 = np.sign(self.layer4_5)

    return self.out_5, S1_5, S2_5, S3_5, S4_5
    

  def backward(self, t, y):
    #誤差逆伝播
    delta5_5 = -2*(t-y)
    delta4_5 = np.dot(delta5_5 * (1 - self.out_5**2),self.J5_5.T)
    delta3_5 = np.dot(delta4_5 * (1 - self.layer4_5**2),self.J4_5.T) 
    delta2_5 = np.dot(delta3_5 * (1 - self.layer3_5**2),self.J3_5.T)
    delta1_5 = np.dot(delta2_5 * (1 - self.layer2_5**2),self.J2_5.T)

    #重みの勾配
    self.dedJ5_5 = np.dot(self.layer4_5.T, delta5_5 * (1 - self.out_5**2)) / delta5_5.shape[0]
    self.dedJ4_5 = np.dot(self.layer3_5.T, delta4_5 * (1 - self.layer4_5**2)) / delta4_5.shape[0]
    self.dedJ3_5 = np.dot(self.layer2_5.T, delta3_5 * (1 - self.layer3_5**2)) / delta3_5.shape[0]
    self.dedJ2_5 = np.dot(self.layer1_5.T, delta2_5 * (1 - self.layer2_5**2)) / delta2_5.shape[0]
    self.dedJ1_5 = np.dot(self.layer0_5.T, delta1_5 * (1 - self.layer1_5**2)) / delta1_5.shape[0]

  def optimize_GradientDecent(self, lr):
    #重みの更新    
    self.J1_5 -= lr * self.dedJ1_5
    self.J2_5 -= lr * self.dedJ2_5
    self.J3_5 -= lr * self.dedJ3_5
    self.J4_5 -= lr * self.dedJ4_5
    self.J5_5 -= lr * self.dedJ5_5

    #重みの正規化
    self.J1_5 = self.J1_5 / (weight_norm(self.J1_5)) * (N**(1/2))
    self.J2_5 = self.J2_5 / (weight_norm(self.J2_5)) * (N**(1/2))
    self.J3_5 = self.J3_5 / (weight_norm(self.J3_5)) * (N**(1/2))
    self.J4_5 = self.J4_5 / (weight_norm(self.J4_5)) * (N**(1/2))
    self.J5_5 = self.J5_5 / (weight_norm(self.J5_5)) * (N**(1/2))

    return self.J1_5, self.J2_5, self.J3_5, self.J4_5, self.J5_5

# %%
class Network6():
  #ネットワークを定義する
  #構成[入力層, 第1層, 第2層, 第3層, 第4層, 第5層]
  #全結合

  def __init__(self):
    #重みの定義
    self.w1_6 = np.random.randn(N,N)
    self.w2_6 = np.random.randn(N,N)
    self.w3_6 = np.random.randn(N,N)
    self.w4_6 = np.random.randn(N,N)
    self.w5_6 = np.random.randn(N,N)

    #重みの正規化
    self.J1_6 = self.w1_6 / (weight_norm(self.w1_6)) * (N**(1/2))
    self.J2_6 = self.w2_6 / (weight_norm(self.w2_6)) * (N**(1/2))
    self.J3_6 = self.w3_6 / (weight_norm(self.w3_6)) * (N**(1/2))
    self.J4_6 = self.w4_6 / (weight_norm(self.w4_6)) * (N**(1/2))
    self.J5_6 = self.w5_6 / (weight_norm(self.w5_6)) * (N**(1/2))

  def forward(self, x):

    self.layer0_6 = x
    self.layer1_6 = np.tanh(np.dot(self.layer0_6, self.J1_6))
    self.layer2_6 = np.tanh(np.dot(self.layer1_6, self.J2_6))
    self.layer3_6 = np.tanh(np.dot(self.layer2_6, self.J3_6))
    self.layer4_6 = np.tanh(np.dot(self.layer3_6, self.J4_6))
    self.out_6 = np.tanh(np.dot(self.layer4_6, self.J5_6))

    S1_6 = np.sign(self.layer1_6)
    S2_6 = np.sign(self.layer2_6)
    S3_6 = np.sign(self.layer3_6)
    S4_6 = np.sign(self.layer4_6)

    return self.out_6, S1_6, S2_6, S3_6, S4_6
    

  def backward(self, t, y):
    #誤差逆伝播
    delta5_6 = -2*(t-y)
    delta4_6 = np.dot(delta5_6 * (1 - self.out_6**2),self.J5_6.T)
    delta3_6 = np.dot(delta4_6 * (1 - self.layer4_6**2),self.J4_6.T) 
    delta2_6 = np.dot(delta3_6 * (1 - self.layer3_6**2),self.J3_6.T)
    delta1_6 = np.dot(delta2_6 * (1 - self.layer2_6**2),self.J2_6.T)

    #重みの勾配
    self.dedJ5_6 = np.dot(self.layer4_6.T, delta5_6 * (1 - self.out_6**2)) / delta5_6.shape[0]
    self.dedJ4_6 = np.dot(self.layer3_6.T, delta4_6 * (1 - self.layer4_6**2)) / delta4_6.shape[0]
    self.dedJ3_6 = np.dot(self.layer2_6.T, delta3_6 * (1 - self.layer3_6**2)) / delta3_6.shape[0]
    self.dedJ2_6 = np.dot(self.layer1_6.T, delta2_6 * (1 - self.layer2_6**2)) / delta2_6.shape[0]
    self.dedJ1_6 = np.dot(self.layer0_6.T, delta1_6 * (1 - self.layer1_6**2)) / delta1_6.shape[0]

  def optimize_GradientDecent(self, lr):
    #重みの更新    
    self.J1_6 -= lr * self.dedJ1_6
    self.J2_6 -= lr * self.dedJ2_6
    self.J3_6 -= lr * self.dedJ3_6
    self.J4_6 -= lr * self.dedJ4_6
    self.J5_6 -= lr * self.dedJ5_6

    #重みの正規化
    self.J1_6 = self.J1_6 / (weight_norm(self.J1_6)) * (N**(1/2))
    self.J2_6 = self.J2_6 / (weight_norm(self.J2_6)) * (N**(1/2))
    self.J3_6 = self.J3_6 / (weight_norm(self.J3_6)) * (N**(1/2))
    self.J4_6 = self.J4_6 / (weight_norm(self.J4_6)) * (N**(1/2))
    self.J5_6 = self.J5_6 / (weight_norm(self.J5_6)) * (N**(1/2))

    return self.J1_6, self.J2_6, self.J3_6, self.J4_6, self.J5_6

# %%
model_1 = Network1()
model_2 = Network2()
model_3 = Network3()
model_4 = Network4()
model_5 = Network5()
model_6 = Network6()


# 学習率
lr = 0.06
# 学習エポック数
n_epoch = 1000000
Loss_1 = []
Loss_2 = []
Loss_3 = []
Loss_4 = []
Loss_5 = []
Loss_6 = []


  # n_epoch繰り返す
  
for n in range(n_epoch):
    y_1 = model_1.forward(S0)
    y_2 = model_2.forward(S0)
    y_3 = model_3.forward(S0)
    y_4 = model_4.forward(S0)
    y_5 = model_5.forward(S0)
    y_6 = model_6.forward(S0)

    loss_Network_1 = MSE(SL, y_1[0])
    loss_Network_2 = MSE(SL, y_2[0])
    loss_Network_3 = MSE(SL, y_3[0])
    loss_Network_4 = MSE(SL, y_4[0])
    loss_Network_5 = MSE(SL, y_5[0])
    loss_Network_6 = MSE(SL, y_6[0])

    model_1.backward(SL, y_1[0])
    model_2.backward(SL, y_2[0])
    model_3.backward(SL, y_3[0])
    model_4.backward(SL, y_4[0])
    model_5.backward(SL, y_5[0])
    model_6.backward(SL, y_6[0])

    w_1 = model_1.optimize_GradientDecent(lr)
    w_2 = model_2.optimize_GradientDecent(lr)
    w_3 = model_3.optimize_GradientDecent(lr)
    w_4 = model_4.optimize_GradientDecent(lr)
    w_5 = model_5.optimize_GradientDecent(lr)
    w_6 = model_6.optimize_GradientDecent(lr)




    Loss_1.append(loss_Network_1)
    Loss_2.append(loss_Network_2)
    Loss_3.append(loss_Network_3)
    Loss_4.append(loss_Network_4)
    Loss_5.append(loss_Network_5)
    Loss_6.append(loss_Network_6)

    print('EPOCH ', n + 1, ' | TRAIN LOSS_1 ',loss_Network_1, '  TRAIN LOSS_2 ',loss_Network_2,
                            '  TRAIN LOSS_3 ',loss_Network_3, '  TRAIN LOSS_4 ',loss_Network_4,
                            '  TRAIN LOSS_5 ',loss_Network_5, '  TRAIN LOSS_6 ',loss_Network_6)
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# EPOCH  559561  | TRAIN LOSS_1  0.0053794756685824705   TRAIN LOSS_2  0.006617856807293944   TRAIN LOSS_3  0.00706382415906518   TRAIN LOSS_4  0.007129444240324969   TRAIN LOSS_5  0.005393364557160432   TRAIN LOSS_6  0.007697215531692675
# EPOCH  559562  | TRAIN LOSS_1  0.005379467525074333   TRAIN LOSS_2  0.0066178508951793774   TRAIN LOSS_3  0.007063819539985443   TRAIN LOSS_4  0.0071294397017243345   TRAIN LOSS_5  0.005393360687946404   TRAIN LOSS_6  0.007697188820163349
# EPOCH  559563  | TRAIN LOSS_1  0.005379459381580323   TRAIN LOSS_2  0.006617844983114685   TRAIN LOSS_3  0.007063814920919858   TRAIN LOSS_4  0.007129435163132991   TRAIN LOSS_5  0.005393356818747542   TRAIN LOSS_6  0.0076971621086374545
# EPOCH  559564  | TRAIN LOSS_1  0.0053794512381004555   TRAIN LOSS_2  0.006617839071099872   TRAIN LOSS_3  0.007063810301868426   TRAIN LOSS_4  0.007129430624550933   TRAIN LOSS_5  0.005393352949563853   TRAIN LOSS_6  0.007697135397115056
# EPOCH  559565  | TRAIN LOSS_1  0.005379443094634717   TRAIN LOSS_2  0.0066178331591349275   TRAIN LOSS_3  0.007063805682831144   TRAIN LOSS_4  0.007129426085978175   TRAIN LOSS_5  0.005393349080395333   TRAIN LOSS_6  0.007697108685596211
# EPOCH  559566  | TRAIN LOSS_1  0.005379434951183103   TRAIN LOSS_2  0.006617827247219856   TRAIN LOSS_3  0.007063801063808003   TRAIN LOSS_4  0.007129421547414711   TRAIN LOSS_5  0.005393345211241978   TRAIN LOSS_6  0.0076970819740809805
# EPOCH  559567  | TRAIN LOSS_1  0.0053794268077456036   TRAIN LOSS_2  0.006617821335354644   TRAIN LOSS_3  0.007063796444798999   TRAIN LOSS_4  0.0071294170088605415   TRAIN LOSS_5  0.00539334134210379   TRAIN LOSS_6  0.007697055262569418
# EPOCH  559568  | TRAIN LOSS_1  0.005379418664322215   TRAIN LOSS_2  0.006617815423539297   TRAIN LOSS_3  0.007063791825804132   TRAIN LOSS_4  0.007129412470315667   TRAIN LOSS_5  0.005393337472980769   TRAIN LOSS_6  0.007697028551061591
# EPOCH  559569  | TRAIN LOSS_1  0.0053794105209129355   TRAIN LOSS_2  0.0066178095117738   TRAIN LOSS_3  0.007063787206823385   TRAIN LOSS_4  0.00712940793178009   TRAIN LOSS_5  0.005393333603872911   TRAIN LOSS_6  0.007697001839557546
# EPOCH  559570  | TRAIN LOSS_1  0.005379402377517751   TRAIN LOSS_2  0.006617803600058162   TRAIN LOSS_3  0.00706378258785676   TRAIN LOSS_4  0.007129403393253802   TRAIN LOSS_5  0.005393329734780217   TRAIN LOSS_6  0.007696975128057354
# EPOCH  559571  | TRAIN LOSS_1  0.005379394234136662   TRAIN LOSS_2  0.006617797688392369   TRAIN LOSS_3  0.00706377796890426   TRAIN LOSS_4  0.007129398854736817   TRAIN LOSS_5  0.005393325865702684   TRAIN LOSS_6  0.007696948416561073
# EPOCH  559572  | TRAIN LOSS_1  0.005379386090769664   TRAIN LOSS_2  0.006617791776776419   TRAIN LOSS_3  0.007063773349965862   TRAIN LOSS_4  0.0071293943162291295   TRAIN LOSS_5  0.005393321996640313   TRAIN LOSS_6  0.007696921705068753
# EPOCH  559573  | TRAIN LOSS_1  0.0053793779474167434   TRAIN LOSS_2  0.006617785865210309   TRAIN LOSS_3  0.007063768731041575   TRAIN LOSS_4  0.007129389777730742   TRAIN LOSS_5  0.005393318127593101   TRAIN LOSS_6  0.0076968949935804646
# EPOCH  559574  | TRAIN LOSS_1  0.0053793698040778964   TRAIN LOSS_2  0.006617779953694031   TRAIN LOSS_3  0.007063764112131383   TRAIN LOSS_4  0.007129385239241647   TRAIN LOSS_5  0.005393314258561048   TRAIN LOSS_6  0.007696868282096255
# EPOCH  559575  | TRAIN LOSS_1  0.005379361660753122   TRAIN LOSS_2  0.006617774042227589   TRAIN LOSS_3  0.007063759493235285   TRAIN LOSS_4  0.007129380700761856   TRAIN LOSS_5  0.005393310389544157   TRAIN LOSS_6  0.007696841570616202
# EPOCH  559576  | TRAIN LOSS_1  0.0053793535174424135   TRAIN LOSS_2  0.006617768130810974   TRAIN LOSS_3  0.007063754874353275   TRAIN LOSS_4  0.007129376162291356   TRAIN LOSS_5  0.005393306520542415   TRAIN LOSS_6  0.007696814859140344
# EPOCH  559577  | TRAIN LOSS_1  0.005379345374145759   TRAIN LOSS_2  0.006617762219444183   TRAIN LOSS_3  0.007063750255485358   TRAIN LOSS_4  0.007129371623830167   TRAIN LOSS_5  0.005393302651555835   TRAIN LOSS_6  0.0076967881476687535
# EPOCH  559578  | TRAIN LOSS_1  0.005379337230863159   TRAIN LOSS_2  0.006617756308127208   TRAIN LOSS_3  0.007063745636631514   TRAIN LOSS_4  0.007129367085378279   TRAIN LOSS_5  0.0053932987825844065   TRAIN LOSS_6  0.007696761436201485
# EPOCH  559579  | TRAIN LOSS_1  0.005379329087594602   TRAIN LOSS_2  0.006617750396860049   TRAIN LOSS_3  0.007063741017791743   TRAIN LOSS_4  0.007129362546935685   TRAIN LOSS_5  0.005393294913628132   TRAIN LOSS_6  0.0076967347247386035
# EPOCH  559580  | TRAIN LOSS_1  0.005379320944340087   TRAIN LOSS_2  0.006617744485642703   TRAIN LOSS_3  0.007063736398966042   TRAIN LOSS_4  0.007129358008502395   TRAIN LOSS_5  0.005393291044687012   TRAIN LOSS_6  0.007696708013280161
# EPOCH  559581  | TRAIN LOSS_1  0.005379312801099604   TRAIN LOSS_2  0.006617738574475164   TRAIN LOSS_3  0.007063731780154403   TRAIN LOSS_4  0.007129353470078411   TRAIN LOSS_5  0.005393287175761043   TRAIN LOSS_6  0.007696681301826218
# EPOCH  559582  | TRAIN LOSS_1  0.0053793046578731515   TRAIN LOSS_2  0.006617732663357425   TRAIN LOSS_3  0.007063727161356824   TRAIN LOSS_4  0.007129348931663728   TRAIN LOSS_5  0.005393283306850225   TRAIN LOSS_6  0.007696654590376836
# EPOCH  559583  | TRAIN LOSS_1  0.005379296514660722   TRAIN LOSS_2  0.006617726752289488   TRAIN LOSS_3  0.007063722542573294   TRAIN LOSS_4  0.0071293443932583505   TRAIN LOSS_5  0.005393279437954552   TRAIN LOSS_6  0.007696627878932074
# EPOCH  559584  | TRAIN LOSS_1  0.0053792883714623   TRAIN LOSS_2  0.0066177208412713405   TRAIN LOSS_3  0.007063717923803812   TRAIN LOSS_4  0.007129339854862276   TRAIN LOSS_5  0.005393275569074036   TRAIN LOSS_6  0.007696601167491988
# EPOCH  559585  | TRAIN LOSS_1  0.005379280228277898   TRAIN LOSS_2  0.006617714930302987   TRAIN LOSS_3  0.007063713305048375   TRAIN LOSS_4  0.007129335316475505   TRAIN LOSS_5  0.005393271700208659   TRAIN LOSS_6  0.007696574456056648
# EPOCH  559586  | TRAIN LOSS_1  0.005379272085107498   TRAIN LOSS_2  0.006617709019384415   TRAIN LOSS_3  0.007063708686306967   TRAIN LOSS_4  0.007129330778098037   TRAIN LOSS_5  0.005393267831358433   TRAIN LOSS_6  0.007696547744626095
# EPOCH  559587  | TRAIN LOSS_1  0.005379263941951096   TRAIN LOSS_2  0.006617703108515631   TRAIN LOSS_3  0.0070637040675795935   TRAIN LOSS_4  0.0071293262397298844   TRAIN LOSS_5  0.005393263962523351   TRAIN LOSS_6  0.007696521033200405
# EPOCH  559588  | TRAIN LOSS_1  0.005379255798808682   TRAIN LOSS_2  0.006617697197696624   TRAIN LOSS_3  0.007063699448866246   TRAIN LOSS_4  0.007129321701371027   TRAIN LOSS_5  0.005393260093703414   TRAIN LOSS_6  0.007696494321779635
# EPOCH  559589  | TRAIN LOSS_1  0.005379247655680255   TRAIN LOSS_2  0.006617691286927393   TRAIN LOSS_3  0.00706369483016692   TRAIN LOSS_4  0.0071293171630214865   TRAIN LOSS_5  0.005393256224898619   TRAIN LOSS_6  0.007696467610363839
# EPOCH  559590  | TRAIN LOSS_1  0.005379239512565809   TRAIN LOSS_2  0.00661768537620793   TRAIN LOSS_3  0.007063690211481607   TRAIN LOSS_4  0.007129312624681251   TRAIN LOSS_5  0.005393252356108969   TRAIN LOSS_6  0.007696440898953077
# EPOCH  559591  | TRAIN LOSS_1  0.005379231369465341   TRAIN LOSS_2  0.00661767946553823   TRAIN LOSS_3  0.0070636855928103036   TRAIN LOSS_4  0.007129308086350326   TRAIN LOSS_5  0.005393248487334458   TRAIN LOSS_6  0.0076964141875474155
# EPOCH  559592  | TRAIN LOSS_1  0.005379223226378843   TRAIN LOSS_2  0.0066176735549182955   TRAIN LOSS_3  0.007063680974153007   TRAIN LOSS_4  0.00712930354802871   TRAIN LOSS_5  0.005393244618575086   TRAIN LOSS_6  0.0076963874761469065
# EPOCH  559593  | TRAIN LOSS_1  0.005379215083306299   TRAIN LOSS_2  0.0066176676443481155   TRAIN LOSS_3  0.00706367635550971   TRAIN LOSS_4  0.007129299009716394   TRAIN LOSS_5  0.005393240749830854   TRAIN LOSS_6  0.007696360764751604
# EPOCH  559594  | TRAIN LOSS_1  0.005379206940247718   TRAIN LOSS_2  0.0066176617338276926   TRAIN LOSS_3  0.007063671736880403   TRAIN LOSS_4  0.007129294471413401   TRAIN LOSS_5  0.005393236881101758   TRAIN LOSS_6  0.007696334053361586
# EPOCH  559595  | TRAIN LOSS_1  0.005379198797203084   TRAIN LOSS_2  0.006617655823357016   TRAIN LOSS_3  0.007063667118265082   TRAIN LOSS_4  0.007129289933119713   TRAIN LOSS_5  0.005393233012387801   TRAIN LOSS_6  0.007696307341976899
# EPOCH  559596  | TRAIN LOSS_1  0.005379190654172398   TRAIN LOSS_2  0.006617649912936085   TRAIN LOSS_3  0.00706366249966375   TRAIN LOSS_4  0.007129285394835335   TRAIN LOSS_5  0.005393229143688985   TRAIN LOSS_6  0.007696280630597603
# EPOCH  559597  | TRAIN LOSS_1  0.005379182511155651   TRAIN LOSS_2  0.006617644002564897   TRAIN LOSS_3  0.0070636578810763925   TRAIN LOSS_4  0.007129280856560268   TRAIN LOSS_5  0.005393225275005297   TRAIN LOSS_6  0.007696253919223758
# EPOCH  559598  | TRAIN LOSS_1  0.005379174368152833   TRAIN LOSS_2  0.006617638092243445   TRAIN LOSS_3  0.0070636532625030085   TRAIN LOSS_4  0.0071292763182945135   TRAIN LOSS_5  0.0053932214063367465   TRAIN LOSS_6  0.00769622720785543
# EPOCH  559599  | TRAIN LOSS_1  0.005379166225163946   TRAIN LOSS_2  0.006617632181971728   TRAIN LOSS_3  0.007063648643943593   TRAIN LOSS_4  0.007129271780038077   TRAIN LOSS_5  0.005393217537683329   TRAIN LOSS_6  0.007696200496492672
# EPOCH  559600  | TRAIN LOSS_1  0.0053791580821889754   TRAIN LOSS_2  0.0066176262717497405   TRAIN LOSS_3  0.007063644025398133   TRAIN LOSS_4  0.0071292672417909535   TRAIN LOSS_5  0.005393213669045039   TRAIN LOSS_6  0.007696173785135542
# EPOCH  559601  | TRAIN LOSS_1  0.005379149939227923   TRAIN LOSS_2  0.006617620361577475   TRAIN LOSS_3  0.007063639406866636   TRAIN LOSS_4  0.007129262703553143   TRAIN LOSS_5  0.005393209800421881   TRAIN LOSS_6  0.007696147073784108
# EPOCH  559602  | TRAIN LOSS_1  0.005379141796280778   TRAIN LOSS_2  0.006617614451454933   TRAIN LOSS_3  0.007063634788349091   TRAIN LOSS_4  0.007129258165324644   TRAIN LOSS_5  0.005393205931813856   TRAIN LOSS_6  0.007696120362438424
# EPOCH  559603  | TRAIN LOSS_1  0.005379133653347536   TRAIN LOSS_2  0.006617608541382108   TRAIN LOSS_3  0.007063630169845487   TRAIN LOSS_4  0.007129253627105466   TRAIN LOSS_5  0.005393202063220954   TRAIN LOSS_6  0.007696093651098548
# EPOCH  559604  | TRAIN LOSS_1  0.005379125510428194   TRAIN LOSS_2  0.00661760263135899   TRAIN LOSS_3  0.007063625551355824   TRAIN LOSS_4  0.007129249088895598   TRAIN LOSS_5  0.0053931981946431845   TRAIN LOSS_6  0.007696066939764545
# EPOCH  559605  | TRAIN LOSS_1  0.005379117367522739   TRAIN LOSS_2  0.006617596721385584   TRAIN LOSS_3  0.0070636209328800974   TRAIN LOSS_4  0.007129244550695044   TRAIN LOSS_5  0.005393194326080539   TRAIN LOSS_6  0.007696040228436468
# EPOCH  559606  | TRAIN LOSS_1  0.005379109224631174   TRAIN LOSS_2  0.006617590811461882   TRAIN LOSS_3  0.007063616314418304   TRAIN LOSS_4  0.007129240012503816   TRAIN LOSS_5  0.005393190457533022   TRAIN LOSS_6  0.007696013517114383
# EPOCH  559607  | TRAIN LOSS_1  0.005379101081753482   TRAIN LOSS_2  0.006617584901587883   TRAIN LOSS_3  0.007063611695970427   TRAIN LOSS_4  0.007129235474321903   TRAIN LOSS_5  0.005393186589000624   TRAIN LOSS_6  0.00769598680579835
# EPOCH  559608  | TRAIN LOSS_1  0.005379092938889668   TRAIN LOSS_2  0.006617578991763574   TRAIN LOSS_3  0.007063607077536474   TRAIN LOSS_4  0.007129230936149307   TRAIN LOSS_5  0.005393182720483355   TRAIN LOSS_6  0.007695960094488422
# EPOCH  559609  | TRAIN LOSS_1  0.005379084796039719   TRAIN LOSS_2  0.0066175730819889615   TRAIN LOSS_3  0.007063602459116433   TRAIN LOSS_4  0.007129226397986033   TRAIN LOSS_5  0.005393178851981208   TRAIN LOSS_6  0.0076959333831846674
# EPOCH  559610  | TRAIN LOSS_1  0.005379076653203632   TRAIN LOSS_2  0.0066175671722640385   TRAIN LOSS_3  0.007063597840710303   TRAIN LOSS_4  0.007129221859832076   TRAIN LOSS_5  0.005393174983494177   TRAIN LOSS_6  0.007695906671887136
# EPOCH  559611  | TRAIN LOSS_1  0.005379068510381404   TRAIN LOSS_2  0.006617561262588794   TRAIN LOSS_3  0.007063593222318076   TRAIN LOSS_4  0.007129217321687439   TRAIN LOSS_5  0.0053931711150222725   TRAIN LOSS_6  0.0076958799605958954
# EPOCH  559612  | TRAIN LOSS_1  0.0053790603675730195   TRAIN LOSS_2  0.006617555352963233   TRAIN LOSS_3  0.0070635886039397446   TRAIN LOSS_4  0.00712921278355212   TRAIN LOSS_5  0.005393167246565481   TRAIN LOSS_6  0.007695853249311005
# EPOCH  559613  | TRAIN LOSS_1  0.00537905222477848   TRAIN LOSS_2  0.006617549443387344   TRAIN LOSS_3  0.0070635839855753045   TRAIN LOSS_4  0.007129208245426123   TRAIN LOSS_5  0.00539316337812381   TRAIN LOSS_6  0.007695826538032518
# EPOCH  559614  | TRAIN LOSS_1  0.005379044081997784   TRAIN LOSS_2  0.006617543533861131   TRAIN LOSS_3  0.007063579367224757   TRAIN LOSS_4  0.007129203707309449   TRAIN LOSS_5  0.005393159509697257   TRAIN LOSS_6  0.007695799826760504
# EPOCH  559615  | TRAIN LOSS_1  0.005379035939230913   TRAIN LOSS_2  0.006617537624384583   TRAIN LOSS_3  0.007063574748888087   TRAIN LOSS_4  0.007129199169202099   TRAIN LOSS_5  0.005393155641285817   TRAIN LOSS_6  0.007695773115495015
# EPOCH  559616  | TRAIN LOSS_1  0.005379027796477867   TRAIN LOSS_2  0.006617531714957701   TRAIN LOSS_3  0.007063570130565295   TRAIN LOSS_4  0.007129194631104069   TRAIN LOSS_5  0.005393151772889501   TRAIN LOSS_6  0.007695746404236114
# EPOCH  559617  | TRAIN LOSS_1  0.005379019653738648   TRAIN LOSS_2  0.006617525805580474   TRAIN LOSS_3  0.007063565512256372   TRAIN LOSS_4  0.007129190093015367   TRAIN LOSS_5  0.005393147904508291   TRAIN LOSS_6  0.007695719692983861
# EPOCH  559618  | TRAIN LOSS_1  0.00537901151101324   TRAIN LOSS_2  0.0066175198962529075   TRAIN LOSS_3  0.007063560893961319   TRAIN LOSS_4  0.007129185554935983   TRAIN LOSS_5  0.0053931440361421985   TRAIN LOSS_6  0.00769569298173831
# EPOCH  559619  | TRAIN LOSS_1  0.005379003368301638   TRAIN LOSS_2  0.006617513986974987   TRAIN LOSS_3  0.007063556275680122   TRAIN LOSS_4  0.007129181016865928   TRAIN LOSS_5  0.005393140167791213   TRAIN LOSS_6  0.007695666270499532
# EPOCH  559620  | TRAIN LOSS_1  0.005378995225603837   TRAIN LOSS_2  0.006617508077746715   TRAIN LOSS_3  0.007063551657412783   TRAIN LOSS_4  0.0071291764788052   TRAIN LOSS_5  0.0053931362994553405   TRAIN LOSS_6  0.007695639559267581
# EPOCH  559621  | TRAIN LOSS_1  0.005378987082919835   TRAIN LOSS_2  0.006617502168568087   TRAIN LOSS_3  0.007063547039159294   TRAIN LOSS_4  0.007129171940753795   TRAIN LOSS_5  0.005393132431134579   TRAIN LOSS_6  0.0076956128480425165
# EPOCH  559622  | TRAIN LOSS_1  0.0053789789402496225   TRAIN LOSS_2  0.006617496259439096   TRAIN LOSS_3  0.0070635424209196445   TRAIN LOSS_4  0.007129167402711714   TRAIN LOSS_5  0.005393128562828927   TRAIN LOSS_6  0.0076955861368244
# EPOCH  559623  | TRAIN LOSS_1  0.005378970797593194   TRAIN LOSS_2  0.006617490350359739   TRAIN LOSS_3  0.007063537802693842   TRAIN LOSS_4  0.007129162864678964   TRAIN LOSS_5  0.00539312469453838   TRAIN LOSS_6  0.007695559425613286
# EPOCH  559624  | TRAIN LOSS_1  0.00537896265495054   TRAIN LOSS_2  0.006617484441330016   TRAIN LOSS_3  0.00706353318448187   TRAIN LOSS_4  0.00712915832665554   TRAIN LOSS_5  0.005393120826262938   TRAIN LOSS_6  0.0076955327144092416
# EPOCH  559625  | TRAIN LOSS_1  0.005378954512321662   TRAIN LOSS_2  0.006617478532349918   TRAIN LOSS_3  0.007063528566283726   TRAIN LOSS_4  0.007129153788641444   TRAIN LOSS_5  0.005393116958002608   TRAIN LOSS_6  0.007695506003212326
# EPOCH  559626  | TRAIN LOSS_1  0.005378946369706551   TRAIN LOSS_2  0.006617472623419443   TRAIN LOSS_3  0.007063523948099406   TRAIN LOSS_4  0.007129149250636678   TRAIN LOSS_5  0.005393113089757383   TRAIN LOSS_6  0.007695479292022603
# EPOCH  559627  | TRAIN LOSS_1  0.0053789382271052   TRAIN LOSS_2  0.006617466714538584   TRAIN LOSS_3  0.007063519329928904   TRAIN LOSS_4  0.0071291447126412355   TRAIN LOSS_5  0.005393109221527252   TRAIN LOSS_6  0.0076954525808401175
# EPOCH  559628  | TRAIN LOSS_1  0.005378930084517601   TRAIN LOSS_2  0.006617460805707338   TRAIN LOSS_3  0.007063514711772212   TRAIN LOSS_4  0.007129140174655129   TRAIN LOSS_5  0.005393105353312233   TRAIN LOSS_6  0.007695425869664944
# EPOCH  559629  | TRAIN LOSS_1  0.005378921941943754   TRAIN LOSS_2  0.0066174548969257065   TRAIN LOSS_3  0.007063510093629332   TRAIN LOSS_4  0.007129135636678352   TRAIN LOSS_5  0.005393101485112312   TRAIN LOSS_6  0.007695399158497136
# EPOCH  559630  | TRAIN LOSS_1  0.00537891379938365   TRAIN LOSS_2  0.006617448988193675   TRAIN LOSS_3  0.00706350547550025   TRAIN LOSS_4  0.0071291310987109035   TRAIN LOSS_5  0.005393097616927493   TRAIN LOSS_6  0.007695372447336753
# EPOCH  559631  | TRAIN LOSS_1  0.005378905656837282   TRAIN LOSS_2  0.006617443079511247   TRAIN LOSS_3  0.007063500857384964   TRAIN LOSS_4  0.007129126560752791   TRAIN LOSS_5  0.005393093748757768   TRAIN LOSS_6  0.007695345736183858
# EPOCH  559632  | TRAIN LOSS_1  0.005378897514304647   TRAIN LOSS_2  0.00661743717087842   TRAIN LOSS_3  0.007063496239283472   TRAIN LOSS_4  0.007129122022804008   TRAIN LOSS_5  0.005393089880603147   TRAIN LOSS_6  0.0076953190250385155
# EPOCH  559633  | TRAIN LOSS_1  0.0053788893717857285   TRAIN LOSS_2  0.006617431262295185   TRAIN LOSS_3  0.007063491621195762   TRAIN LOSS_4  0.007129117484864557   TRAIN LOSS_5  0.005393086012463622   TRAIN LOSS_6  0.007695292313900777
# EPOCH  559634  | TRAIN LOSS_1  0.0053788812292805376   TRAIN LOSS_2  0.00661742535376154   TRAIN LOSS_3  0.007063487003121837   TRAIN LOSS_4  0.00712911294693444   TRAIN LOSS_5  0.005393082144339192   TRAIN LOSS_6  0.007695265602770703
# EPOCH  559635  | TRAIN LOSS_1  0.005378873086789053   TRAIN LOSS_2  0.006617419445277473   TRAIN LOSS_3  0.007063482385061684   TRAIN LOSS_4  0.00712910840901366   TRAIN LOSS_5  0.005393078276229856   TRAIN LOSS_6  0.007695238891648362
# EPOCH  559636  | TRAIN LOSS_1  0.005378864944311278   TRAIN LOSS_2  0.0066174135368429945   TRAIN LOSS_3  0.007063477767015301   TRAIN LOSS_4  0.007129103871102208   TRAIN LOSS_5  0.005393074408135621   TRAIN LOSS_6  0.007695212180533804
# EPOCH  559637  | TRAIN LOSS_1  0.005378856801847204   TRAIN LOSS_2  0.006617407628458093   TRAIN LOSS_3  0.007063473148982687   TRAIN LOSS_4  0.007129099333200092   TRAIN LOSS_5  0.005393070540056474   TRAIN LOSS_6  0.0076951854694271
# EPOCH  559638  | TRAIN LOSS_1  0.005378848659396825   TRAIN LOSS_2  0.0066174017201227646   TRAIN LOSS_3  0.007063468530963827   TRAIN LOSS_4  0.007129094795307322   TRAIN LOSS_5  0.005393066671992419   TRAIN LOSS_6  0.0076951587583283
# EPOCH  559639  | TRAIN LOSS_1  0.005378840516960137   TRAIN LOSS_2  0.006617395811837004   TRAIN LOSS_3  0.007063463912958722   TRAIN LOSS_4  0.007129090257423875   TRAIN LOSS_5  0.005393062803943457   TRAIN LOSS_6  0.00769513204723747
# EPOCH  559640  | TRAIN LOSS_1  0.005378832374537135   TRAIN LOSS_2  0.006617389903600808   TRAIN LOSS_3  0.0070634592949673685   TRAIN LOSS_4  0.007129085719549771   TRAIN LOSS_5  0.005393058935909584   TRAIN LOSS_6  0.007695105336154672
# EPOCH  559641  | TRAIN LOSS_1  0.005378824232127807   TRAIN LOSS_2  0.006617383995414175   TRAIN LOSS_3  0.0070634546769897544   TRAIN LOSS_4  0.007129081181685004   TRAIN LOSS_5  0.0053930550678908   TRAIN LOSS_6  0.007695078625079957
# EPOCH  559642  | TRAIN LOSS_1  0.005378816089732149   TRAIN LOSS_2  0.006617378087277091   TRAIN LOSS_3  0.00706345005902588   TRAIN LOSS_4  0.00712907664382958   TRAIN LOSS_5  0.0053930511998871045   TRAIN LOSS_6  0.0076950519140133984
# EPOCH  559643  | TRAIN LOSS_1  0.005378807947350154   TRAIN LOSS_2  0.006617372179189571   TRAIN LOSS_3  0.007063445441075739   TRAIN LOSS_4  0.007129072105983485   TRAIN LOSS_5  0.005393047331898493   TRAIN LOSS_6  0.007695025202955042
# EPOCH  559644  | TRAIN LOSS_1  0.005378799804981824   TRAIN LOSS_2  0.006617366271151592   TRAIN LOSS_3  0.007063440823139325   TRAIN LOSS_4  0.007129067568146735   TRAIN LOSS_5  0.005393043463924973   TRAIN LOSS_6  0.007694998491904956
# EPOCH  559645  | TRAIN LOSS_1  0.005378791662627146   TRAIN LOSS_2  0.006617360363163158   TRAIN LOSS_3  0.0070634362052166295   TRAIN LOSS_4  0.0071290630303193206   TRAIN LOSS_5  0.005393039595966532   TRAIN LOSS_6  0.007694971780863205
# EPOCH  559646  | TRAIN LOSS_1  0.005378783520286115   TRAIN LOSS_2  0.006617354455224265   TRAIN LOSS_3  0.007063431587307653   TRAIN LOSS_4  0.00712905849250125   TRAIN LOSS_5  0.00539303572802318   TRAIN LOSS_6  0.007694945069829843
# EPOCH  559647  | TRAIN LOSS_1  0.005378775377958728   TRAIN LOSS_2  0.006617348547334908   TRAIN LOSS_3  0.0070634269694123935   TRAIN LOSS_4  0.007129053954692518   TRAIN LOSS_5  0.005393031860094908   TRAIN LOSS_6  0.007694918358804928
# EPOCH  559648  | TRAIN LOSS_1  0.005378767235644974   TRAIN LOSS_2  0.006617342639495081   TRAIN LOSS_3  0.007063422351530827   TRAIN LOSS_4  0.00712904941689313   TRAIN LOSS_5  0.0053930279921817195   TRAIN LOSS_6  0.007694891647788524
# EPOCH  559649  | TRAIN LOSS_1  0.005378759093344851   TRAIN LOSS_2  0.006617336731704785   TRAIN LOSS_3  0.0070634177336629704   TRAIN LOSS_4  0.007129044879103085   TRAIN LOSS_5  0.005393024124283608   TRAIN LOSS_6  0.007694864936780693
# EPOCH  559650  | TRAIN LOSS_1  0.005378750951058353   TRAIN LOSS_2  0.0066173308239640145   TRAIN LOSS_3  0.007063413115808807   TRAIN LOSS_4  0.007129040341322379   TRAIN LOSS_5  0.005393020256400579   TRAIN LOSS_6  0.007694838225781497
# EPOCH  559651  | TRAIN LOSS_1  0.0053787428087854715   TRAIN LOSS_2  0.006617324916272759   TRAIN LOSS_3  0.0070634084979683326   TRAIN LOSS_4  0.007129035803551017   TRAIN LOSS_5  0.005393016388532628   TRAIN LOSS_6  0.007694811514790991
# EPOCH  559652  | TRAIN LOSS_1  0.0053787346665262045   TRAIN LOSS_2  0.006617319008631018   TRAIN LOSS_3  0.007063403880141542   TRAIN LOSS_4  0.007129031265788999   TRAIN LOSS_5  0.005393012520679756   TRAIN LOSS_6  0.0076947848038092315
# EPOCH  559653  | TRAIN LOSS_1  0.00537872652428054   TRAIN LOSS_2  0.006617313101038791   TRAIN LOSS_3  0.007063399262328435   TRAIN LOSS_4  0.0071290267280363275   TRAIN LOSS_5  0.00539300865284196   TRAIN LOSS_6  0.0076947580928362885
# EPOCH  559654  | TRAIN LOSS_1  0.00537871838204848   TRAIN LOSS_2  0.006617307193496072   TRAIN LOSS_3  0.0070633946445289985   TRAIN LOSS_4  0.007129022190292997   TRAIN LOSS_5  0.005393004785019239   TRAIN LOSS_6  0.007694731381872224
# EPOCH  559655  | TRAIN LOSS_1  0.005378710239830013   TRAIN LOSS_2  0.006617301286002858   TRAIN LOSS_3  0.007063390026743232   TRAIN LOSS_4  0.0071290176525590125   TRAIN LOSS_5  0.0053930009172115925   TRAIN LOSS_6  0.0076947046709170885
# EPOCH  559656  | TRAIN LOSS_1  0.005378702097625132   TRAIN LOSS_2  0.006617295378559137   TRAIN LOSS_3  0.007063385408971127   TRAIN LOSS_4  0.007129013114834377   TRAIN LOSS_5  0.005392997049419024   TRAIN LOSS_6  0.007694677959970945
# EPOCH  559657  | TRAIN LOSS_1  0.005378693955433831   TRAIN LOSS_2  0.006617289471164916   TRAIN LOSS_3  0.007063380791212676   TRAIN LOSS_4  0.007129008577119085   TRAIN LOSS_5  0.005392993181641521   TRAIN LOSS_6  0.007694651249033859
# EPOCH  559658  | TRAIN LOSS_1  0.005378685813256113   TRAIN LOSS_2  0.006617283563820186   TRAIN LOSS_3  0.007063376173467886   TRAIN LOSS_4  0.007129004039413145   TRAIN LOSS_5  0.005392989313879094   TRAIN LOSS_6  0.007694624538105891
# EPOCH  559659  | TRAIN LOSS_1  0.005378677671091961   TRAIN LOSS_2  0.00661727765652494   TRAIN LOSS_3  0.007063371555736738   TRAIN LOSS_4  0.007128999501716553   TRAIN LOSS_5  0.005392985446131736   TRAIN LOSS_6  0.007694597827187093
# EPOCH  559660  | TRAIN LOSS_1  0.0053786695289413785   TRAIN LOSS_2  0.006617271749279176   TRAIN LOSS_3  0.007063366938019233   TRAIN LOSS_4  0.007128994964029303   TRAIN LOSS_5  0.005392981578399441   TRAIN LOSS_6  0.007694571116277531
# EPOCH  559661  | TRAIN LOSS_1  0.005378661386804351   TRAIN LOSS_2  0.006617265842082895   TRAIN LOSS_3  0.007063362320315364   TRAIN LOSS_4  0.007128990426351402   TRAIN LOSS_5  0.005392977710682225   TRAIN LOSS_6  0.007694544405377267
# EPOCH  559662  | TRAIN LOSS_1  0.005378653244680876   TRAIN LOSS_2  0.006617259934936086   TRAIN LOSS_3  0.007063357702625127   TRAIN LOSS_4  0.007128985888682856   TRAIN LOSS_5  0.005392973842980073   TRAIN LOSS_6  0.007694517694486368
# EPOCH  559663  | TRAIN LOSS_1  0.0053786451025709505   TRAIN LOSS_2  0.006617254027838744   TRAIN LOSS_3  0.007063353084948517   TRAIN LOSS_4  0.007128981351023661   TRAIN LOSS_5  0.005392969975292988   TRAIN LOSS_6  0.007694490983604876
# EPOCH  559664  | TRAIN LOSS_1  0.005378636960474567   TRAIN LOSS_2  0.006617248120790871   TRAIN LOSS_3  0.0070633484672855225   TRAIN LOSS_4  0.007128976813373813   TRAIN LOSS_5  0.005392966107620964   TRAIN LOSS_6  0.007694464272732863
# EPOCH  559665  | TRAIN LOSS_1  0.005378628818391718   TRAIN LOSS_2  0.0066172422137924574   TRAIN LOSS_3  0.007063343849636149   TRAIN LOSS_4  0.007128972275733313   TRAIN LOSS_5  0.0053929622399640055   TRAIN LOSS_6  0.007694437561870395
# EPOCH  559666  | TRAIN LOSS_1  0.005378620676322392   TRAIN LOSS_2  0.006617236306843508   TRAIN LOSS_3  0.007063339232000381   TRAIN LOSS_4  0.007128967738102175   TRAIN LOSS_5  0.005392958372322112   TRAIN LOSS_6  0.007694410851017518
# EPOCH  559667  | TRAIN LOSS_1  0.005378612534266596   TRAIN LOSS_2  0.0066172303999440085   TRAIN LOSS_3  0.007063334614378219   TRAIN LOSS_4  0.007128963200480383   TRAIN LOSS_5  0.005392954504695282   TRAIN LOSS_6  0.0076943841401743126
# EPOCH  559668  | TRAIN LOSS_1  0.005378604392224312   TRAIN LOSS_2  0.00661722449309396   TRAIN LOSS_3  0.007063329996769658   TRAIN LOSS_4  0.007128958662867944   TRAIN LOSS_5  0.005392950637083505   TRAIN LOSS_6  0.00769435742934082
# EPOCH  559669  | TRAIN LOSS_1  0.005378596250195546   TRAIN LOSS_2  0.006617218586293356   TRAIN LOSS_3  0.007063325379174691   TRAIN LOSS_4  0.00712895412526486   TRAIN LOSS_5  0.005392946769486795   TRAIN LOSS_6  0.007694330718517109
# EPOCH  559670  | TRAIN LOSS_1  0.005378588108180282   TRAIN LOSS_2  0.006617212679542193   TRAIN LOSS_3  0.007063320761593311   TRAIN LOSS_4  0.0071289495876711295   TRAIN LOSS_5  0.005392942901905146   TRAIN LOSS_6  0.007694304007703234
# EPOCH  559671  | TRAIN LOSS_1  0.005378579966178516   TRAIN LOSS_2  0.006617206772840471   TRAIN LOSS_3  0.007063316144025511   TRAIN LOSS_4  0.007128945050086752   TRAIN LOSS_5  0.005392939034338555   TRAIN LOSS_6  0.007694277296899267
# EPOCH  559672  | TRAIN LOSS_1  0.005378571824190246   TRAIN LOSS_2  0.006617200866188177   TRAIN LOSS_3  0.007063311526471294   TRAIN LOSS_4  0.00712894051251173   TRAIN LOSS_5  0.0053929351667870145   TRAIN LOSS_6  0.007694250586105263
# EPOCH  559673  | TRAIN LOSS_1  0.005378563682215465   TRAIN LOSS_2  0.006617194959585315   TRAIN LOSS_3  0.007063306908930644   TRAIN LOSS_4  0.007128935974946069   TRAIN LOSS_5  0.005392931299250531   TRAIN LOSS_6  0.007694223875321283
# EPOCH  559674  | TRAIN LOSS_1  0.005378555540254158   TRAIN LOSS_2  0.006617189053031881   TRAIN LOSS_3  0.007063302291403564   TRAIN LOSS_4  0.007128931437389759   TRAIN LOSS_5  0.005392927431729109   TRAIN LOSS_6  0.007694197164547387
# EPOCH  559675  | TRAIN LOSS_1  0.005378547398306334   TRAIN LOSS_2  0.006617183146527864   TRAIN LOSS_3  0.007063297673890047   TRAIN LOSS_4  0.007128926899842808   TRAIN LOSS_5  0.005392923564222736   TRAIN LOSS_6  0.0076941704537836384
# EPOCH  559676  | TRAIN LOSS_1  0.005378539256371979   TRAIN LOSS_2  0.006617177240073263   TRAIN LOSS_3  0.007063293056390088   TRAIN LOSS_4  0.007128922362305215   TRAIN LOSS_5  0.005392919696731415   TRAIN LOSS_6  0.007694143743030096
# EPOCH  559677  | TRAIN LOSS_1  0.005378531114451085   TRAIN LOSS_2  0.0066171713336680765   TRAIN LOSS_3  0.007063288438903676   TRAIN LOSS_4  0.007128917824776985   TRAIN LOSS_5  0.0053929158292551505   TRAIN LOSS_6  0.00769411703228682
# EPOCH  559678  | TRAIN LOSS_1  0.005378522972543653   TRAIN LOSS_2  0.0066171654273123   TRAIN LOSS_3  0.007063283821430808   TRAIN LOSS_4  0.0071289132872581085   TRAIN LOSS_5  0.00539291196179393   TRAIN LOSS_6  0.007694090321553869
# EPOCH  559679  | TRAIN LOSS_1  0.005378514830649676   TRAIN LOSS_2  0.006617159521005926   TRAIN LOSS_3  0.007063279203971484   TRAIN LOSS_4  0.007128908749748589   TRAIN LOSS_5  0.005392908094347766   TRAIN LOSS_6  0.007694063610831302
# EPOCH  559680  | TRAIN LOSS_1  0.005378506688769139   TRAIN LOSS_2  0.006617153614748952   TRAIN LOSS_3  0.007063274586525695   TRAIN LOSS_4  0.007128904212248434   TRAIN LOSS_5  0.005392904226916645   TRAIN LOSS_6  0.0076940369001191914
# EPOCH  559681  | TRAIN LOSS_1  0.005378498546902044   TRAIN LOSS_2  0.006617147708541376   TRAIN LOSS_3  0.007063269969093437   TRAIN LOSS_4  0.007128899674757632   TRAIN LOSS_5  0.005392900359500577   TRAIN LOSS_6  0.007694010189417589
# EPOCH  559682  | TRAIN LOSS_1  0.005378490405048381   TRAIN LOSS_2  0.006617141802383191   TRAIN LOSS_3  0.007063265351674702   TRAIN LOSS_4  0.007128895137276204   TRAIN LOSS_5  0.0053928964920995515   TRAIN LOSS_6  0.007693983478726557
# EPOCH  559683  | TRAIN LOSS_1  0.005378482263208152   TRAIN LOSS_2  0.006617135896274398   TRAIN LOSS_3  0.007063260734269485   TRAIN LOSS_4  0.007128890599804127   TRAIN LOSS_5  0.005392892624713574   TRAIN LOSS_6  0.007693956768046158
# EPOCH  559684  | TRAIN LOSS_1  0.005378474121381344   TRAIN LOSS_2  0.006617129990214984   TRAIN LOSS_3  0.007063256116877784   TRAIN LOSS_4  0.007128886062341416   TRAIN LOSS_5  0.00539288875734264   TRAIN LOSS_6  0.007693930057376445
# EPOCH  559685  | TRAIN LOSS_1  0.005378465979567949   TRAIN LOSS_2  0.006617124084204951   TRAIN LOSS_3  0.007063251499499588   TRAIN LOSS_4  0.007128881524888075   TRAIN LOSS_5  0.005392884889986748   TRAIN LOSS_6  0.007693903346717491
# EPOCH  559686  | TRAIN LOSS_1  0.0053784578377679675   TRAIN LOSS_2  0.006617118178244293   TRAIN LOSS_3  0.007063246882134896   TRAIN LOSS_4  0.007128876987444088   TRAIN LOSS_5  0.005392881022645902   TRAIN LOSS_6  0.007693876636069353
# EPOCH  559687  | TRAIN LOSS_1  0.00537844969598139   TRAIN LOSS_2  0.006617112272333009   TRAIN LOSS_3  0.007063242264783702   TRAIN LOSS_4  0.007128872450009467   TRAIN LOSS_5  0.005392877155320094   TRAIN LOSS_6  0.00769384992543208
# EPOCH  559688  | TRAIN LOSS_1  0.0053784415542082135   TRAIN LOSS_2  0.006617106366471089   TRAIN LOSS_3  0.007063237647446001   TRAIN LOSS_4  0.007128867912584214   TRAIN LOSS_5  0.005392873288009329   TRAIN LOSS_6  0.00769382321480575
# EPOCH  559689  | TRAIN LOSS_1  0.005378433412448425   TRAIN LOSS_2  0.006617100460658536   TRAIN LOSS_3  0.007063233030121786   TRAIN LOSS_4  0.007128863375168321   TRAIN LOSS_5  0.005392869420713605   TRAIN LOSS_6  0.007693796504190415
# EPOCH  559690  | TRAIN LOSS_1  0.005378425270702032   TRAIN LOSS_2  0.006617094554895343   TRAIN LOSS_3  0.0070632284128110505   TRAIN LOSS_4  0.007128858837761796   TRAIN LOSS_5  0.005392865553432915   TRAIN LOSS_6  0.007693769793586139
# EPOCH  559691  | TRAIN LOSS_1  0.0053784171289690125   TRAIN LOSS_2  0.006617088649181502   TRAIN LOSS_3  0.007063223795513792   TRAIN LOSS_4  0.0071288543003646425   TRAIN LOSS_5  0.0053928616861672616   TRAIN LOSS_6  0.007693743082992979
# EPOCH  559692  | TRAIN LOSS_1  0.005378408987249371   TRAIN LOSS_2  0.006617082743517013   TRAIN LOSS_3  0.0070632191782300105   TRAIN LOSS_4  0.007128849762976847   TRAIN LOSS_5  0.0053928578189166515   TRAIN LOSS_6  0.007693716372411004
# EPOCH  559693  | TRAIN LOSS_1  0.005378400845543101   TRAIN LOSS_2  0.006617076837901873   TRAIN LOSS_3  0.00706321456095969   TRAIN LOSS_4  0.007128845225598424   TRAIN LOSS_5  0.0053928539516810686   TRAIN LOSS_6  0.007693689661840261
# EPOCH  559694  | TRAIN LOSS_1  0.005378392703850191   TRAIN LOSS_2  0.00661707093233607   TRAIN LOSS_3  0.007063209943702833   TRAIN LOSS_4  0.007128840688229372   TRAIN LOSS_5  0.005392850084460526   TRAIN LOSS_6  0.007693662951280827
# EPOCH  559695  | TRAIN LOSS_1  0.005378384562170638   TRAIN LOSS_2  0.00661706502681961   TRAIN LOSS_3  0.0070632053264594215   TRAIN LOSS_4  0.007128836150869683   TRAIN LOSS_5  0.005392846217255014   TRAIN LOSS_6  0.007693636240732749
# EPOCH  559696  | TRAIN LOSS_1  0.0053783764205044375   TRAIN LOSS_2  0.006617059121352487   TRAIN LOSS_3  0.00706320070922947   TRAIN LOSS_4  0.007128831613519365   TRAIN LOSS_5  0.005392842350064537   TRAIN LOSS_6  0.007693609530196095
# EPOCH  559697  | TRAIN LOSS_1  0.005378368278851584   TRAIN LOSS_2  0.00661705321593469   TRAIN LOSS_3  0.007063196092012958   TRAIN LOSS_4  0.0071288270761784185   TRAIN LOSS_5  0.0053928384828890895   TRAIN LOSS_6  0.007693582819670931
# EPOCH  559698  | TRAIN LOSS_1  0.0053783601372120685   TRAIN LOSS_2  0.006617047310566219   TRAIN LOSS_3  0.007063191474809887   TRAIN LOSS_4  0.007128822538846844   TRAIN LOSS_5  0.005392834615728673   TRAIN LOSS_6  0.007693556109157306
# EPOCH  559699  | TRAIN LOSS_1  0.005378351995585893   TRAIN LOSS_2  0.006617041405247071   TRAIN LOSS_3  0.007063186857620248   TRAIN LOSS_4  0.007128818001524638   TRAIN LOSS_5  0.005392830748583286   TRAIN LOSS_6  0.0076935293986552964
# EPOCH  559700  | TRAIN LOSS_1  0.005378343853973039   TRAIN LOSS_2  0.006617035499977244   TRAIN LOSS_3  0.007063182240444042   TRAIN LOSS_4  0.007128813464211801   TRAIN LOSS_5  0.005392826881452925   TRAIN LOSS_6  0.007693502688164949
# EPOCH  559701  | TRAIN LOSS_1  0.005378335712373506   TRAIN LOSS_2  0.006617029594756727   TRAIN LOSS_3  0.007063177623281248   TRAIN LOSS_4  0.0071288089269083395   TRAIN LOSS_5  0.00539282301433759   TRAIN LOSS_6  0.007693475977686329
# EPOCH  559702  | TRAIN LOSS_1  0.005378327570787292   TRAIN LOSS_2  0.0066170236895855255   TRAIN LOSS_3  0.007063173006131878   TRAIN LOSS_4  0.007128804389614252   TRAIN LOSS_5  0.005392819147237282   TRAIN LOSS_6  0.007693449267219498
# EPOCH  559703  | TRAIN LOSS_1  0.005378319429214385   TRAIN LOSS_2  0.006617017784463628   TRAIN LOSS_3  0.0070631683889959196   TRAIN LOSS_4  0.007128799852329533   TRAIN LOSS_5  0.005392815280151999   TRAIN LOSS_6  0.007693422556764521
# EPOCH  559704  | TRAIN LOSS_1  0.005378311287654787   TRAIN LOSS_2  0.006617011879391033   TRAIN LOSS_3  0.007063163771873365   TRAIN LOSS_4  0.007128795315054196   TRAIN LOSS_5  0.005392811413081739   TRAIN LOSS_6  0.007693395846321453
# EPOCH  559705  | TRAIN LOSS_1  0.005378303146108487   TRAIN LOSS_2  0.006617005974367731   TRAIN LOSS_3  0.007063159154764219   TRAIN LOSS_4  0.007128790777788227   TRAIN LOSS_5  0.00539280754602651   TRAIN LOSS_6  0.007693369135890359
# EPOCH  559706  | TRAIN LOSS_1  0.005378295004575475   TRAIN LOSS_2  0.006617000069393725   TRAIN LOSS_3  0.007063154537668465   TRAIN LOSS_4  0.0071287862405316335   TRAIN LOSS_5  0.005392803678986298   TRAIN LOSS_6  0.007693342425471301
# EPOCH  559707  | TRAIN LOSS_1  0.005378286863055752   TRAIN LOSS_2  0.006616994164469009   TRAIN LOSS_3  0.0070631499205861   TRAIN LOSS_4  0.007128781703284414   TRAIN LOSS_5  0.0053927998119611045   TRAIN LOSS_6  0.007693315715064335
# EPOCH  559708  | TRAIN LOSS_1  0.005378278721549311   TRAIN LOSS_2  0.006616988259593579   TRAIN LOSS_3  0.007063145303517126   TRAIN LOSS_4  0.0071287771660465795   TRAIN LOSS_5  0.005392795944950931   TRAIN LOSS_6  0.007693289004669533
# EPOCH  559709  | TRAIN LOSS_1  0.0053782705800561464   TRAIN LOSS_2  0.006616982354767428   TRAIN LOSS_3  0.007063140686461525   TRAIN LOSS_4  0.007128772628818116   TRAIN LOSS_5  0.005392792077955778   TRAIN LOSS_6  0.007693262294286945
# EPOCH  559710  | TRAIN LOSS_1  0.005378262438576247   TRAIN LOSS_2  0.006616976449990552   TRAIN LOSS_3  0.007063136069419304   TRAIN LOSS_4  0.007128768091599026   TRAIN LOSS_5  0.005392788210975643   TRAIN LOSS_6  0.007693235583916631
# EPOCH  559711  | TRAIN LOSS_1  0.005378254297109612   TRAIN LOSS_2  0.006616970545262949   TRAIN LOSS_3  0.007063131452390447   TRAIN LOSS_4  0.007128763554389321   TRAIN LOSS_5  0.005392784344010522   TRAIN LOSS_6  0.00769320887355866
# EPOCH  559712  | TRAIN LOSS_1  0.005378246155656231   TRAIN LOSS_2  0.006616964640584619   TRAIN LOSS_3  0.007063126835374958   TRAIN LOSS_4  0.00712875901718899   TRAIN LOSS_5  0.00539278047706042   TRAIN LOSS_6  0.0076931821632130895
# EPOCH  559713  | TRAIN LOSS_1  0.005378238014216104   TRAIN LOSS_2  0.0066169587359555465   TRAIN LOSS_3  0.007063122218372826   TRAIN LOSS_4  0.0071287544799980415   TRAIN LOSS_5  0.005392776610125332   TRAIN LOSS_6  0.007693155452879989
# EPOCH  559714  | TRAIN LOSS_1  0.005378229872789226   TRAIN LOSS_2  0.006616952831375742   TRAIN LOSS_3  0.00706311760138405   TRAIN LOSS_4  0.007128749942816469   TRAIN LOSS_5  0.005392772743205261   TRAIN LOSS_6  0.007693128742559401
# EPOCH  559715  | TRAIN LOSS_1  0.00537822173137558   TRAIN LOSS_2  0.006616946926845193   TRAIN LOSS_3  0.007063112984408617   TRAIN LOSS_4  0.00712874540564428   TRAIN LOSS_5  0.005392768876300199   TRAIN LOSS_6  0.007693102032251408
# EPOCH  559716  | TRAIN LOSS_1  0.005378213589975169   TRAIN LOSS_2  0.006616941022363894   TRAIN LOSS_3  0.007063108367446532   TRAIN LOSS_4  0.0071287408684814705   TRAIN LOSS_5  0.005392765009410148   TRAIN LOSS_6  0.007693075321956053
# EPOCH  559717  | TRAIN LOSS_1  0.005378205448587988   TRAIN LOSS_2  0.0066169351179318405   TRAIN LOSS_3  0.007063103750497777   TRAIN LOSS_4  0.007128736331328043   TRAIN LOSS_5  0.00539276114253511   TRAIN LOSS_6  0.0076930486116734125
# EPOCH  559718  | TRAIN LOSS_1  0.00537819730721403   TRAIN LOSS_2  0.006616929213549036   TRAIN LOSS_3  0.007063099133562361   TRAIN LOSS_4  0.007128731794183996   TRAIN LOSS_5  0.005392757275675079   TRAIN LOSS_6  0.007693021901403538
# EPOCH  559719  | TRAIN LOSS_1  0.005378189165853283   TRAIN LOSS_2  0.00661692330921547   TRAIN LOSS_3  0.0070630945166402755   TRAIN LOSS_4  0.007128727257049334   TRAIN LOSS_5  0.005392753408830058   TRAIN LOSS_6  0.0076929951911464955
# EPOCH  559720  | TRAIN LOSS_1  0.00537818102450575   TRAIN LOSS_2  0.0066169174049311415   TRAIN LOSS_3  0.0070630898997315   TRAIN LOSS_4  0.007128722719924052   TRAIN LOSS_5  0.005392749542000048   TRAIN LOSS_6  0.007692968480902343
# EPOCH  559721  | TRAIN LOSS_1  0.005378172883171418   TRAIN LOSS_2  0.006616911500696039   TRAIN LOSS_3  0.007063085282836046   TRAIN LOSS_4  0.007128718182808161   TRAIN LOSS_5  0.005392745675185036   TRAIN LOSS_6  0.007692941770671143
# EPOCH  559722  | TRAIN LOSS_1  0.00537816474185028   TRAIN LOSS_2  0.006616905596510175   TRAIN LOSS_3  0.007063080665953901   TRAIN LOSS_4  0.0071287136457016485   TRAIN LOSS_5  0.005392741808385041   TRAIN LOSS_6  0.007692915060452961
# EPOCH  559723  | TRAIN LOSS_1  0.005378156600542342   TRAIN LOSS_2  0.006616899692373525   TRAIN LOSS_3  0.007063076049085063   TRAIN LOSS_4  0.00712870910860452   TRAIN LOSS_5  0.005392737941600043   TRAIN LOSS_6  0.007692888350247854
# EPOCH  559724  | TRAIN LOSS_1  0.005378148459247588   TRAIN LOSS_2  0.006616893788286093   TRAIN LOSS_3  0.007063071432229526   TRAIN LOSS_4  0.007128704571516779   TRAIN LOSS_5  0.005392734074830047   TRAIN LOSS_6  0.007692861640055882
# EPOCH  559725  | TRAIN LOSS_1  0.005378140317966016   TRAIN LOSS_2  0.0066168878842478825   TRAIN LOSS_3  0.007063066815387278   TRAIN LOSS_4  0.007128700034438425   TRAIN LOSS_5  0.005392730208075059   TRAIN LOSS_6  0.007692834929877111
# EPOCH  559726  | TRAIN LOSS_1  0.005378132176697612   TRAIN LOSS_2  0.00661688198025888   TRAIN LOSS_3  0.007063062198558324   TRAIN LOSS_4  0.00712869549736946   TRAIN LOSS_5  0.005392726341335071   TRAIN LOSS_6  0.007692808219711603
# EPOCH  559727  | TRAIN LOSS_1  0.0053781240354423806   TRAIN LOSS_2  0.0066168760763190854   TRAIN LOSS_3  0.007063057581742651   TRAIN LOSS_4  0.007128690960309877   TRAIN LOSS_5  0.005392722474610081   TRAIN LOSS_6  0.007692781509559409
# EPOCH  559728  | TRAIN LOSS_1  0.0053781158942003094   TRAIN LOSS_2  0.006616870172428489   TRAIN LOSS_3  0.007063052964940259   TRAIN LOSS_4  0.007128686423259684   TRAIN LOSS_5  0.0053927186079000934   TRAIN LOSS_6  0.007692754799420599
# EPOCH  559729  | TRAIN LOSS_1  0.0053781077529713945   TRAIN LOSS_2  0.006616864268587097   TRAIN LOSS_3  0.007063048348151139   TRAIN LOSS_4  0.007128681886218879   TRAIN LOSS_5  0.005392714741205101   TRAIN LOSS_6  0.007692728089295235
# EPOCH  559730  | TRAIN LOSS_1  0.005378099611755633   TRAIN LOSS_2  0.0066168583647949   TRAIN LOSS_3  0.007063043731375286   TRAIN LOSS_4  0.007128677349187463   TRAIN LOSS_5  0.005392710874525111   TRAIN LOSS_6  0.007692701379183377
# EPOCH  559731  | TRAIN LOSS_1  0.005378091470553017   TRAIN LOSS_2  0.006616852461051886   TRAIN LOSS_3  0.007063039114612695   TRAIN LOSS_4  0.007128672812165438   TRAIN LOSS_5  0.005392707007860112   TRAIN LOSS_6  0.007692674669085089
# EPOCH  559732  | TRAIN LOSS_1  0.005378083329363539   TRAIN LOSS_2  0.006616846557358066   TRAIN LOSS_3  0.007063034497863358   TRAIN LOSS_4  0.007128668275152803   TRAIN LOSS_5  0.005392703141210113   TRAIN LOSS_6  0.007692647959000427
# EPOCH  559733  | TRAIN LOSS_1  0.0053780751881871945   TRAIN LOSS_2  0.006616840653713424   TRAIN LOSS_3  0.0070630298811272816   TRAIN LOSS_4  0.0071286637381495575   TRAIN LOSS_5  0.005392699274575104   TRAIN LOSS_6  0.007692621248929449
# EPOCH  559734  | TRAIN LOSS_1  0.005378067047023972   TRAIN LOSS_2  0.006616834750117961   TRAIN LOSS_3  0.007063025264404444   TRAIN LOSS_4  0.007128659201155702   TRAIN LOSS_5  0.005392695407955089   TRAIN LOSS_6  0.007692594538872234
# EPOCH  559735  | TRAIN LOSS_1  0.00537805890587388   TRAIN LOSS_2  0.00661682884657167   TRAIN LOSS_3  0.007063020647694855   TRAIN LOSS_4  0.007128654664171243   TRAIN LOSS_5  0.0053926915413500705   TRAIN LOSS_6  0.007692567828828831
# EPOCH  559736  | TRAIN LOSS_1  0.005378050764736893   TRAIN LOSS_2  0.006616822943074556   TRAIN LOSS_3  0.007063016030998488   TRAIN LOSS_4  0.007128650127196174   TRAIN LOSS_5  0.0053926876747600406   TRAIN LOSS_6  0.007692541118799299
# EPOCH  559737  | TRAIN LOSS_1  0.0053780426236130245   TRAIN LOSS_2  0.006616817039626602   TRAIN LOSS_3  0.00706301141431536   TRAIN LOSS_4  0.007128645590230498   TRAIN LOSS_5  0.005392683808184996   TRAIN LOSS_6  0.007692514408783708
# EPOCH  559738  | TRAIN LOSS_1  0.005378034482502253   TRAIN LOSS_2  0.006616811136227811   TRAIN LOSS_3  0.007063006797645461   TRAIN LOSS_4  0.0071286410532742156   TRAIN LOSS_5  0.005392679941624947   TRAIN LOSS_6  0.007692487698782107
# EPOCH  559739  | TRAIN LOSS_1  0.005378026341404582   TRAIN LOSS_2  0.006616805232878177   TRAIN LOSS_3  0.007063002180988773   TRAIN LOSS_4  0.007128636516327327   TRAIN LOSS_5  0.005392676075079886   TRAIN LOSS_6  0.007692460988794576
# EPOCH  559740  | TRAIN LOSS_1  0.005378018200320004   TRAIN LOSS_2  0.006616799329577697   TRAIN LOSS_3  0.0070629975643453045   TRAIN LOSS_4  0.007128631979389835   TRAIN LOSS_5  0.005392672208549811   TRAIN LOSS_6  0.007692434278821157
# EPOCH  559741  | TRAIN LOSS_1  0.005378010059248508   TRAIN LOSS_2  0.00661679342632637   TRAIN LOSS_3  0.007062992947715042   TRAIN LOSS_4  0.007128627442461741   TRAIN LOSS_5  0.005392668342034718   TRAIN LOSS_6  0.007692407568861928
# EPOCH  559742  | TRAIN LOSS_1  0.005378001918190095   TRAIN LOSS_2  0.006616787523124181   TRAIN LOSS_3  0.007062988331097984   TRAIN LOSS_4  0.00712862290554304   TRAIN LOSS_5  0.005392664475534616   TRAIN LOSS_6  0.007692380858916942
# EPOCH  559743  | TRAIN LOSS_1  0.005377993777144753   TRAIN LOSS_2  0.0066167816199711365   TRAIN LOSS_3  0.007062983714494123   TRAIN LOSS_4  0.007128618368633728   TRAIN LOSS_5  0.005392660609049496   TRAIN LOSS_6  0.007692354148986257
# EPOCH  559744  | TRAIN LOSS_1  0.005377985636112481   TRAIN LOSS_2  0.0066167757168672315   TRAIN LOSS_3  0.00706297909790346   TRAIN LOSS_4  0.007128613831733819   TRAIN LOSS_5  0.00539265674257936   TRAIN LOSS_6  0.007692327439069949
# EPOCH  559745  | TRAIN LOSS_1  0.005377977495093272   TRAIN LOSS_2  0.0066167698138124564   TRAIN LOSS_3  0.007062974481325977   TRAIN LOSS_4  0.007128609294843316   TRAIN LOSS_5  0.005392652876124205   TRAIN LOSS_6  0.007692300729168068
# EPOCH  559746  | TRAIN LOSS_1  0.005377969354087117   TRAIN LOSS_2  0.0066167639108068105   TRAIN LOSS_3  0.00706296986476168   TRAIN LOSS_4  0.007128604757962202   TRAIN LOSS_5  0.00539264900968403   TRAIN LOSS_6  0.0076922740192806715
# EPOCH  559747  | TRAIN LOSS_1  0.005377961213094014   TRAIN LOSS_2  0.006616758007850287   TRAIN LOSS_3  0.00706296524821056   TRAIN LOSS_4  0.007128600221090488   TRAIN LOSS_5  0.005392645143258834   TRAIN LOSS_6  0.007692247309407836
# EPOCH  559748  | TRAIN LOSS_1  0.0053779530721139585   TRAIN LOSS_2  0.006616752104942885   TRAIN LOSS_3  0.007062960631672609   TRAIN LOSS_4  0.007128595684228177   TRAIN LOSS_5  0.00539264127684862   TRAIN LOSS_6  0.00769222059954961
# EPOCH  559749  | TRAIN LOSS_1  0.005377944931146937   TRAIN LOSS_2  0.006616746202084602   TRAIN LOSS_3  0.007062956015147824   TRAIN LOSS_4  0.007128591147375259   TRAIN LOSS_5  0.005392637410453387   TRAIN LOSS_6  0.007692193889706063
# EPOCH  559750  | TRAIN LOSS_1  0.005377936790192953   TRAIN LOSS_2  0.006616740299275424   TRAIN LOSS_3  0.007062951398636201   TRAIN LOSS_4  0.007128586610531748   TRAIN LOSS_5  0.005392633544073126   TRAIN LOSS_6  0.007692167179877258
# EPOCH  559751  | TRAIN LOSS_1  0.0053779286492519895   TRAIN LOSS_2  0.006616734396515363   TRAIN LOSS_3  0.007062946782137732   TRAIN LOSS_4  0.007128582073697636   TRAIN LOSS_5  0.005392629677707839   TRAIN LOSS_6  0.007692140470063247
# EPOCH  559752  | TRAIN LOSS_1  0.005377920508324053   TRAIN LOSS_2  0.006616728493804401   TRAIN LOSS_3  0.007062942165652413   TRAIN LOSS_4  0.007128577536872933   TRAIN LOSS_5  0.005392625811357531   TRAIN LOSS_6  0.007692113760264103
# EPOCH  559753  | TRAIN LOSS_1  0.0053779123674091295   TRAIN LOSS_2  0.006616722591142539   TRAIN LOSS_3  0.007062937549180237   TRAIN LOSS_4  0.007128573000057625   TRAIN LOSS_5  0.005392621945022197   TRAIN LOSS_6  0.007692087050479875
# EPOCH  559754  | TRAIN LOSS_1  0.0053779042265072125   TRAIN LOSS_2  0.006616716688529773   TRAIN LOSS_3  0.007062932932721209   TRAIN LOSS_4  0.007128568463251719   TRAIN LOSS_5  0.005392618078701835   TRAIN LOSS_6  0.0076920603407106365
# EPOCH  559755  | TRAIN LOSS_1  0.005377896085618299   TRAIN LOSS_2  0.006616710785966102   TRAIN LOSS_3  0.007062928316275309   TRAIN LOSS_4  0.007128563926455219   TRAIN LOSS_5  0.0053926142123964455   TRAIN LOSS_6  0.007692033630956445
# EPOCH  559756  | TRAIN LOSS_1  0.005377887944742385   TRAIN LOSS_2  0.006616704883451512   TRAIN LOSS_3  0.007062923699842535   TRAIN LOSS_4  0.007128559389668125   TRAIN LOSS_5  0.005392610346106027   TRAIN LOSS_6  0.007692006921217366
# EPOCH  559757  | TRAIN LOSS_1  0.0053778798038794625   TRAIN LOSS_2  0.0066166989809860076   TRAIN LOSS_3  0.007062919083422884   TRAIN LOSS_4  0.007128554852890434   TRAIN LOSS_5  0.005392606479830574   TRAIN LOSS_6  0.007691980211493459
# EPOCH  559758  | TRAIN LOSS_1  0.005377871663029525   TRAIN LOSS_2  0.006616693078569582   TRAIN LOSS_3  0.007062914467016356   TRAIN LOSS_4  0.007128550316122143   TRAIN LOSS_5  0.005392602613570094   TRAIN LOSS_6  0.007691953501784778
# EPOCH  559759  | TRAIN LOSS_1  0.005377863522192568   TRAIN LOSS_2  0.0066166871762022355   TRAIN LOSS_3  0.007062909850622936   TRAIN LOSS_4  0.007128545779363269   TRAIN LOSS_5  0.005392598747324586   TRAIN LOSS_6  0.0076919267920913985
# EPOCH  559760  | TRAIN LOSS_1  0.005377855381368585   TRAIN LOSS_2  0.006616681273883959   TRAIN LOSS_3  0.007062905234242623   TRAIN LOSS_4  0.00712854124261379   TRAIN LOSS_5  0.005392594881094039   TRAIN LOSS_6  0.0076919000824133684
# EPOCH  559761  | TRAIN LOSS_1  0.005377847240557567   TRAIN LOSS_2  0.006616675371614745   TRAIN LOSS_3  0.007062900617875415   TRAIN LOSS_4  0.0071285367058737245   TRAIN LOSS_5  0.005392591014878458   TRAIN LOSS_6  0.007691873372750759
# EPOCH  559762  | TRAIN LOSS_1  0.005377839099759514   TRAIN LOSS_2  0.006616669469394597   TRAIN LOSS_3  0.007062896001521301   TRAIN LOSS_4  0.007128532169143065   TRAIN LOSS_5  0.005392587148677838   TRAIN LOSS_6  0.0076918466631036315
# ...
# EPOCH  564494  | TRAIN LOSS_1  0.005339368544522106   TRAIN LOSS_2  0.0065892123066853495   TRAIN LOSS_3  0.0070410985803739355   TRAIN LOSS_4  0.007107180407672219   TRAIN LOSS_5  0.005374445120687658   TRAIN LOSS_6  0.007566851133956689
# EPOCH  564495  | TRAIN LOSS_1  0.0053393604088526085   TRAIN LOSS_2  0.006589206586476668   TRAIN LOSS_3  0.007041093961829479   TRAIN LOSS_4  0.007107175922353582   TRAIN LOSS_5  0.005374441316559689   TRAIN LOSS_6  0.007566825269149115
# EPOCH  564496  | TRAIN LOSS_1  0.0053393522731752276   TRAIN LOSS_2  0.006589200866294675   TRAIN LOSS_3  0.0070410893432700395   TRAIN LOSS_4  0.007107171437047353   TRAIN LOSS_5  0.005374437512443445   TRAIN LOSS_6  0.007566799404670571
# EPOCH  564497  | TRAIN LOSS_1  0.00533934413748995   TRAIN LOSS_2  0.006589195146139356   TRAIN LOSS_3  0.007041084724695602   TRAIN LOSS_4  0.007107166951753537   TRAIN LOSS_5  0.005374433708338925   TRAIN LOSS_6  0.007566773540521124
# EPOCH  564498  | TRAIN LOSS_1  0.00533933600179678   TRAIN LOSS_2  0.006589189426010712   TRAIN LOSS_3  0.007041080106106157   TRAIN LOSS_4  0.007107162466472131   TRAIN LOSS_5  0.005374429904246124   TRAIN LOSS_6  0.007566747676700814
# EPOCH  564499  | TRAIN LOSS_1  0.005339327866095717   TRAIN LOSS_2  0.006589183705908731   TRAIN LOSS_3  0.007041075487501707   TRAIN LOSS_4  0.007107157981203135   TRAIN LOSS_5  0.005374426100165049   TRAIN LOSS_6  0.007566721813209678
# EPOCH  564500  | TRAIN LOSS_1  0.005339319730386752   TRAIN LOSS_2  0.0065891779858334165   TRAIN LOSS_3  0.007041070868882233   TRAIN LOSS_4  0.007107153495946554   TRAIN LOSS_5  0.005374422296095691   TRAIN LOSS_6  0.007566695950047789
# EPOCH  564501  | TRAIN LOSS_1  0.005339311594669893   TRAIN LOSS_2  0.006589172265784756   TRAIN LOSS_3  0.007041066250247739   TRAIN LOSS_4  0.00710714901070238   TRAIN LOSS_5  0.005374418492038058   TRAIN LOSS_6  0.007566670087215179
# EPOCH  564502  | TRAIN LOSS_1  0.00533930345894513   TRAIN LOSS_2  0.006589166545762751   TRAIN LOSS_3  0.007041061631598218   TRAIN LOSS_4  0.0071071445254706255   TRAIN LOSS_5  0.005374414687992145   TRAIN LOSS_6  0.0075666442247119044
# EPOCH  564503  | TRAIN LOSS_1  0.005339295323212456   TRAIN LOSS_2  0.006589160825767386   TRAIN LOSS_3  0.007041057012933654   TRAIN LOSS_4  0.007107140040251285   TRAIN LOSS_5  0.0053744108839579524   TRAIN LOSS_6  0.0075666183625380115
# EPOCH  564504  | TRAIN LOSS_1  0.005339287187471882   TRAIN LOSS_2  0.0065891551057986626   TRAIN LOSS_3  0.0070410523942540494   TRAIN LOSS_4  0.0071071355550443565   TRAIN LOSS_5  0.005374407079935485   TRAIN LOSS_6  0.007566592500693553
# EPOCH  564505  | TRAIN LOSS_1  0.005339279051723396   TRAIN LOSS_2  0.006589149385856571   TRAIN LOSS_3  0.007041047775559398   TRAIN LOSS_4  0.0071071310698498456   TRAIN LOSS_5  0.005374403275924725   TRAIN LOSS_6  0.007566566639178566
# EPOCH  564506  | TRAIN LOSS_1  0.0053392709159669986   TRAIN LOSS_2  0.006589143665941108   TRAIN LOSS_3  0.007041043156849686   TRAIN LOSS_4  0.007107126584667749   TRAIN LOSS_5  0.005374399471925695   TRAIN LOSS_6  0.007566540777993117
# EPOCH  564507  | TRAIN LOSS_1  0.00533926278020269   TRAIN LOSS_2  0.006589137946052271   TRAIN LOSS_3  0.007041038538124915   TRAIN LOSS_4  0.007107122099498071   TRAIN LOSS_5  0.005374395667938376   TRAIN LOSS_6  0.00756651491713725
# EPOCH  564508  | TRAIN LOSS_1  0.005339254644430466   TRAIN LOSS_2  0.006589132226190046   TRAIN LOSS_3  0.0070410339193850684   TRAIN LOSS_4  0.007107117614340808   TRAIN LOSS_5  0.00537439186396278   TRAIN LOSS_6  0.007566489056611004
# EPOCH  564509  | TRAIN LOSS_1  0.005339246508650323   TRAIN LOSS_2  0.006589126506354439   TRAIN LOSS_3  0.007041029300630155   TRAIN LOSS_4  0.0071071131291959655   TRAIN LOSS_5  0.005374388059998897   TRAIN LOSS_6  0.007566463196414438
# EPOCH  564510  | TRAIN LOSS_1  0.005339238372862256   TRAIN LOSS_2  0.006589120786545427   TRAIN LOSS_3  0.007041024681860155   TRAIN LOSS_4  0.007107108644063545   TRAIN LOSS_5  0.005374384256046734   TRAIN LOSS_6  0.0075664373365476
# EPOCH  564511  | TRAIN LOSS_1  0.005339230237066275   TRAIN LOSS_2  0.006589115066763016   TRAIN LOSS_3  0.007041020063075062   TRAIN LOSS_4  0.007107104158943539   TRAIN LOSS_5  0.005374380452106289   TRAIN LOSS_6  0.00756641147701054
# EPOCH  564512  | TRAIN LOSS_1  0.005339222101262367   TRAIN LOSS_2  0.006589109347007205   TRAIN LOSS_3  0.007041015444274876   TRAIN LOSS_4  0.007107099673835959   TRAIN LOSS_5  0.005374376648177557   TRAIN LOSS_6  0.007566385617803299
# EPOCH  564513  | TRAIN LOSS_1  0.005339213965450534   TRAIN LOSS_2  0.006589103627277984   TRAIN LOSS_3  0.007041010825459584   TRAIN LOSS_4  0.007107095188740794   TRAIN LOSS_5  0.005374372844260541   TRAIN LOSS_6  0.007566359758925934
# EPOCH  564514  | TRAIN LOSS_1  0.005339205829630769   TRAIN LOSS_2  0.006589097907575339   TRAIN LOSS_3  0.007041006206629187   TRAIN LOSS_4  0.0071070907036580545   TRAIN LOSS_5  0.005374369040355245   TRAIN LOSS_6  0.007566333900378494
# EPOCH  564515  | TRAIN LOSS_1  0.005339197693803074   TRAIN LOSS_2  0.006589092187899271   TRAIN LOSS_3  0.007041001587783671   TRAIN LOSS_4  0.007107086218587741   TRAIN LOSS_5  0.00537436523646166   TRAIN LOSS_6  0.007566308042161024
# EPOCH  564516  | TRAIN LOSS_1  0.00533918955796745   TRAIN LOSS_2  0.006589086468249779   TRAIN LOSS_3  0.007040996968923038   TRAIN LOSS_4  0.007107081733529846   TRAIN LOSS_5  0.00537436143257979   TRAIN LOSS_6  0.007566282184273576
# EPOCH  564517  | TRAIN LOSS_1  0.005339181422123889   TRAIN LOSS_2  0.006589080748626857   TRAIN LOSS_3  0.00704099235004727   TRAIN LOSS_4  0.007107077248484376   TRAIN LOSS_5  0.005374357628709637   TRAIN LOSS_6  0.007566256326716197
# EPOCH  564518  | TRAIN LOSS_1  0.005339173286272386   TRAIN LOSS_2  0.0065890750290304905   TRAIN LOSS_3  0.0070409877311563675   TRAIN LOSS_4  0.0071070727634513315   TRAIN LOSS_5  0.005374353824851194   TRAIN LOSS_6  0.0075662304694889375
# EPOCH  564519  | TRAIN LOSS_1  0.0053391651504129485   TRAIN LOSS_2  0.006589069309460673   TRAIN LOSS_3  0.007040983112250324   TRAIN LOSS_4  0.007107068278430714   TRAIN LOSS_5  0.005374350021004466   TRAIN LOSS_6  0.0075662046125918375
# EPOCH  564520  | TRAIN LOSS_1  0.005339157014545569   TRAIN LOSS_2  0.006589063589917411   TRAIN LOSS_3  0.007040978493329133   TRAIN LOSS_4  0.007107063793422519   TRAIN LOSS_5  0.0053743462171694486   TRAIN LOSS_6  0.007566178756024968
# EPOCH  564521  | TRAIN LOSS_1  0.0053391488786702496   TRAIN LOSS_2  0.0065890578704006905   TRAIN LOSS_3  0.007040973874392789   TRAIN LOSS_4  0.0071070593084267535   TRAIN LOSS_5  0.005374342413346145   TRAIN LOSS_6  0.007566152899788354
# EPOCH  564522  | TRAIN LOSS_1  0.005339140742786979   TRAIN LOSS_2  0.0065890521509105095   TRAIN LOSS_3  0.007040969255441273   TRAIN LOSS_4  0.00710705482344341   TRAIN LOSS_5  0.005374338609534556   TRAIN LOSS_6  0.007566127043882056
# EPOCH  564523  | TRAIN LOSS_1  0.005339132606895762   TRAIN LOSS_2  0.006589046431446858   TRAIN LOSS_3  0.007040964636474601   TRAIN LOSS_4  0.007107050338472503   TRAIN LOSS_5  0.0053743348057346775   TRAIN LOSS_6  0.007566101188306131
# EPOCH  564524  | TRAIN LOSS_1  0.005339124470996592   TRAIN LOSS_2  0.0065890407120097385   TRAIN LOSS_3  0.007040960017492748   TRAIN LOSS_4  0.007107045853514018   TRAIN LOSS_5  0.005374331001946505   TRAIN LOSS_6  0.007566075333060609
# EPOCH  564525  | TRAIN LOSS_1  0.0053391163350894714   TRAIN LOSS_2  0.006589034992599135   TRAIN LOSS_3  0.007040955398495712   TRAIN LOSS_4  0.007107041368567965   TRAIN LOSS_5  0.005374327198170046   TRAIN LOSS_6  0.007566049478145551
# EPOCH  564526  | TRAIN LOSS_1  0.005339108199174402   TRAIN LOSS_2  0.006589029273215046   TRAIN LOSS_3  0.007040950779483492   TRAIN LOSS_4  0.007107036883634346   TRAIN LOSS_5  0.0053743233944053   TRAIN LOSS_6  0.007566023623560999
# EPOCH  564527  | TRAIN LOSS_1  0.005339100063251372   TRAIN LOSS_2  0.006589023553857471   TRAIN LOSS_3  0.007040946160456072   TRAIN LOSS_4  0.007107032398713153   TRAIN LOSS_5  0.0053743195906522595   TRAIN LOSS_6  0.00756599776930701
# EPOCH  564528  | TRAIN LOSS_1  0.005339091927320382   TRAIN LOSS_2  0.006589017834526396   TRAIN LOSS_3  0.0070409415414134525   TRAIN LOSS_4  0.007107027913804393   TRAIN LOSS_5  0.005374315786910932   TRAIN LOSS_6  0.007565971915383627
# EPOCH  564529  | TRAIN LOSS_1  0.005339083791381433   TRAIN LOSS_2  0.006589012115221823   TRAIN LOSS_3  0.00704093692235563   TRAIN LOSS_4  0.007107023428908065   TRAIN LOSS_5  0.005374311983181308   TRAIN LOSS_6  0.007565946061790898
# EPOCH  564530  | TRAIN LOSS_1  0.005339075655434516   TRAIN LOSS_2  0.006589006395943736   TRAIN LOSS_3  0.007040932303282581   TRAIN LOSS_4  0.00710701894402417   TRAIN LOSS_5  0.005374308179463399   TRAIN LOSS_6  0.00756592020852888
# EPOCH  564531  | TRAIN LOSS_1  0.005339067519479643   TRAIN LOSS_2  0.006589000676692144   TRAIN LOSS_3  0.007040927684194318   TRAIN LOSS_4  0.007107014459152709   TRAIN LOSS_5  0.005374304375757195   TRAIN LOSS_6  0.007565894355597622
# EPOCH  564532  | TRAIN LOSS_1  0.005339059383516792   TRAIN LOSS_2  0.006588994957467032   TRAIN LOSS_3  0.007040923065090829   TRAIN LOSS_4  0.007107009974293682   TRAIN LOSS_5  0.005374300572062697   TRAIN LOSS_6  0.007565868502997158
# EPOCH  564533  | TRAIN LOSS_1  0.005339051247545979   TRAIN LOSS_2  0.006588989238268391   TRAIN LOSS_3  0.0070409184459721   TRAIN LOSS_4  0.007107005489447092   TRAIN LOSS_5  0.0053742967683799115   TRAIN LOSS_6  0.007565842650727553
# EPOCH  564534  | TRAIN LOSS_1  0.005339043111567196   TRAIN LOSS_2  0.00658898351909622   TRAIN LOSS_3  0.0070409138268381355   TRAIN LOSS_4  0.007107001004612938   TRAIN LOSS_5  0.005374292964708824   TRAIN LOSS_6  0.007565816798788839
# EPOCH  564535  | TRAIN LOSS_1  0.005339034975580438   TRAIN LOSS_2  0.0065889777999505175   TRAIN LOSS_3  0.007040909207688923   TRAIN LOSS_4  0.007106996519791219   TRAIN LOSS_5  0.00537428916104945   TRAIN LOSS_6  0.007565790947181081
# EPOCH  564536  | TRAIN LOSS_1  0.005339026839585698   TRAIN LOSS_2  0.006588972080831269   TRAIN LOSS_3  0.007040904588524454   TRAIN LOSS_4  0.007106992034981941   TRAIN LOSS_5  0.005374285357401777   TRAIN LOSS_6  0.0075657650959043195
# EPOCH  564537  | TRAIN LOSS_1  0.005339018703582985   TRAIN LOSS_2  0.006588966361738472   TRAIN LOSS_3  0.007040899969344724   TRAIN LOSS_4  0.007106987550185092   TRAIN LOSS_5  0.005374281553765812   TRAIN LOSS_6  0.00756573924495861
# EPOCH  564538  | TRAIN LOSS_1  0.005339010567572296   TRAIN LOSS_2  0.006588960642672133   TRAIN LOSS_3  0.007040895350149723   TRAIN LOSS_4  0.007106983065400688   TRAIN LOSS_5  0.0053742777501415515   TRAIN LOSS_6  0.007565713394343992
# EPOCH  564539  | TRAIN LOSS_1  0.00533900243155362   TRAIN LOSS_2  0.006588954923632229   TRAIN LOSS_3  0.007040890730939452   TRAIN LOSS_4  0.007106978580628727   TRAIN LOSS_5  0.005374273946528992   TRAIN LOSS_6  0.007565687544060522
# EPOCH  564540  | TRAIN LOSS_1  0.00533899429552696   TRAIN LOSS_2  0.006588949204618758   TRAIN LOSS_3  0.007040886111713907   TRAIN LOSS_4  0.007106974095869201   TRAIN LOSS_5  0.005374270142928144   TRAIN LOSS_6  0.0075656616941082435
# EPOCH  564541  | TRAIN LOSS_1  0.005338986159492311   TRAIN LOSS_2  0.006588943485631724   TRAIN LOSS_3  0.0070408814924730655   TRAIN LOSS_4  0.007106969611122114   TRAIN LOSS_5  0.005374266339338993   TRAIN LOSS_6  0.007565635844487201
# EPOCH  564542  | TRAIN LOSS_1  0.005338978023449677   TRAIN LOSS_2  0.006588937766671111   TRAIN LOSS_3  0.007040876873216934   TRAIN LOSS_4  0.0071069651263874715   TRAIN LOSS_5  0.005374262535761551   TRAIN LOSS_6  0.007565609995197455
# EPOCH  564543  | TRAIN LOSS_1  0.005338969887399052   TRAIN LOSS_2  0.006588932047736917   TRAIN LOSS_3  0.007040872253945496   TRAIN LOSS_4  0.007106960641665274   TRAIN LOSS_5  0.0053742587321958   TRAIN LOSS_6  0.00756558414623905
# EPOCH  564544  | TRAIN LOSS_1  0.005338961751340434   TRAIN LOSS_2  0.006588926328829137   TRAIN LOSS_3  0.007040867634658757   TRAIN LOSS_4  0.007106956156955516   TRAIN LOSS_5  0.005374254928641762   TRAIN LOSS_6  0.007565558297612033
# EPOCH  564545  | TRAIN LOSS_1  0.005338953615273819   TRAIN LOSS_2  0.006588920609947768   TRAIN LOSS_3  0.007040863015356704   TRAIN LOSS_4  0.007106951672258202   TRAIN LOSS_5  0.005374251125099425   TRAIN LOSS_6  0.00756553244931645
# EPOCH  564546  | TRAIN LOSS_1  0.005338945479199207   TRAIN LOSS_2  0.006588914891092796   TRAIN LOSS_3  0.007040858396039326   TRAIN LOSS_4  0.007106947187573329   TRAIN LOSS_5  0.005374247321568784   TRAIN LOSS_6  0.007565506601352351
# EPOCH  564547  | TRAIN LOSS_1  0.005338937343116595   TRAIN LOSS_2  0.006588909172264224   TRAIN LOSS_3  0.0070408537767066275   TRAIN LOSS_4  0.007106942702900909   TRAIN LOSS_5  0.005374243518049852   TRAIN LOSS_6  0.007565480753719791
# EPOCH  564548  | TRAIN LOSS_1  0.0053389292070259815   TRAIN LOSS_2  0.006588903453462042   TRAIN LOSS_3  0.007040849157358592   TRAIN LOSS_4  0.007106938218240926   TRAIN LOSS_5  0.005374239714542612   TRAIN LOSS_6  0.007565454906418812
# EPOCH  564549  | TRAIN LOSS_1  0.00533892107092737   TRAIN LOSS_2  0.006588897734686244   TRAIN LOSS_3  0.0070408445379952144   TRAIN LOSS_4  0.007106933733593392   TRAIN LOSS_5  0.005374235911047075   TRAIN LOSS_6  0.007565429059449462
# EPOCH  564550  | TRAIN LOSS_1  0.005338912934820748   TRAIN LOSS_2  0.0065888920159368255   TRAIN LOSS_3  0.007040839918616495   TRAIN LOSS_4  0.0071069292489583085   TRAIN LOSS_5  0.005374232107563241   TRAIN LOSS_6  0.007565403212811795
# EPOCH  564551  | TRAIN LOSS_1  0.0053389047987061206   TRAIN LOSS_2  0.006588886297213783   TRAIN LOSS_3  0.007040835299222424   TRAIN LOSS_4  0.007106924764335666   TRAIN LOSS_5  0.005374228304091103   TRAIN LOSS_6  0.007565377366505853
# EPOCH  564552  | TRAIN LOSS_1  0.005338896662583484   TRAIN LOSS_2  0.006588880578517113   TRAIN LOSS_3  0.007040830679812984   TRAIN LOSS_4  0.007106920279725481   TRAIN LOSS_5  0.005374224500630667   TRAIN LOSS_6  0.00756535152053169
# EPOCH  564553  | TRAIN LOSS_1  0.005338888526452828   TRAIN LOSS_2  0.006588874859846798   TRAIN LOSS_3  0.007040826060388184   TRAIN LOSS_4  0.007106915795127737   TRAIN LOSS_5  0.005374220697181923   TRAIN LOSS_6  0.0075653256748893505
# EPOCH  564554  | TRAIN LOSS_1  0.005338880390314166   TRAIN LOSS_2  0.006588869141202839   TRAIN LOSS_3  0.007040821440948009   TRAIN LOSS_4  0.007106911310542449   TRAIN LOSS_5  0.005374216893744881   TRAIN LOSS_6  0.007565299829578883
# EPOCH  564555  | TRAIN LOSS_1  0.005338872254167484   TRAIN LOSS_2  0.006588863422585235   TRAIN LOSS_3  0.007040816821492452   TRAIN LOSS_4  0.007106906825969607   TRAIN LOSS_5  0.0053742130903195314   TRAIN LOSS_6  0.007565273984600345
# EPOCH  564556  | TRAIN LOSS_1  0.0053388641180127875   TRAIN LOSS_2  0.006588857703993973   TRAIN LOSS_3  0.007040812202021514   TRAIN LOSS_4  0.007106902341409217   TRAIN LOSS_5  0.005374209286905885   TRAIN LOSS_6  0.0075652481399537735
# EPOCH  564557  | TRAIN LOSS_1  0.005338855981850068   TRAIN LOSS_2  0.006588851985429057   TRAIN LOSS_3  0.007040807582535178   TRAIN LOSS_4  0.007106897856861277   TRAIN LOSS_5  0.005374205483503935   TRAIN LOSS_6  0.00756522229563922
# EPOCH  564558  | TRAIN LOSS_1  0.005338847845679326   TRAIN LOSS_2  0.006588846266890471   TRAIN LOSS_3  0.007040802963033448   TRAIN LOSS_4  0.007106893372325795   TRAIN LOSS_5  0.005374201680113677   TRAIN LOSS_6  0.007565196451656741
# EPOCH  564559  | TRAIN LOSS_1  0.005338839709500559   TRAIN LOSS_2  0.006588840548378212   TRAIN LOSS_3  0.0070407983435163074   TRAIN LOSS_4  0.007106888887802763   TRAIN LOSS_5  0.005374197876735113   TRAIN LOSS_6  0.0075651706080063765
# EPOCH  564560  | TRAIN LOSS_1  0.0053388315733137685   TRAIN LOSS_2  0.00658883482989228   TRAIN LOSS_3  0.007040793723983755   TRAIN LOSS_4  0.00710688440329219   TRAIN LOSS_5  0.005374194073368253   TRAIN LOSS_6  0.007565144764688171

# %%
i = range(n_epoch)
plt.plot(i, Loss_1)
plt.plot(i, Loss_2)
plt.plot(i, Loss_3)
plt.plot(i, Loss_4)
plt.plot(i, Loss_5)
plt.plot(i, Loss_6)
plt.legend(['Network_1', 'Network_2', 'Network_3', 'Network_4', 'Network_5', 'Network_6'])
plt.xlabel('epoch')
plt.ylabel('Mean squared error(tanh)')
plt.yscale("log")
plt.show()

# %%
i = range(n_epoch)
plt.plot(i, Loss_1)
plt.plot(i, Loss_2)
plt.plot(i, Loss_3)
plt.plot(i, Loss_4)
plt.plot(i, Loss_5)
plt.plot(i, Loss_6)
plt.legend(['Network_1', 'Network_2', 'Network_3', 'Network_4', 'Network_5', 'Network_6'])
plt.xlabel('epoch')
plt.ylabel('Mean squared error(tanh)')
#plt.yscale("log")
plt.ylim(0.001,0.008)
plt.show()

# %%
#出力が定義されたSLと等しいかの確認
print('レプリカ1の出力と正解のオーバーラップ',spin_overlap(np.sign(y_1[0]),SL))
print('レプリカ2の出力と正解のオーバーラップ',spin_overlap(np.sign(y_2[0]),SL))
print('レプリカ3の出力と正解のオーバーラップ',spin_overlap(np.sign(y_3[0]),SL))
print('レプリカ4の出力と正解のオーバーラップ',spin_overlap(np.sign(y_4[0]),SL))
print('レプリカ5の出力と正解のオーバーラップ',spin_overlap(np.sign(y_5[0]),SL))
print('レプリカ6の出力と正解のオーバーラップ',spin_overlap(np.sign(y_6[0]),SL))
# Out:
# レプリカ1の出力と正解のオーバーラップ 1.0
# レプリカ2の出力と正解のオーバーラップ 1.0
# レプリカ3の出力と正解のオーバーラップ 1.0
# レプリカ4の出力と正解のオーバーラップ 1.0
# レプリカ5の出力と正解のオーバーラップ 1.0
# レプリカ6の出力と正解のオーバーラップ 1.0

# %%
#オーダーパラメータ
#レプリカ1と2
q_12_S0 = spin_overlap(S0,S0)
q_12_S1 = spin_overlap(y_1[1],y_2[1])
q_12_S2 = spin_overlap(y_1[2],y_2[2])
q_12_S3 = spin_overlap(y_1[3],y_2[3])
q_12_S4 = spin_overlap(y_1[4],y_2[4])
q_12_SL = spin_overlap(SL,SL)

Q_12_1 = bond_overlap(w_1[0],w_2[0])
Q_12_2 = bond_overlap(w_1[1],w_2[1])
Q_12_3 = bond_overlap(w_1[2],w_2[2])
Q_12_4 = bond_overlap(w_1[3],w_2[3])
Q_12_5 = bond_overlap(w_1[4],w_2[4])

#レプリカ1と3
q_13_S0 = spin_overlap(S0,S0)
q_13_S1 = spin_overlap(y_1[1],y_3[1])
q_13_S2 = spin_overlap(y_1[2],y_3[2])
q_13_S3 = spin_overlap(y_1[3],y_3[3])
q_13_S4 = spin_overlap(y_1[4],y_3[4])
q_13_SL = spin_overlap(SL,SL)

Q_13_1 = bond_overlap(w_1[0],w_3[0])
Q_13_2 = bond_overlap(w_1[1],w_3[1])
Q_13_3 = bond_overlap(w_1[2],w_3[2])
Q_13_4 = bond_overlap(w_1[3],w_3[3])
Q_13_5 = bond_overlap(w_1[4],w_3[4])

#レプリカ1と4
q_14_S0 = spin_overlap(S0,S0)
q_14_S1 = spin_overlap(y_1[1],y_4[1])
q_14_S2 = spin_overlap(y_1[2],y_4[2])
q_14_S3 = spin_overlap(y_1[3],y_4[3])
q_14_S4 = spin_overlap(y_1[4],y_4[4])
q_14_SL = spin_overlap(SL,SL)

Q_14_1 = bond_overlap(w_1[0],w_4[0])
Q_14_2 = bond_overlap(w_1[1],w_4[1])
Q_14_3 = bond_overlap(w_1[2],w_4[2])
Q_14_4 = bond_overlap(w_1[3],w_4[3])
Q_14_5 = bond_overlap(w_1[4],w_4[4])

#レプリカ1と5
q_15_S0 = spin_overlap(S0,S0)
q_15_S1 = spin_overlap(y_1[1],y_5[1])
q_15_S2 = spin_overlap(y_1[2],y_5[2])
q_15_S3 = spin_overlap(y_1[3],y_5[3])
q_15_S4 = spin_overlap(y_1[4],y_5[4])
q_15_SL = spin_overlap(SL,SL)

Q_15_1 = bond_overlap(w_1[0],w_5[0])
Q_15_2 = bond_overlap(w_1[1],w_5[1])
Q_15_3 = bond_overlap(w_1[2],w_5[2])
Q_15_4 = bond_overlap(w_1[3],w_5[3])
Q_15_5 = bond_overlap(w_1[4],w_5[4])

#レプリカ1と6
q_16_S0 = spin_overlap(S0,S0)
q_16_S1 = spin_overlap(y_1[1],y_6[1])
q_16_S2 = spin_overlap(y_1[2],y_6[2])
q_16_S3 = spin_overlap(y_1[3],y_6[3])
q_16_S4 = spin_overlap(y_1[4],y_6[4])
q_16_SL = spin_overlap(SL,SL)

Q_16_1 = bond_overlap(w_1[0],w_6[0])
Q_16_2 = bond_overlap(w_1[1],w_6[1])
Q_16_3 = bond_overlap(w_1[2],w_6[2])
Q_16_4 = bond_overlap(w_1[3],w_6[3])
Q_16_5 = bond_overlap(w_1[4],w_6[4])

#レプリカ2と3
q_23_S0 = spin_overlap(S0,S0)
q_23_S1 = spin_overlap(y_2[1],y_5[1])
q_23_S2 = spin_overlap(y_2[2],y_5[2])
q_23_S3 = spin_overlap(y_2[3],y_5[3])
q_23_S4 = spin_overlap(y_2[4],y_5[4])
q_23_SL = spin_overlap(SL,SL)

Q_23_1 = bond_overlap(w_2[0],w_3[0])
Q_23_2 = bond_overlap(w_2[1],w_3[1])
Q_23_3 = bond_overlap(w_2[2],w_3[2])
Q_23_4 = bond_overlap(w_2[3],w_3[3])
Q_23_5 = bond_overlap(w_2[4],w_3[4])

#レプリカ2と4
q_24_S0 = spin_overlap(S0,S0)
q_24_S1 = spin_overlap(y_2[1],y_4[1])
q_24_S2 = spin_overlap(y_2[2],y_4[2])
q_24_S3 = spin_overlap(y_2[3],y_4[3])
q_24_S4 = spin_overlap(y_2[4],y_4[4])
q_24_SL = spin_overlap(SL,SL)

Q_24_1 = bond_overlap(w_2[0],w_4[0])
Q_24_2 = bond_overlap(w_2[1],w_4[1])
Q_24_3 = bond_overlap(w_2[2],w_4[2])
Q_24_4 = bond_overlap(w_2[3],w_4[3])
Q_24_5 = bond_overlap(w_2[4],w_4[4])

#レプリカ2と5
q_25_S0 = spin_overlap(S0,S0)
q_25_S1 = spin_overlap(y_2[1],y_5[1])
q_25_S2 = spin_overlap(y_2[2],y_5[2])
q_25_S3 = spin_overlap(y_2[3],y_5[3])
q_25_S4 = spin_overlap(y_2[4],y_5[4])
q_25_SL = spin_overlap(SL,SL)

Q_25_1 = bond_overlap(w_2[0],w_5[0])
Q_25_2 = bond_overlap(w_2[1],w_5[1])
Q_25_3 = bond_overlap(w_2[2],w_5[2])
Q_25_4 = bond_overlap(w_2[3],w_5[3])
Q_25_5 = bond_overlap(w_2[4],w_5[4])

#レプリカ2と6
q_26_S0 = spin_overlap(S0,S0)
q_26_S1 = spin_overlap(y_2[1],y_6[1])
q_26_S2 = spin_overlap(y_2[2],y_6[2])
q_26_S3 = spin_overlap(y_2[3],y_6[3])
q_26_S4 = spin_overlap(y_2[4],y_6[4])
q_26_SL = spin_overlap(SL,SL)

Q_26_1 = bond_overlap(w_2[0],w_6[0])
Q_26_2 = bond_overlap(w_2[1],w_6[1])
Q_26_3 = bond_overlap(w_2[2],w_6[2])
Q_26_4 = bond_overlap(w_2[3],w_6[3])
Q_26_5 = bond_overlap(w_2[4],w_6[4])

#レプリカ3と4
q_34_S0 = spin_overlap(S0,S0)
q_34_S1 = spin_overlap(y_3[1],y_4[1])
q_34_S2 = spin_overlap(y_3[2],y_4[2])
q_34_S3 = spin_overlap(y_3[3],y_4[3])
q_34_S4 = spin_overlap(y_3[4],y_4[4])
q_34_SL = spin_overlap(SL,SL)

Q_34_1 = bond_overlap(w_3[0],w_4[0])
Q_34_2 = bond_overlap(w_3[1],w_4[1])
Q_34_3 = bond_overlap(w_3[2],w_4[2])
Q_34_4 = bond_overlap(w_3[3],w_4[3])
Q_34_5 = bond_overlap(w_3[4],w_4[4])

#レプリカ3と5
q_35_S0 = spin_overlap(S0,S0)
q_35_S1 = spin_overlap(y_3[1],y_5[1])
q_35_S2 = spin_overlap(y_3[2],y_5[2])
q_35_S3 = spin_overlap(y_3[3],y_5[3])
q_35_S4 = spin_overlap(y_3[4],y_5[4])
q_35_SL = spin_overlap(SL,SL)

Q_35_1 = bond_overlap(w_3[0],w_5[0])
Q_35_2 = bond_overlap(w_3[1],w_5[1])
Q_35_3 = bond_overlap(w_3[2],w_5[2])
Q_35_4 = bond_overlap(w_3[3],w_5[3])
Q_35_5 = bond_overlap(w_3[4],w_5[4])

#レプリカ3と6
q_36_S0 = spin_overlap(S0,S0)
q_36_S1 = spin_overlap(y_3[1],y_6[1])
q_36_S2 = spin_overlap(y_3[2],y_6[2])
q_36_S3 = spin_overlap(y_3[3],y_6[3])
q_36_S4 = spin_overlap(y_3[4],y_6[4])
q_36_SL = spin_overlap(SL,SL)

Q_36_1 = bond_overlap(w_3[0],w_6[0])
Q_36_2 = bond_overlap(w_3[1],w_6[1])
Q_36_3 = bond_overlap(w_3[2],w_6[2])
Q_36_4 = bond_overlap(w_3[3],w_6[3])
Q_36_5 = bond_overlap(w_3[4],w_6[4])

#レプリカ4と5
q_45_S0 = spin_overlap(S0,S0)
q_45_S1 = spin_overlap(y_4[1],y_5[1])
q_45_S2 = spin_overlap(y_4[2],y_5[2])
q_45_S3 = spin_overlap(y_4[3],y_5[3])
q_45_S4 = spin_overlap(y_4[4],y_5[4])
q_45_SL = spin_overlap(SL,SL)

Q_45_1 = bond_overlap(w_4[0],w_5[0])
Q_45_2 = bond_overlap(w_4[1],w_5[1])
Q_45_3 = bond_overlap(w_4[2],w_5[2])
Q_45_4 = bond_overlap(w_4[3],w_5[3])
Q_45_5 = bond_overlap(w_4[4],w_5[4])

#レプリカ4と6
q_46_S0 = spin_overlap(S0,S0)
q_46_S1 = spin_overlap(y_4[1],y_6[1])
q_46_S2 = spin_overlap(y_4[2],y_6[2])
q_46_S3 = spin_overlap(y_4[3],y_6[3])
q_46_S4 = spin_overlap(y_4[4],y_6[4])
q_46_SL = spin_overlap(SL,SL)

Q_46_1 = bond_overlap(w_4[0],w_6[0])
Q_46_2 = bond_overlap(w_4[1],w_6[1])
Q_46_3 = bond_overlap(w_4[2],w_6[2])
Q_46_4 = bond_overlap(w_4[3],w_6[3])
Q_46_5 = bond_overlap(w_4[4],w_6[4])

#レプリカ5と6
q_56_S0 = spin_overlap(S0,S0)
q_56_S1 = spin_overlap(y_5[1],y_6[1])
q_56_S2 = spin_overlap(y_5[2],y_6[2])
q_56_S3 = spin_overlap(y_5[3],y_6[3])
q_56_S4 = spin_overlap(y_5[4],y_6[4])
q_56_SL = spin_overlap(SL,SL)

Q_56_1 = bond_overlap(w_5[0],w_6[0])
Q_56_2 = bond_overlap(w_5[1],w_6[1])
Q_56_3 = bond_overlap(w_5[2],w_6[2])
Q_56_4 = bond_overlap(w_5[3],w_6[3])
Q_56_5 = bond_overlap(w_5[4],w_6[4])

# %%
q_12 = np.array([q_12_S0, q_12_S1, q_12_S2,
     q_12_S3, q_12_S4, q_12_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_12)
plt.xlabel('Layer')
plt.ylabel('q_12')
plt.show()
print(q_12)
# Out:
# [1.         0.08666667 0.1        0.02666667 0.09333333 1.        ]

# %%
q_13 = np.array([q_13_S0, q_13_S1, q_13_S2,
     q_13_S3, q_13_S4, q_13_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_13)
plt.xlabel('Layer')
plt.ylabel('q_13')
plt.show()
print(q_13)
# Out:
# [1.         0.06666667 0.02666667 0.06       0.04666667 1.        ]

# %%
q_14 = np.array([q_14_S0, q_14_S1, q_14_S2,
     q_14_S3, q_14_S4, q_14_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_14)
plt.xlabel('Layer')
plt.ylabel('q_14')
plt.show()
print(q_14)
# Out:
# [1.         0.02       0.08       0.08666667 0.03333333 1.        ]

# %%
q_15 = np.array([q_15_S0, q_15_S1, q_15_S2,
     q_15_S3, q_15_S4, q_15_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_15)
plt.xlabel('Layer')
plt.ylabel('q_15')
plt.show()
print(q_15)
# Out:
# [1.         0.06       0.14666667 0.15333333 0.04       1.        ]

# %%
q_16 = np.array([q_16_S0, q_16_S1, q_16_S2,
     q_16_S3, q_16_S4, q_16_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_16)
plt.xlabel('Layer')
plt.ylabel('q_16')
plt.show()
print(q_16)
# Out:
# [1.         0.04666667 0.02       0.         0.04666667 1.        ]

# %%
q_23 = np.array([q_23_S0, q_23_S1, q_23_S2,
     q_23_S3, q_23_S4, q_23_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_23)
plt.xlabel('Layer')
plt.ylabel('q_23')
plt.show()
print(q_23)
# Out:
# [1.         0.05333333 0.06       0.12666667 0.10666667 1.        ]

# %%
q_24 = np.array([q_24_S0, q_24_S1, q_24_S2,
     q_24_S3, q_24_S4, q_24_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_24)
plt.xlabel('Layer')
plt.ylabel('q_24')
plt.show()
print(q_24)
# Out:
# [1.         0.05333333 0.00666667 0.00666667 0.1        1.        ]

# %%
q_25 = np.array([q_25_S0, q_25_S1, q_25_S2,
     q_25_S3, q_25_S4, q_25_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_25)
plt.xlabel('Layer')
plt.ylabel('q_25')
plt.show()
print(q_25)
# Out:
# [1.         0.05333333 0.06       0.12666667 0.10666667 1.        ]

# %%
q_26 = np.array([q_26_S0, q_26_S1, q_26_S2,
     q_26_S3, q_26_S4, q_26_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_26)
plt.xlabel('Layer')
plt.ylabel('q_26')
plt.show()
print(q_26)
# Out:
# [1.         0.04       0.21333333 0.06666667 0.03333333 1.        ]

# %%
q_34 = np.array([q_34_S0, q_34_S1, q_34_S2,
     q_34_S3, q_34_S4, q_34_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_34)
plt.xlabel('Layer')
plt.ylabel('q_34')
plt.show()
print(q_34)
# Out:
# [1.         0.07333333 0.05333333 0.01333333 0.         1.        ]

# %%
q_35 = np.array([q_35_S0, q_35_S1, q_35_S2,
     q_35_S3, q_35_S4, q_35_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_35)
plt.xlabel('Layer')
plt.ylabel('q_35')
plt.show()
print(q_35)
# Out:
# [1.         0.00666667 0.02666667 0.04       0.02       1.        ]

# %%
q_36 = np.array([q_36_S0, q_36_S1, q_36_S2,
     q_36_S3, q_36_S4, q_36_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_36)
plt.xlabel('Layer')
plt.ylabel('q_36')
plt.show()
print(q_36)
# Out:
# [1.         0.04666667 0.14       0.11333333 0.01333333 1.        ]

# %%
q_45 = np.array([q_45_S0, q_45_S1, q_45_S2,
     q_45_S3, q_45_S4, q_45_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_45)
plt.xlabel('Layer')
plt.ylabel('q_45')
plt.show()
print(q_45)
# Out:
# [1.         0.01333333 0.         0.13333333 0.02       1.        ]

# %%
q_46 = np.array([q_46_S0, q_46_S1, q_46_S2,
     q_46_S3, q_46_S4, q_46_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_46)
plt.xlabel('Layer')
plt.ylabel('q_46')
plt.show()
print(q_46)
# Out:
# [1.         0.01333333 0.00666667 0.11333333 0.14666667 1.        ]

# %%
q_56 = np.array([q_56_S0, q_56_S1, q_56_S2,
     q_56_S3, q_56_S4, q_56_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_56)
plt.xlabel('Layer')
plt.ylabel('q_56')
plt.show()
print(q_56)
# Out:
# [1.         0.02666667 0.02       0.07333333 0.03333333 1.        ]

# %%
Q_12 = np.array([Q_12_1, Q_12_2, Q_12_3,
     Q_12_4, Q_12_5])
i = [1,2,3,4,5]
plt.plot(i, Q_12)
plt.xlabel('Layer')
plt.ylabel('Q_12')
plt.show()
print(Q_12)
# Out:
# [0.06617694 0.23129633 0.04879238 0.01955232 0.01429602]

# %%
Q_13 = np.array([Q_13_1, Q_13_2, Q_13_3,
     Q_13_4, Q_13_5])
i = [1,2,3,4,5]
plt.plot(i, Q_13)
plt.xlabel('Layer')
plt.ylabel('Q_13')
plt.show()
print(Q_13)
# Out:
# [0.04269577 0.00297485 0.04315523 0.0329222  0.08717303]

# %%
Q_14 = np.array([Q_14_1, Q_14_2, Q_14_3,
     Q_14_4, Q_14_5])
i = [1,2,3,4,5]
plt.plot(i, Q_14)
plt.xlabel('Layer')
plt.ylabel('Q_14')
plt.show()
print(Q_14)
# Out:
# [0.09920239 0.02252919 0.20092393 0.23104201 0.00570652]

# %%
Q_15 = np.array([Q_15_1, Q_15_2, Q_15_3,
     Q_15_4, Q_15_5])
i = [1,2,3,4,5]
plt.plot(i, Q_15)
plt.xlabel('Layer')
plt.ylabel('Q_15')
plt.show()
print(Q_15)
# Out:
# [0.05572086 0.00253261 0.15240048 0.04018854 0.08501701]

# %%
Q_16 = np.array([Q_16_1, Q_16_2, Q_16_3,
     Q_16_4, Q_16_5])
i = [1,2,3,4,5]
plt.plot(i, Q_16)
plt.xlabel('Layer')
plt.ylabel('Q_16')
plt.show()
print(Q_16)
# Out:
# [0.03166537 0.04255603 0.02429219 0.11976283 0.07892692]

# %%
Q_23 = np.array([Q_23_1, Q_23_2, Q_23_3,
     Q_23_4, Q_23_5])
i = [1,2,3,4,5]
plt.plot(i, Q_23)
plt.xlabel('Layer')
plt.ylabel('Q_23')
plt.show()
print(Q_23)
# Out:
# [0.12897685 0.0009553  0.0069201  0.04338809 0.19763519]

# %%
Q_24 = np.array([Q_24_1, Q_24_2, Q_24_3,
     Q_24_4, Q_24_5])
i = [1,2,3,4,5]
plt.plot(i, Q_24)
plt.xlabel('Layer')
plt.ylabel('Q_24')
plt.show()
print(Q_24)
# Out:
# [0.15849802 0.12037248 0.08659961 0.07007181 0.10107246]

# %%
Q_25 = np.array([Q_25_1, Q_25_2, Q_25_3,
     Q_25_4, Q_25_5])
i = [1,2,3,4,5]
plt.plot(i, Q_25)
plt.xlabel('Layer')
plt.ylabel('Q_25')
plt.show()
print(Q_25)
# Out:
# [0.08005245 0.03445401 0.06579017 0.00734418 0.16353233]

# %%
Q_26 = np.array([Q_26_1, Q_26_2, Q_26_3,
     Q_26_4, Q_26_5])
i = [1,2,3,4,5]
plt.plot(i, Q_26)
plt.xlabel('Layer')
plt.ylabel('Q_26')
plt.show()
print(Q_26)
# Out:
# [0.04494566 0.23103203 0.19693626 0.00231334 0.03719066]

# %%
Q_34 = np.array([Q_34_1, Q_34_2, Q_34_3,
     Q_34_4, Q_34_5])
i = [1,2,3,4,5]
plt.plot(i, Q_34)
plt.xlabel('Layer')
plt.ylabel('Q_34')
plt.show()
print(Q_34)
# Out:
# [0.05497776 0.00737374 0.04091991 0.03675542 0.09822255]

# %%
Q_35 = np.array([Q_35_1, Q_35_2, Q_35_3,
     Q_35_4, Q_35_5])
i = [1,2,3,4,5]
plt.plot(i, Q_35)
plt.xlabel('Layer')
plt.ylabel('Q_35')
plt.show()
print(Q_35)
# Out:
# [0.00552794 0.04240723 0.06874019 0.0250031  0.0257061 ]

# %%
Q_36 = np.array([Q_36_1, Q_36_2, Q_36_3,
     Q_36_4, Q_36_5])
i = [1,2,3,4,5]
plt.plot(i, Q_36)
plt.xlabel('Layer')
plt.ylabel('Q_36')
plt.show()
print(Q_36)
# Out:
# [0.0237996  0.12536709 0.00343276 0.0290179  0.02619305]

# %%
Q_45 = np.array([Q_45_1, Q_45_2, Q_45_3,
     Q_45_4, Q_45_5])
i = [1,2,3,4,5]
plt.plot(i, Q_45)
plt.xlabel('Layer')
plt.ylabel('Q_45')
plt.show()
print(Q_45)
# Out:
# [0.11741994 0.2219718  0.14377269 0.15865516 0.04392492]

# %%
Q_46 = np.array([Q_46_1, Q_46_2, Q_46_3,
     Q_46_4, Q_46_5])
i = [1,2,3,4,5]
plt.plot(i, Q_46)
plt.xlabel('Layer')
plt.ylabel('Q_46')
plt.show()
print(Q_46)
# Out:
# [0.00929039 0.11135552 0.01628506 0.06088678 0.08774835]

# %%
Q_56 = np.array([Q_56_1, Q_56_2, Q_56_3,
     Q_56_4, Q_56_5])
i = [1,2,3,4,5]
plt.plot(i, Q_56)
plt.xlabel('Layer')
plt.ylabel('Q_56')
plt.show()
print(Q_56)
# Out:
# [0.11523719 0.08923959 0.03176776 0.04564427 0.07304119]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_12)
plt.xlabel('Layer')
plt.ylabel('q_12')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_12)
plt.xlabel('Layer')
plt.ylabel('Q_12')

plt.legend(['spin','bond'])
plt.show()

print('q_12 ',q_12)
print('Q_12 ',Q_12)
# Out:
# q_12  [1.         0.08666667 0.1        0.02666667 0.09333333 1.        ]
# Q_12  [0.06617694 0.23129633 0.04879238 0.01955232 0.01429602]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_12)
plt.xlabel('Layer')
plt.ylabel('q_12')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_12)
plt.xlabel('Layer')
plt.ylabel('Q_12')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_13)
plt.xlabel('Layer')
plt.ylabel('q_13')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_13)
plt.xlabel('Layer')
plt.ylabel('Q_13')

plt.legend(['spin','bond'])
plt.show()

print('q_13 ',q_13)
print('Q_13 ',Q_13)
# Out:
# q_13  [1.         0.06666667 0.02666667 0.06       0.04666667 1.        ]
# Q_13  [0.04269577 0.00297485 0.04315523 0.0329222  0.08717303]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_13)
plt.xlabel('Layer')
plt.ylabel('q_13')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_13)
plt.xlabel('Layer')
plt.ylabel('Q_13')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_14)
plt.xlabel('Layer')
plt.ylabel('q_14')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_14)
plt.xlabel('Layer')
plt.ylabel('Q_14')

plt.legend(['spin','bond'])
plt.show()

print('q_14 ',q_14)
print('Q_14 ',Q_14)
# Out:
# q_14  [1.         0.02       0.08       0.08666667 0.03333333 1.        ]
# Q_14  [0.09920239 0.02252919 0.20092393 0.23104201 0.00570652]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_14)
plt.xlabel('Layer')
plt.ylabel('q_14')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_14)
plt.xlabel('Layer')
plt.ylabel('Q_14')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_15)
plt.xlabel('Layer')
plt.ylabel('q_15')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_15)
plt.xlabel('Layer')
plt.ylabel('Q_15')

plt.legend(['spin','bond'])
plt.show()

print('q_15 ',q_15)
print('Q_15 ',Q_15)
# Out:
# q_15  [1.         0.06       0.14666667 0.15333333 0.04       1.        ]
# Q_15  [0.05572086 0.00253261 0.15240048 0.04018854 0.08501701]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_15)
plt.xlabel('Layer')
plt.ylabel('q_15')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_15)
plt.xlabel('Layer')
plt.ylabel('Q_15')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_16)
plt.xlabel('Layer')
plt.ylabel('q_16')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_16)
plt.xlabel('Layer')
plt.ylabel('Q_16')

plt.legend(['spin','bond'])
plt.show()

print('q_16 ',q_16)
print('Q_16 ',Q_16)
# Out:
# q_16  [1.         0.04666667 0.02       0.         0.04666667 1.        ]
# Q_16  [0.03166537 0.04255603 0.02429219 0.11976283 0.07892692]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_16)
plt.xlabel('Layer')
plt.ylabel('q_16')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_16)
plt.xlabel('Layer')
plt.ylabel('Q_16')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_23)
plt.xlabel('Layer')
plt.ylabel('q_23')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_23)
plt.xlabel('Layer')
plt.ylabel('Q_23')

plt.legend(['spin','bond'])
plt.show()

print('q_23 ',q_23)
print('Q_23 ',Q_23)
# Out:
# q_23  [1.         0.05333333 0.06       0.12666667 0.10666667 1.        ]
# Q_23  [0.12897685 0.0009553  0.0069201  0.04338809 0.19763519]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_23)
plt.xlabel('Layer')
plt.ylabel('q_23')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_23)
plt.xlabel('Layer')
plt.ylabel('Q_23')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_24)
plt.xlabel('Layer')
plt.ylabel('q_24')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_24)
plt.xlabel('Layer')
plt.ylabel('Q_24')

plt.legend(['spin','bond'])
plt.show()

print('q_24 ',q_24)
print('Q_24 ',Q_24)
# Out:
# q_24  [1.         0.05333333 0.00666667 0.00666667 0.1        1.        ]
# Q_24  [0.15849802 0.12037248 0.08659961 0.07007181 0.10107246]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_24)
plt.xlabel('Layer')
plt.ylabel('q_24')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_24)
plt.xlabel('Layer')
plt.ylabel('Q_24')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_25)
plt.xlabel('Layer')
plt.ylabel('q_25')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_25)
plt.xlabel('Layer')
plt.ylabel('Q_25')

plt.legend(['spin','bond'])
plt.show()

print('q_25 ',q_25)
print('Q_25 ',Q_25)
# Out:
# q_25  [1.         0.05333333 0.06       0.12666667 0.10666667 1.        ]
# Q_25  [0.08005245 0.03445401 0.06579017 0.00734418 0.16353233]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_25)
plt.xlabel('Layer')
plt.ylabel('q_25')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_25)
plt.xlabel('Layer')
plt.ylabel('Q_25')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_26)
plt.xlabel('Layer')
plt.ylabel('q_26')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_26)
plt.xlabel('Layer')
plt.ylabel('Q_26')

plt.legend(['spin','bond'])
plt.show()

print('q_26 ',q_26)
print('Q_26 ',Q_26)
# Out:
# q_26  [1.         0.04       0.21333333 0.06666667 0.03333333 1.        ]
# Q_26  [0.04494566 0.23103203 0.19693626 0.00231334 0.03719066]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_26)
plt.xlabel('Layer')
plt.ylabel('q_26')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_26)
plt.xlabel('Layer')
plt.ylabel('Q_26')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_34)
plt.xlabel('Layer')
plt.ylabel('q_34')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_34)
plt.xlabel('Layer')
plt.ylabel('Q_34')

plt.legend(['spin','bond'])
plt.show()

print('q_34 ',q_34)
print('Q_34 ',Q_34)
# Out:
# q_34  [1.         0.07333333 0.05333333 0.01333333 0.         1.        ]
# Q_34  [0.05497776 0.00737374 0.04091991 0.03675542 0.09822255]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_34)
plt.xlabel('Layer')
plt.ylabel('q_34')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_34)
plt.xlabel('Layer')
plt.ylabel('Q_34')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_35)
plt.xlabel('Layer')
plt.ylabel('q_35')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_35)
plt.xlabel('Layer')
plt.ylabel('Q_35')

plt.legend(['spin','bond'])
plt.show()

print('q_35 ',q_35)
print('Q_35 ',Q_35)
# Out:
# q_35  [1.         0.00666667 0.02666667 0.04       0.02       1.        ]
# Q_35  [0.00552794 0.04240723 0.06874019 0.0250031  0.0257061 ]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_35)
plt.xlabel('Layer')
plt.ylabel('q_35')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_35)
plt.xlabel('Layer')
plt.ylabel('Q_35')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_36)
plt.xlabel('Layer')
plt.ylabel('q_36')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_36)
plt.xlabel('Layer')
plt.ylabel('Q_36')

plt.legend(['spin','bond'])
plt.show()

print('q_36 ',q_36)
print('Q_36 ',Q_36)
# Out:
# q_36  [1.         0.04666667 0.14       0.11333333 0.01333333 1.        ]
# Q_36  [0.0237996  0.12536709 0.00343276 0.0290179  0.02619305]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_36)
plt.xlabel('Layer')
plt.ylabel('q_36')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_36)
plt.xlabel('Layer')
plt.ylabel('Q_36')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_45)
plt.xlabel('Layer')
plt.ylabel('q_45')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_45)
plt.xlabel('Layer')
plt.ylabel('Q_45')

plt.legend(['spin','bond'])
plt.show()

print('q_45 ',q_45)
print('Q_45 ',Q_45)
# Out:
# q_45  [1.         0.01333333 0.         0.13333333 0.02       1.        ]
# Q_45  [0.11741994 0.2219718  0.14377269 0.15865516 0.04392492]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_45)
plt.xlabel('Layer')
plt.ylabel('q_45')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_45)
plt.xlabel('Layer')
plt.ylabel('Q_45')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_46)
plt.xlabel('Layer')
plt.ylabel('q_46')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_46)
plt.xlabel('Layer')
plt.ylabel('Q_46')

plt.legend(['spin','bond'])
plt.show()

print('q_46 ',q_46)
print('Q_46 ',Q_46)
# Out:
# q_46  [1.         0.01333333 0.00666667 0.11333333 0.14666667 1.        ]
# Q_46  [0.00929039 0.11135552 0.01628506 0.06088678 0.08774835]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_46)
plt.xlabel('Layer')
plt.ylabel('q_46')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_46)
plt.xlabel('Layer')
plt.ylabel('Q_46')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_56)
plt.xlabel('Layer')
plt.ylabel('q_56')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_56)
plt.xlabel('Layer')
plt.ylabel('Q_56')

plt.legend(['spin','bond'])
plt.show()

print('q_56 ',q_56)
print('Q_56 ',Q_56)
# Out:
# q_56  [1.         0.02666667 0.02       0.07333333 0.03333333 1.        ]
# Q_56  [0.11523719 0.08923959 0.03176776 0.04564427 0.07304119]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_56)
plt.xlabel('Layer')
plt.ylabel('q_56')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_56)
plt.xlabel('Layer')
plt.ylabel('Q_56')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
#q = (q_12 + q_13 + q_14 + q_15 + q_16 + q_23 + q_24 + q_25 + q_26 + q_34 + q_35 + q_36 + q_45 + q_46 + q_56) / 15
#Q = (Q_12 + Q_13 + Q_14 + Q_15 + Q_16 + Q_23 + Q_24 + Q_25 + Q_26 + Q_34 + Q_35 + Q_36 + Q_45 + Q_46 + Q_56) / 15
#print(q)
#print(Q)

# %%
#i = [0,1,2,3,4,5]
#plt.plot(i, q)
#plt.xlabel('Layer')
#plt.ylabel('q')

#i = [0.5,1.5,2.5,3.5,4.5]
#plt.plot(i, Q)
#plt.xlabel('Layer')
#plt.ylabel('Q')

#plt.legend(['spin','bond'])
#plt.show()

# %%
#i = [0,1,2,3,4,5]
#plt.plot(i, q)
#plt.xlabel('Layer')
#plt.ylabel('q')

#i = [0.5,1.5,2.5,3.5,4.5]
#plt.plot(i, Q)
#plt.xlabel('Layer')
#plt.ylabel('Q')

#plt.legend(['spin','bond'])

#plt.ylim(0,0.5)
#plt.show()
