# %% [markdown]
# <a href="https://colab.research.google.com/github/tumblingdice512/Research/blob/master/model3_4_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# モデル3 シンプルなnumpyによる実装(leaky_reluの使用)

# %% [markdown]
# モデルについて
#
# 幅N、深さL+1(l=0,1,･･･,L)のネットワーク
#
# 各パーセプトロンはM成分を持つスピンで各成分は+1か-1を取る
#
# 第l層と第l+1層の各パーセプトロンの同一成分は全て結合→重みJ
#
# 各層の重みJはΣJ^2 = Nと正規化されている
#
# 第l層のスピンの値に重みをかけた値に対して符号関数をかませたものが第l+1層の値(0に対して+1か-1にする)
#
# ただし学習の際には、tanhを使っている
# 第l+1層の学習用の出力 = tanh(第l層の出力)
# 第l+1層のスピンの値 = sign(第l層の出力)
#
# 初期条件としては、入力層と出力層のスピンの値を与える
#
# 入力層のスピンの値と、初期の重みの条件から、出力層を予想して、損失関数(平均2乗誤差)を小さくするために重みを更新する

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
np.random.seed(100)

# %%
N = 10
L = 5

# %%
#S0 = np.array([random.choice([1,-1]) for i in range(N)])
#SL = np.array([random.choice([1,-1]) for i in range(N)])

#print(S0)
#print("S0の要素数は",len(S0))

#print(SL)
#print("SLの要素数は",len(SL))

#初期条件として与えるスピンを生成
#各パーセプトロンのスピンの成分数を増やすときは、SOとSLを行列の形式にすればよい。

# %%
S0 = np.sign(np.random.randn(10,N))

SL = np.sign(np.random.randn(10,N))


M = len(S0)
print(M)
print(N)
print(S0.shape)
print(S0[0].shape)
# Out:
# 10
# 10
# (10, 10)
# (10,)

# %%
alpha = M / N
print(alpha)
# Out:
# 1.0

# %%
D = np.array([[1,2,3],[2,3,4]])
print(D.shape)
print(len(D)) #M
print(len(D[0])) #N
# Out:
# (2, 3)
# 2
# 3

# %%
def leaky_relu(x):
  return np.where(x>=0, x, 0.01*x)

# %%
v= np.array([[1,-3],[2,-1]])
print(leaky_relu(v))
# Out:
# [[ 1.   -0.03]
#  [ 2.   -0.01]]

# %%
def spin_overlap(x,y):
  spin_overlap = 0
  for i in range (len(x[0])) :

    spin_overlap = spin_overlap + np.dot(x.T[i],y.T[i])
  return np.abs(spin_overlap/(len(x)*len(x[0])))

print(spin_overlap(S0,S0))
# Out:
# 1.0

# %%
def bond_overlap(x,y):
  bond_overlap = 0
  for i in range (len(x[0])) :

    bond_overlap = bond_overlap + np.dot(x.T[i],y.T[i])
  return np.abs(bond_overlap/(len(x[0])*len(x[0])))

# %%
S_a = np.array([[1,-1],[1,1],[1,-1]])
S_b = np.array([[1,-1],[1,1],[1,1]])
print(spin_overlap(S_a,S_b))
print(spin_overlap(S_a,S_a))
# Out:
# 0.6666666666666666
# 1.0

# %%
a1 = np.dot(S_a.T[0],S_b.T[0])
a2 = np.dot(S_a.T[1],S_b.T[1])
a3 = (a1 + a2)/(2*3)
print(a3)
# Out:
# 0.6666666666666666

# %%
def MSE(t, y):
    mse = np.mean(np.sum(np.square(t-y),axis =1),axis = 0)
    return mse

# %%
A = np.array([[3,5,1],[4,12,1]])
print(A**2)
A_norm = (np.sum(np.square(A),axis=0))**(1/2)

A_normalized = A / A_norm
A_normalized_2 = A / A_norm * (N**(1/2))

print(A_norm)

print(A_normalized)
print(A_normalized_2)
# Out:
# [[  9  25   1]
#  [ 16 144   1]]
# [ 5.         13.          1.41421356]
# [[0.6        0.38461538 0.70710678]
#  [0.8        0.92307692 0.70710678]]
# [[1.8973666  1.21626064 2.23606798]
#  [2.52982213 2.91902553 2.23606798]]

# %%
def weight_norm(x):
    x_norm = (np.sum(np.square(x),axis=0)**(1/2))
    return x_norm

# %%
w_a = np.array([[0,0,1],[1,0,0],[0,1,0]]) 
w_b = np.array([[1,0,0],[0,1,0],[0,0,1]]) 
J_a = w_a / (weight_norm(w_a)) * (3**(1/2))
J_b = w_b / (weight_norm(w_b)) * (3**(1/2))


print(J_a)
print(J_b)
print(len(J_a[0]))

print(bond_overlap(J_a,J_b))
print(bond_overlap(J_a,J_a))
# Out:
# [[0.         0.         1.73205081]
#  [1.73205081 0.         0.        ]
#  [0.         1.73205081 0.        ]]
# [[1.73205081 0.         0.        ]
#  [0.         1.73205081 0.        ]
#  [0.         0.         1.73205081]]
# 3
# 0.0
# 0.9999999999999998

# %%
class Network1():
  #ネットワークを定義する
  #構成[入力層, 第1層, 第2層, 第3層, 第4層, 第5層]
  #全結合

  def __init__(self):
    #重みの定義
    self.w1_1 = np.random.randn(N,N)
    self.w2_1 = np.random.randn(N,N)
    self.w3_1 = np.random.randn(N,N)
    self.w4_1 = np.random.randn(N,N)
    self.w5_1 = np.random.randn(N,N)

    #重みの正規化
    self.J1_1 = self.w1_1 / (weight_norm(self.w1_1)) * (N**(1/2))
    self.J2_1 = self.w2_1 / (weight_norm(self.w2_1)) * (N**(1/2))
    self.J3_1 = self.w3_1 / (weight_norm(self.w3_1)) * (N**(1/2))
    self.J4_1 = self.w4_1 / (weight_norm(self.w4_1)) * (N**(1/2))
    self.J5_1 = self.w5_1 / (weight_norm(self.w5_1)) * (N**(1/2))

  def forward(self, x):

    self.layer0_1 = x
    self.layer1_1 = leaky_relu(np.dot(self.layer0_1, self.J1_1))
    self.layer2_1 = leaky_relu(np.dot(self.layer1_1, self.J2_1))
    self.layer3_1 = leaky_relu(np.dot(self.layer2_1, self.J3_1))
    self.layer4_1 = leaky_relu(np.dot(self.layer3_1, self.J4_1))
    self.out_1 = np.tanh(np.dot(self.layer4_1, self.J5_1))

    S1_1 = np.sign(self.layer1_1)
    S2_1 = np.sign(self.layer2_1)
    S3_1 = np.sign(self.layer3_1)
    S4_1 = np.sign(self.layer4_1)
    

    return self.out_1, S1_1, S2_1, S3_1, S4_1
    

  def backward(self, t, y):
    #誤差逆伝播
    delta5_1 = -2*(t-y)
    delta4_1 = np.dot(delta5_1 * (1 - self.out_1**2),self.J5_1.T)
    delta3_1 = np.dot(delta4_1 * np.where(self.layer4_1>=0, 1, 0.01),self.J4_1.T) 
    delta2_1 = np.dot(delta3_1 * np.where(self.layer3_1>=0, 1, 0.01),self.J3_1.T)
    delta1_1 = np.dot(delta2_1 * np.where(self.layer2_1>=0, 1, 0.01),self.J2_1.T)

    #重みの勾配
    self.dedJ5_1 = np.dot(self.layer4_1.T, delta5_1 * (1 - self.out_1**2)) / delta5_1.shape[0]
    self.dedJ4_1 = np.dot(self.layer3_1.T, delta4_1 * np.where(self.layer4_1>=0, 1, 0.01)) / delta4_1.shape[0]
    self.dedJ3_1 = np.dot(self.layer2_1.T, delta3_1 * np.where(self.layer3_1>=0, 1, 0.01)) / delta3_1.shape[0]
    self.dedJ2_1 = np.dot(self.layer1_1.T, delta2_1 * np.where(self.layer2_1>=0, 1, 0.01)) / delta2_1.shape[0]
    self.dedJ1_1 = np.dot(self.layer0_1.T, delta1_1 * np.where(self.layer1_1>=0, 1, 0.01)) / delta1_1.shape[0]

  def optimize_GradientDecent(self, lr):
    #重みの更新    
    self.J1_1 -= lr * self.dedJ1_1
    self.J2_1 -= lr * self.dedJ2_1
    self.J3_1 -= lr * self.dedJ3_1
    self.J4_1 -= lr * self.dedJ4_1
    self.J5_1 -= lr * self.dedJ5_1

    #重みの正規化
    self.J1_1 = self.J1_1 / (weight_norm(self.J1_1)) * (N**(1/2))
    self.J2_1 = self.J2_1 / (weight_norm(self.J2_1)) * (N**(1/2))
    self.J3_1 = self.J3_1 / (weight_norm(self.J3_1)) * (N**(1/2))
    self.J4_1 = self.J4_1 / (weight_norm(self.J4_1)) * (N**(1/2))
    self.J5_1 = self.J5_1 / (weight_norm(self.J5_1)) * (N**(1/2))

    return self.J1_1, self.J2_1, self.J3_1, self.J4_1, self.J5_1

# %%
class Network2():
  #ネットワークを定義する
  #構成[入力層, 第1層, 第2層, 第3層, 第4層, 第5層]
  #全結合

  def __init__(self):
    #重みの定義
    self.w1_2 = np.random.randn(N,N)
    self.w2_2 = np.random.randn(N,N)
    self.w3_2 = np.random.randn(N,N)
    self.w4_2 = np.random.randn(N,N)
    self.w5_2 = np.random.randn(N,N)

    #重みの正規化
    self.J1_2 = self.w1_2 / (weight_norm(self.w1_2)) * (N**(1/2))
    self.J2_2 = self.w2_2 / (weight_norm(self.w2_2)) * (N**(1/2))
    self.J3_2 = self.w3_2 / (weight_norm(self.w3_2)) * (N**(1/2))
    self.J4_2 = self.w4_2 / (weight_norm(self.w4_2)) * (N**(1/2))
    self.J5_2 = self.w5_2 / (weight_norm(self.w5_2)) * (N**(1/2))

  def forward(self, x):

    self.layer0_2 = x
    self.layer1_2 = leaky_relu(np.dot(self.layer0_2, self.J1_2))
    self.layer2_2 = leaky_relu(np.dot(self.layer1_2, self.J2_2))
    self.layer3_2 = leaky_relu(np.dot(self.layer2_2, self.J3_2))
    self.layer4_2 = leaky_relu(np.dot(self.layer3_2, self.J4_2))
    self.out_2 = np.tanh(np.dot(self.layer4_2, self.J5_2))

    S1_2 = np.sign(self.layer1_2)
    S2_2 = np.sign(self.layer2_2)
    S3_2 = np.sign(self.layer3_2)
    S4_2 = np.sign(self.layer4_2)

    return self.out_2, S1_2, S2_2, S3_2, S4_2
    

  def backward(self, t, y):
    #誤差逆伝播
    delta5_2 = -2*(t-y)
    delta4_2 = np.dot(delta5_2 * (1 - self.out_2**2),self.J5_2.T)
    delta3_2 = np.dot(delta4_2 * np.where(self.layer4_2>=0, 1, 0.01),self.J4_2.T) 
    delta2_2 = np.dot(delta3_2 * np.where(self.layer3_2>=0, 1, 0.01),self.J3_2.T)
    delta1_2 = np.dot(delta2_2 * np.where(self.layer2_2>=0, 1, 0.01),self.J2_2.T)

    #重みの勾配
    self.dedJ5_2 = np.dot(self.layer4_2.T, delta5_2 * (1 - self.out_2**2)) / delta5_2.shape[0]
    self.dedJ4_2 = np.dot(self.layer3_2.T, delta4_2 * np.where(self.layer4_2>=0, 1, 0.01)) / delta4_2.shape[0]
    self.dedJ3_2 = np.dot(self.layer2_2.T, delta3_2 * np.where(self.layer3_2>=0, 1, 0.01)) / delta3_2.shape[0]
    self.dedJ2_2 = np.dot(self.layer1_2.T, delta2_2 * np.where(self.layer2_2>=0, 1, 0.01)) / delta2_2.shape[0]
    self.dedJ1_2 = np.dot(self.layer0_2.T, delta1_2 * np.where(self.layer1_2>=0, 1, 0.01))/ delta1_2.shape[0]

  def optimize_GradientDecent(self, lr):
    #重みの更新    
    self.J1_2 -= lr * self.dedJ1_2
    self.J2_2 -= lr * self.dedJ2_2
    self.J3_2 -= lr * self.dedJ3_2
    self.J4_2 -= lr * self.dedJ4_2
    self.J5_2 -= lr * self.dedJ5_2

    #重みの正規化
    self.J1_2 = self.J1_2 / (weight_norm(self.J1_2)) * (N**(1/2))
    self.J2_2 = self.J2_2 / (weight_norm(self.J2_2)) * (N**(1/2))
    self.J3_2 = self.J3_2 / (weight_norm(self.J3_2)) * (N**(1/2))
    self.J4_2 = self.J4_2 / (weight_norm(self.J4_2)) * (N**(1/2))
    self.J5_2 = self.J5_2 / (weight_norm(self.J5_2)) * (N**(1/2))

    return self.J1_2, self.J2_2, self.J3_2, self.J4_2, self.J5_2

# %%
class Network3():
  #ネットワークを定義する
  #構成[入力層, 第1層, 第2層, 第3層, 第4層, 第5層]
  #全結合

  def __init__(self):
    #重みの定義
    self.w1_3 = np.random.randn(N,N)
    self.w2_3 = np.random.randn(N,N)
    self.w3_3 = np.random.randn(N,N)
    self.w4_3 = np.random.randn(N,N)
    self.w5_3 = np.random.randn(N,N)

    #重みの正規化
    self.J1_3 = self.w1_3 / (weight_norm(self.w1_3)) * (N**(1/2))
    self.J2_3 = self.w2_3 / (weight_norm(self.w2_3)) * (N**(1/2))
    self.J3_3 = self.w3_3 / (weight_norm(self.w3_3)) * (N**(1/2))
    self.J4_3 = self.w4_3 / (weight_norm(self.w4_3)) * (N**(1/2))
    self.J5_3 = self.w5_3 / (weight_norm(self.w5_3)) * (N**(1/2))

  def forward(self, x):

    self.layer0_3 = x
    self.layer1_3 = leaky_relu(np.dot(self.layer0_3, self.J1_3))
    self.layer2_3 = leaky_relu(np.dot(self.layer1_3, self.J2_3))
    self.layer3_3 = leaky_relu(np.dot(self.layer2_3, self.J3_3))
    self.layer4_3 = leaky_relu(np.dot(self.layer3_3, self.J4_3))
    self.out_3 = np.tanh(np.dot(self.layer4_3, self.J5_3))

    S1_3 = np.sign(self.layer1_3)
    S2_3 = np.sign(self.layer2_3)
    S3_3 = np.sign(self.layer3_3)
    S4_3 = np.sign(self.layer4_3)

    return self.out_3, S1_3, S2_3, S3_3, S4_3
    

  def backward(self, t, y):
    #誤差逆伝播
    delta5_3 = -2*(t-y)
    delta4_3 = np.dot(delta5_3 * (1 - self.out_3**2),self.J5_3.T)
    delta3_3 = np.dot(delta4_3 * np.where(self.layer4_3>=0, 1, 0.01),self.J4_3.T) 
    delta2_3 = np.dot(delta3_3 * np.where(self.layer3_3>=0, 1, 0.01),self.J3_3.T)
    delta1_3 = np.dot(delta2_3 * np.where(self.layer2_3>=0, 1, 0.01),self.J2_3.T)

    #重みの勾配
    self.dedJ5_3 = np.dot(self.layer4_3.T, delta5_3 * (1 - self.out_3**2)) / delta5_3.shape[0]
    self.dedJ4_3 = np.dot(self.layer3_3.T, delta4_3 * np.where(self.layer4_3>=0, 1, 0.01)) / delta4_3.shape[0]
    self.dedJ3_3 = np.dot(self.layer2_3.T, delta3_3 * np.where(self.layer3_3>=0, 1, 0.01)) / delta3_3.shape[0]
    self.dedJ2_3 = np.dot(self.layer1_3.T, delta2_3 * np.where(self.layer2_3>=0, 1, 0.01)) / delta2_3.shape[0]
    self.dedJ1_3 = np.dot(self.layer0_3.T, delta1_3 * np.where(self.layer1_3>=0, 1, 0.01)) / delta1_3.shape[0]

  def optimize_GradientDecent(self, lr):
    #重みの更新    
    self.J1_3 -= lr * self.dedJ1_3
    self.J2_3 -= lr * self.dedJ2_3
    self.J3_3 -= lr * self.dedJ3_3
    self.J4_3 -= lr * self.dedJ4_3
    self.J5_3 -= lr * self.dedJ5_3

    #重みの正規化
    self.J1_3 = self.J1_3 / (weight_norm(self.J1_3)) * (N**(1/2))
    self.J2_3 = self.J2_3 / (weight_norm(self.J2_3)) * (N**(1/2))
    self.J3_3 = self.J3_3 / (weight_norm(self.J3_3)) * (N**(1/2))
    self.J4_3 = self.J4_3 / (weight_norm(self.J4_3)) * (N**(1/2))
    self.J5_3 = self.J5_3 / (weight_norm(self.J5_3)) * (N**(1/2))

    return self.J1_3, self.J2_3, self.J3_3, self.J4_3, self.J5_3

# %%
class Network4():
  #ネットワークを定義する
  #構成[入力層, 第1層, 第2層, 第3層, 第4層, 第5層]
  #全結合

  def __init__(self):
    #重みの定義
    self.w1_4 = np.random.randn(N,N)
    self.w2_4 = np.random.randn(N,N)
    self.w3_4 = np.random.randn(N,N)
    self.w4_4 = np.random.randn(N,N)
    self.w5_4 = np.random.randn(N,N)

    #重みの正規化
    self.J1_4 = self.w1_4 / (weight_norm(self.w1_4)) * (N**(1/2))
    self.J2_4 = self.w2_4 / (weight_norm(self.w2_4)) * (N**(1/2))
    self.J3_4 = self.w3_4 / (weight_norm(self.w3_4)) * (N**(1/2))
    self.J4_4 = self.w4_4 / (weight_norm(self.w4_4)) * (N**(1/2))
    self.J5_4 = self.w5_4 / (weight_norm(self.w5_4)) * (N**(1/2))

  def forward(self, x):

    self.layer0_4 = x
    self.layer1_4 = leaky_relu(np.dot(self.layer0_4, self.J1_4))
    self.layer2_4 = leaky_relu(np.dot(self.layer1_4, self.J2_4))
    self.layer3_4 = leaky_relu(np.dot(self.layer2_4, self.J3_4))
    self.layer4_4 = leaky_relu(np.dot(self.layer3_4, self.J4_4))
    self.out_4 = np.tanh(np.dot(self.layer4_4, self.J5_4))

    S1_4 = np.sign(self.layer1_4)
    S2_4 = np.sign(self.layer2_4)
    S3_4 = np.sign(self.layer3_4)
    S4_4 = np.sign(self.layer4_4)

    return self.out_4, S1_4, S2_4, S3_4, S4_4
    

  def backward(self, t, y):
    #誤差逆伝播
    delta5_4 = -2*(t-y)
    delta4_4 = np.dot(delta5_4 * (1 - self.out_4**2),self.J5_4.T)
    delta3_4 = np.dot(delta4_4 * np.where(self.layer4_4>=0, 1, 0.01),self.J4_4.T) 
    delta2_4 = np.dot(delta3_4 * np.where(self.layer3_4>=0, 1, 0.01),self.J3_4.T)
    delta1_4 = np.dot(delta2_4 * np.where(self.layer2_4>=0, 1, 0.01),self.J2_4.T)

    #重みの勾配
    self.dedJ5_4 = np.dot(self.layer4_4.T, delta5_4 * (1 - self.out_4**2)) / delta5_4.shape[0]
    self.dedJ4_4 = np.dot(self.layer3_4.T, delta4_4 * np.where(self.layer4_4>=0, 1, 0.01)) / delta4_4.shape[0]
    self.dedJ3_4 = np.dot(self.layer2_4.T, delta3_4 * np.where(self.layer3_4>=0, 1, 0.01)) / delta3_4.shape[0]
    self.dedJ2_4 = np.dot(self.layer1_4.T, delta2_4 * np.where(self.layer2_4>=0, 1, 0.01)) / delta2_4.shape[0]
    self.dedJ1_4 = np.dot(self.layer0_4.T, delta1_4 * np.where(self.layer1_4>=0, 1, 0.01)) / delta1_4.shape[0]

  def optimize_GradientDecent(self, lr):
    #重みの更新    
    self.J1_4 -= lr * self.dedJ1_4
    self.J2_4 -= lr * self.dedJ2_4
    self.J3_4 -= lr * self.dedJ3_4
    self.J4_4 -= lr * self.dedJ4_4
    self.J5_4 -= lr * self.dedJ5_4

    #重みの正規化
    self.J1_4 = self.J1_4 / (weight_norm(self.J1_4)) * (N**(1/2))
    self.J2_4 = self.J2_4 / (weight_norm(self.J2_4)) * (N**(1/2))
    self.J3_4 = self.J3_4 / (weight_norm(self.J3_4)) * (N**(1/2))
    self.J4_4 = self.J4_4 / (weight_norm(self.J4_4)) * (N**(1/2))
    self.J5_4 = self.J5_4 / (weight_norm(self.J5_4)) * (N**(1/2))

    return self.J1_4, self.J2_4, self.J3_4, self.J4_4, self.J5_4

# %%
class Network5():
  #ネットワークを定義する
  #構成[入力層, 第1層, 第2層, 第3層, 第4層, 第5層]
  #全結合

  def __init__(self):
    #重みの定義
    self.w1_5 = np.random.randn(N,N)
    self.w2_5 = np.random.randn(N,N)
    self.w3_5 = np.random.randn(N,N)
    self.w4_5 = np.random.randn(N,N)
    self.w5_5 = np.random.randn(N,N)

    #重みの正規化
    self.J1_5 = self.w1_5 / (weight_norm(self.w1_5)) * (N**(1/2))
    self.J2_5 = self.w2_5 / (weight_norm(self.w2_5)) * (N**(1/2))
    self.J3_5 = self.w3_5 / (weight_norm(self.w3_5)) * (N**(1/2))
    self.J4_5 = self.w4_5 / (weight_norm(self.w4_5)) * (N**(1/2))
    self.J5_5 = self.w5_5 / (weight_norm(self.w5_5)) * (N**(1/2))

  def forward(self, x):

    self.layer0_5 = x
    self.layer1_5 = leaky_relu(np.dot(self.layer0_5, self.J1_5))
    self.layer2_5 = leaky_relu(np.dot(self.layer1_5, self.J2_5))
    self.layer3_5 = leaky_relu(np.dot(self.layer2_5, self.J3_5))
    self.layer4_5 = leaky_relu(np.dot(self.layer3_5, self.J4_5))
    self.out_5 = np.tanh(np.dot(self.layer4_5, self.J5_5))

    S1_5 = np.sign(self.layer1_5)
    S2_5 = np.sign(self.layer2_5)
    S3_5 = np.sign(self.layer3_5)
    S4_5 = np.sign(self.layer4_5)

    return self.out_5, S1_5, S2_5, S3_5, S4_5
    

  def backward(self, t, y):
    #誤差逆伝播
    delta5_5 = -2*(t-y)
    delta4_5 = np.dot(delta5_5 * (1 - self.out_5**2),self.J5_5.T)
    delta3_5 = np.dot(delta4_5 * np.where(self.layer4_5>=0, 1, 0.01),self.J4_5.T) 
    delta2_5 = np.dot(delta3_5 * np.where(self.layer3_5>=0, 1, 0.01),self.J3_5.T)
    delta1_5 = np.dot(delta2_5 * np.where(self.layer2_5>=0, 1, 0.01),self.J2_5.T)

    #重みの勾配
    self.dedJ5_5 = np.dot(self.layer4_5.T, delta5_5 * (1 - self.out_5**2)) / delta5_5.shape[0]
    self.dedJ4_5 = np.dot(self.layer3_5.T, delta4_5 * np.where(self.layer4_5>=0, 1, 0.01)) / delta4_5.shape[0]
    self.dedJ3_5 = np.dot(self.layer2_5.T, delta3_5 * np.where(self.layer3_5>=0, 1, 0.01)) / delta3_5.shape[0]
    self.dedJ2_5 = np.dot(self.layer1_5.T, delta2_5 * np.where(self.layer2_5>=0, 1, 0.01)) / delta2_5.shape[0]
    self.dedJ1_5 = np.dot(self.layer0_5.T, delta1_5 * np.where(self.layer1_5>=0, 1, 0.01)) / delta1_5.shape[0]

  def optimize_GradientDecent(self, lr):
    #重みの更新    
    self.J1_5 -= lr * self.dedJ1_5
    self.J2_5 -= lr * self.dedJ2_5
    self.J3_5 -= lr * self.dedJ3_5
    self.J4_5 -= lr * self.dedJ4_5
    self.J5_5 -= lr * self.dedJ5_5

    #重みの正規化
    self.J1_5 = self.J1_5 / (weight_norm(self.J1_5)) * (N**(1/2))
    self.J2_5 = self.J2_5 / (weight_norm(self.J2_5)) * (N**(1/2))
    self.J3_5 = self.J3_5 / (weight_norm(self.J3_5)) * (N**(1/2))
    self.J4_5 = self.J4_5 / (weight_norm(self.J4_5)) * (N**(1/2))
    self.J5_5 = self.J5_5 / (weight_norm(self.J5_5)) * (N**(1/2))

    return self.J1_5, self.J2_5, self.J3_5, self.J4_5, self.J5_5

# %%
class Network6():
  #ネットワークを定義する
  #構成[入力層, 第1層, 第2層, 第3層, 第4層, 第5層]
  #全結合

  def __init__(self):
    #重みの定義
    self.w1_6 = np.random.randn(N,N)
    self.w2_6 = np.random.randn(N,N)
    self.w3_6 = np.random.randn(N,N)
    self.w4_6 = np.random.randn(N,N)
    self.w5_6 = np.random.randn(N,N)

    #重みの正規化
    self.J1_6 = self.w1_6 / (weight_norm(self.w1_6)) * (N**(1/2))
    self.J2_6 = self.w2_6 / (weight_norm(self.w2_6)) * (N**(1/2))
    self.J3_6 = self.w3_6 / (weight_norm(self.w3_6)) * (N**(1/2))
    self.J4_6 = self.w4_6 / (weight_norm(self.w4_6)) * (N**(1/2))
    self.J5_6 = self.w5_6 / (weight_norm(self.w5_6)) * (N**(1/2))

  def forward(self, x):

    self.layer0_6 = x
    self.layer1_6 = leaky_relu(np.dot(self.layer0_6, self.J1_6))
    self.layer2_6 = leaky_relu(np.dot(self.layer1_6, self.J2_6))
    self.layer3_6 = leaky_relu(np.dot(self.layer2_6, self.J3_6))
    self.layer4_6 = leaky_relu(np.dot(self.layer3_6, self.J4_6))
    self.out_6 = np.tanh(np.dot(self.layer4_6, self.J5_6))

    S1_6 = np.sign(self.layer1_6)
    S2_6 = np.sign(self.layer2_6)
    S3_6 = np.sign(self.layer3_6)
    S4_6 = np.sign(self.layer4_6)

    return self.out_6, S1_6, S2_6, S3_6, S4_6
    

  def backward(self, t, y):
    #誤差逆伝播
    delta5_6 = -2*(t-y)
    delta4_6 = np.dot(delta5_6 * (1 - self.out_6**2),self.J5_6.T)
    delta3_6 = np.dot(delta4_6 * np.where(self.layer4_6>=0, 1, 0.01),self.J4_6.T) 
    delta2_6 = np.dot(delta3_6 * np.where(self.layer3_6>=0, 1, 0.01),self.J3_6.T)
    delta1_6 = np.dot(delta2_6 * np.where(self.layer2_6>=0, 1, 0.01),self.J2_6.T)

    #重みの勾配
    self.dedJ5_6 = np.dot(self.layer4_6.T, delta5_6 * (1 - self.out_6**2)) / delta5_6.shape[0]
    self.dedJ4_6 = np.dot(self.layer3_6.T, delta4_6 * np.where(self.layer4_6>=0, 1, 0.01)) / delta4_6.shape[0]
    self.dedJ3_6 = np.dot(self.layer2_6.T, delta3_6 * np.where(self.layer3_6>=0, 1, 0.01)) / delta3_6.shape[0]
    self.dedJ2_6 = np.dot(self.layer1_6.T, delta2_6 * np.where(self.layer2_6>=0, 1, 0.01)) / delta2_6.shape[0]
    self.dedJ1_6 = np.dot(self.layer0_6.T, delta1_6 * np.where(self.layer1_6>=0, 1, 0.01)) / delta1_6.shape[0]

  def optimize_GradientDecent(self, lr):
    #重みの更新    
    self.J1_6 -= lr * self.dedJ1_6
    self.J2_6 -= lr * self.dedJ2_6
    self.J3_6 -= lr * self.dedJ3_6
    self.J4_6 -= lr * self.dedJ4_6
    self.J5_6 -= lr * self.dedJ5_6

    #重みの正規化
    self.J1_6 = self.J1_6 / (weight_norm(self.J1_6)) * (N**(1/2))
    self.J2_6 = self.J2_6 / (weight_norm(self.J2_6)) * (N**(1/2))
    self.J3_6 = self.J3_6 / (weight_norm(self.J3_6)) * (N**(1/2))
    self.J4_6 = self.J4_6 / (weight_norm(self.J4_6)) * (N**(1/2))
    self.J5_6 = self.J5_6 / (weight_norm(self.J5_6)) * (N**(1/2))

    return self.J1_6, self.J2_6, self.J3_6, self.J4_6, self.J5_6

# %%
model_1 = Network1()
model_2 = Network2()
model_3 = Network3()
model_4 = Network4()
model_5 = Network5()
model_6 = Network6()


# 学習率
lr = 0.06
# 学習エポック数
n_epoch = 100000
Loss_1 = []
Loss_2 = []
Loss_3 = []
Loss_4 = []
Loss_5 = []
Loss_6 = []


  # n_epoch繰り返す
  
for n in range(n_epoch):
    y_1 = model_1.forward(S0)
    y_2 = model_2.forward(S0)
    y_3 = model_3.forward(S0)
    y_4 = model_4.forward(S0)
    y_5 = model_5.forward(S0)
    y_6 = model_6.forward(S0)

    loss_Network_1 = MSE(SL, y_1[0])
    loss_Network_2 = MSE(SL, y_2[0])
    loss_Network_3 = MSE(SL, y_3[0])
    loss_Network_4 = MSE(SL, y_4[0])
    loss_Network_5 = MSE(SL, y_5[0])
    loss_Network_6 = MSE(SL, y_6[0])

    model_1.backward(SL, y_1[0])
    model_2.backward(SL, y_2[0])
    model_3.backward(SL, y_3[0])
    model_4.backward(SL, y_4[0])
    model_5.backward(SL, y_5[0])
    model_6.backward(SL, y_6[0])

    w_1 = model_1.optimize_GradientDecent(lr)
    w_2 = model_2.optimize_GradientDecent(lr)
    w_3 = model_3.optimize_GradientDecent(lr)
    w_4 = model_4.optimize_GradientDecent(lr)
    w_5 = model_5.optimize_GradientDecent(lr)
    w_6 = model_6.optimize_GradientDecent(lr)




    Loss_1.append(loss_Network_1)
    Loss_2.append(loss_Network_2)
    Loss_3.append(loss_Network_3)
    Loss_4.append(loss_Network_4)
    Loss_5.append(loss_Network_5)
    Loss_6.append(loss_Network_6)

    print('EPOCH ', n + 1, ' | TRAIN LOSS_1 ',loss_Network_1, '  TRAIN LOSS_2 ',loss_Network_2,
                            '  TRAIN LOSS_3 ',loss_Network_3, '  TRAIN LOSS_4 ',loss_Network_4,
                            '  TRAIN LOSS_5 ',loss_Network_5, '  TRAIN LOSS_6 ',loss_Network_6)
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# EPOCH  3885  | TRAIN LOSS_1  14.40000020658336   TRAIN LOSS_2  13.60000259071532   TRAIN LOSS_3  16.000000744059555   TRAIN LOSS_4  16.400000043174927   TRAIN LOSS_5  17.19999998794726   TRAIN LOSS_6  18.800001785859816
# EPOCH  3886  | TRAIN LOSS_1  14.400000206539563   TRAIN LOSS_2  13.600002589073133   TRAIN LOSS_3  16.000000743875656   TRAIN LOSS_4  16.400000043164873   TRAIN LOSS_5  17.199999987944658   TRAIN LOSS_6  18.800001785409844
# EPOCH  3887  | TRAIN LOSS_1  14.40000020649579   TRAIN LOSS_2  13.600002587433329   TRAIN LOSS_3  16.00000074369187   TRAIN LOSS_4  16.40000004315483   TRAIN LOSS_5  17.199999987942057   TRAIN LOSS_6  18.800001784960088
# EPOCH  3888  | TRAIN LOSS_1  14.400000206452038   TRAIN LOSS_2  13.6000025857959   TRAIN LOSS_3  16.000000743508203   TRAIN LOSS_4  16.40000004314479   TRAIN LOSS_5  17.199999987939453   TRAIN LOSS_6  18.80000178451055
# EPOCH  3889  | TRAIN LOSS_1  14.400000206408313   TRAIN LOSS_2  13.600002584160842   TRAIN LOSS_3  16.000000743324645   TRAIN LOSS_4  16.40000004313475   TRAIN LOSS_5  17.19999998793685   TRAIN LOSS_6  18.800001784061223
# EPOCH  3890  | TRAIN LOSS_1  14.400000206364613   TRAIN LOSS_2  13.600002582528152   TRAIN LOSS_3  16.000000743141204   TRAIN LOSS_4  16.40000004312472   TRAIN LOSS_5  17.199999987934245   TRAIN LOSS_6  18.800001783612114
# EPOCH  3891  | TRAIN LOSS_1  14.400000206320936   TRAIN LOSS_2  13.600002580897822   TRAIN LOSS_3  16.000000742957873   TRAIN LOSS_4  16.400000043114694   TRAIN LOSS_5  17.19999998793164   TRAIN LOSS_6  18.80000178316322
# EPOCH  3892  | TRAIN LOSS_1  14.400000206277284   TRAIN LOSS_2  13.60000257926985   TRAIN LOSS_3  16.000000742774656   TRAIN LOSS_4  16.400000043104676   TRAIN LOSS_5  17.19999998792903   TRAIN LOSS_6  18.800001782714553
# EPOCH  3893  | TRAIN LOSS_1  14.40000020623366   TRAIN LOSS_2  13.600002577644224   TRAIN LOSS_3  16.000000742591553   TRAIN LOSS_4  16.400000043094657   TRAIN LOSS_5  17.19999998792642   TRAIN LOSS_6  18.800001782266094
# EPOCH  3894  | TRAIN LOSS_1  14.400000206190057   TRAIN LOSS_2  13.600002576020945   TRAIN LOSS_3  16.000000742408563   TRAIN LOSS_4  16.40000004308465   TRAIN LOSS_5  17.19999998792381   TRAIN LOSS_6  18.800001781817848
# EPOCH  3895  | TRAIN LOSS_1  14.400000206146478   TRAIN LOSS_2  13.600002574400005   TRAIN LOSS_3  16.000000742225687   TRAIN LOSS_4  16.40000004307464   TRAIN LOSS_5  17.1999999879212   TRAIN LOSS_6  18.800001781369822
# EPOCH  3896  | TRAIN LOSS_1  14.400000206102922   TRAIN LOSS_2  13.600002572781401   TRAIN LOSS_3  16.00000074204292   TRAIN LOSS_4  16.40000004306464   TRAIN LOSS_5  17.19999998791859   TRAIN LOSS_6  18.80000178092201
# EPOCH  3897  | TRAIN LOSS_1  14.400000206059394   TRAIN LOSS_2  13.60000257116513   TRAIN LOSS_3  16.000000741860273   TRAIN LOSS_4  16.400000043054643   TRAIN LOSS_5  17.199999987915977   TRAIN LOSS_6  18.800001780474414
# EPOCH  3898  | TRAIN LOSS_1  14.40000020601589   TRAIN LOSS_2  13.600002569551176   TRAIN LOSS_3  16.000000741677734   TRAIN LOSS_4  16.400000043044653   TRAIN LOSS_5  17.199999987913362   TRAIN LOSS_6  18.800001780027035
# EPOCH  3899  | TRAIN LOSS_1  14.40000020597241   TRAIN LOSS_2  13.600002567939546   TRAIN LOSS_3  16.00000074149531   TRAIN LOSS_4  16.400000043034666   TRAIN LOSS_5  17.199999987910747   TRAIN LOSS_6  18.800001779579866
# EPOCH  3900  | TRAIN LOSS_1  14.400000205928952   TRAIN LOSS_2  13.600002566330232   TRAIN LOSS_3  16.000000741312995   TRAIN LOSS_4  16.400000043024683   TRAIN LOSS_5  17.19999998790813   TRAIN LOSS_6  18.800001779132916
# EPOCH  3901  | TRAIN LOSS_1  14.400000205885519   TRAIN LOSS_2  13.600002564723223   TRAIN LOSS_3  16.000000741130798   TRAIN LOSS_4  16.400000043014707   TRAIN LOSS_5  17.19999998790551   TRAIN LOSS_6  18.800001778686177
# EPOCH  3902  | TRAIN LOSS_1  14.400000205842113   TRAIN LOSS_2  13.600002563118522   TRAIN LOSS_3  16.00000074094871   TRAIN LOSS_4  16.400000043004734   TRAIN LOSS_5  17.199999987902892   TRAIN LOSS_6  18.800001778239654
# EPOCH  3903  | TRAIN LOSS_1  14.40000020579873   TRAIN LOSS_2  13.60000256151612   TRAIN LOSS_3  16.000000740766733   TRAIN LOSS_4  16.40000004299477   TRAIN LOSS_5  17.199999987900274   TRAIN LOSS_6  18.800001777793348
# EPOCH  3904  | TRAIN LOSS_1  14.400000205755372   TRAIN LOSS_2  13.600002559916012   TRAIN LOSS_3  16.00000074058487   TRAIN LOSS_4  16.400000042984807   TRAIN LOSS_5  17.19999998789765   TRAIN LOSS_6  18.800001777347255
# EPOCH  3905  | TRAIN LOSS_1  14.400000205712038   TRAIN LOSS_2  13.600002558318195   TRAIN LOSS_3  16.000000740403117   TRAIN LOSS_4  16.40000004297485   TRAIN LOSS_5  17.19999998789503   TRAIN LOSS_6  18.800001776901375
# EPOCH  3906  | TRAIN LOSS_1  14.400000205668727   TRAIN LOSS_2  13.60000255672266   TRAIN LOSS_3  16.000000740221477   TRAIN LOSS_4  16.400000042964898   TRAIN LOSS_5  17.199999987892404   TRAIN LOSS_6  18.800001776455712
# EPOCH  3907  | TRAIN LOSS_1  14.400000205625437   TRAIN LOSS_2  13.600002555129404   TRAIN LOSS_3  16.00000074003995   TRAIN LOSS_4  16.40000004295495   TRAIN LOSS_5  17.199999987889782   TRAIN LOSS_6  18.800001776010262
# EPOCH  3908  | TRAIN LOSS_1  14.400000205582177   TRAIN LOSS_2  13.600002553538422   TRAIN LOSS_3  16.000000739858535   TRAIN LOSS_4  16.400000042945006   TRAIN LOSS_5  17.199999987887157   TRAIN LOSS_6  18.800001775565025
# EPOCH  3909  | TRAIN LOSS_1  14.40000020553894   TRAIN LOSS_2  13.60000255194971   TRAIN LOSS_3  16.00000073967723   TRAIN LOSS_4  16.40000004293507   TRAIN LOSS_5  17.19999998788453   TRAIN LOSS_6  18.800001775120002
# EPOCH  3910  | TRAIN LOSS_1  14.400000205495724   TRAIN LOSS_2  13.600002550363268   TRAIN LOSS_3  16.000000739496038   TRAIN LOSS_4  16.400000042925136   TRAIN LOSS_5  17.199999987881903   TRAIN LOSS_6  18.800001774675188
# EPOCH  3911  | TRAIN LOSS_1  14.400000205452534   TRAIN LOSS_2  13.600002548779079   TRAIN LOSS_3  16.000000739314952   TRAIN LOSS_4  16.40000004291521   TRAIN LOSS_5  17.199999987879274   TRAIN LOSS_6  18.80000177423059
# EPOCH  3912  | TRAIN LOSS_1  14.40000020540937   TRAIN LOSS_2  13.600002547197146   TRAIN LOSS_3  16.00000073913398   TRAIN LOSS_4  16.400000042905287   TRAIN LOSS_5  17.199999987876645   TRAIN LOSS_6  18.800001773786207
# EPOCH  3913  | TRAIN LOSS_1  14.40000020536623   TRAIN LOSS_2  13.600002545617466   TRAIN LOSS_3  16.000000738953123   TRAIN LOSS_4  16.400000042895368   TRAIN LOSS_5  17.199999987874012   TRAIN LOSS_6  18.80000177334204
# EPOCH  3914  | TRAIN LOSS_1  14.40000020532311   TRAIN LOSS_2  13.600002544040029   TRAIN LOSS_3  16.000000738772375   TRAIN LOSS_4  16.400000042885456   TRAIN LOSS_5  17.199999987871376   TRAIN LOSS_6  18.800001772898078
# EPOCH  3915  | TRAIN LOSS_1  14.400000205280017   TRAIN LOSS_2  13.60000254246483   TRAIN LOSS_3  16.000000738591734   TRAIN LOSS_4  16.400000042875547   TRAIN LOSS_5  17.199999987868743   TRAIN LOSS_6  18.80000177245433
# EPOCH  3916  | TRAIN LOSS_1  14.40000020523695   TRAIN LOSS_2  13.60000254089187   TRAIN LOSS_3  16.000000738411206   TRAIN LOSS_4  16.400000042865646   TRAIN LOSS_5  17.19999998786611   TRAIN LOSS_6  18.8000017720108
# EPOCH  3917  | TRAIN LOSS_1  14.400000205193901   TRAIN LOSS_2  13.600002539321139   TRAIN LOSS_3  16.00000073823079   TRAIN LOSS_4  16.400000042855744   TRAIN LOSS_5  17.199999987863475   TRAIN LOSS_6  18.800001771567473
# EPOCH  3918  | TRAIN LOSS_1  14.40000020515088   TRAIN LOSS_2  13.600002537752633   TRAIN LOSS_3  16.00000073805048   TRAIN LOSS_4  16.400000042845853   TRAIN LOSS_5  17.19999998786084   TRAIN LOSS_6  18.800001771124364
# EPOCH  3919  | TRAIN LOSS_1  14.400000205107881   TRAIN LOSS_2  13.600002536186349   TRAIN LOSS_3  16.000000737870284   TRAIN LOSS_4  16.400000042835963   TRAIN LOSS_5  17.1999999878582   TRAIN LOSS_6  18.80000177068147
# EPOCH  3920  | TRAIN LOSS_1  14.400000205064908   TRAIN LOSS_2  13.60000253462228   TRAIN LOSS_3  16.000000737690193   TRAIN LOSS_4  16.40000004282608   TRAIN LOSS_5  17.19999998785556   TRAIN LOSS_6  18.800001770238783
# EPOCH  3921  | TRAIN LOSS_1  14.400000205021957   TRAIN LOSS_2  13.600002533060422   TRAIN LOSS_3  16.000000737510216   TRAIN LOSS_4  16.4000000428162   TRAIN LOSS_5  17.19999998785292   TRAIN LOSS_6  18.80000176979631
# EPOCH  3922  | TRAIN LOSS_1  14.400000204979033   TRAIN LOSS_2  13.600002531500772   TRAIN LOSS_3  16.00000073733035   TRAIN LOSS_4  16.400000042806326   TRAIN LOSS_5  17.199999987850276   TRAIN LOSS_6  18.800001769354047
# EPOCH  3923  | TRAIN LOSS_1  14.40000020493613   TRAIN LOSS_2  13.600002529943321   TRAIN LOSS_3  16.000000737150593   TRAIN LOSS_4  16.400000042796457   TRAIN LOSS_5  17.199999987847633   TRAIN LOSS_6  18.800001768911997
# EPOCH  3924  | TRAIN LOSS_1  14.400000204893251   TRAIN LOSS_2  13.60000252838807   TRAIN LOSS_3  16.000000736970946   TRAIN LOSS_4  16.400000042786594   TRAIN LOSS_5  17.19999998784499   TRAIN LOSS_6  18.800001768470157
# EPOCH  3925  | TRAIN LOSS_1  14.400000204850397   TRAIN LOSS_2  13.60000252683501   TRAIN LOSS_3  16.000000736791414   TRAIN LOSS_4  16.400000042776732   TRAIN LOSS_5  17.199999987842347   TRAIN LOSS_6  18.80000176802853
# EPOCH  3926  | TRAIN LOSS_1  14.400000204807565   TRAIN LOSS_2  13.60000252528414   TRAIN LOSS_3  16.000000736611984   TRAIN LOSS_4  16.400000042766877   TRAIN LOSS_5  17.199999987839696   TRAIN LOSS_6  18.80000176758711
# EPOCH  3927  | TRAIN LOSS_1  14.400000204764757   TRAIN LOSS_2  13.60000252373545   TRAIN LOSS_3  16.00000073643266   TRAIN LOSS_4  16.400000042757025   TRAIN LOSS_5  17.199999987837053   TRAIN LOSS_6  18.8000017671459
# EPOCH  3928  | TRAIN LOSS_1  14.400000204721977   TRAIN LOSS_2  13.60000252218894   TRAIN LOSS_3  16.000000736253455   TRAIN LOSS_4  16.40000004274718   TRAIN LOSS_5  17.199999987834403   TRAIN LOSS_6  18.800001766704906
# EPOCH  3929  | TRAIN LOSS_1  14.400000204679216   TRAIN LOSS_2  13.6000025206446   TRAIN LOSS_3  16.000000736074355   TRAIN LOSS_4  16.40000004273734   TRAIN LOSS_5  17.199999987831752   TRAIN LOSS_6  18.800001766264124
# EPOCH  3930  | TRAIN LOSS_1  14.400000204636479   TRAIN LOSS_2  13.600002519102432   TRAIN LOSS_3  16.000000735895362   TRAIN LOSS_4  16.400000042727505   TRAIN LOSS_5  17.199999987829102   TRAIN LOSS_6  18.800001765823545
# EPOCH  3931  | TRAIN LOSS_1  14.400000204593766   TRAIN LOSS_2  13.600002517562427   TRAIN LOSS_3  16.00000073571648   TRAIN LOSS_4  16.400000042717675   TRAIN LOSS_5  17.199999987826452   TRAIN LOSS_6  18.80000176538318
# EPOCH  3932  | TRAIN LOSS_1  14.400000204551077   TRAIN LOSS_2  13.600002516024583   TRAIN LOSS_3  16.000000735537704   TRAIN LOSS_4  16.40000004270785   TRAIN LOSS_5  17.199999987823798   TRAIN LOSS_6  18.800001764943026
# EPOCH  3933  | TRAIN LOSS_1  14.400000204508412   TRAIN LOSS_2  13.600002514488892   TRAIN LOSS_3  16.00000073535904   TRAIN LOSS_4  16.40000004269803   TRAIN LOSS_5  17.199999987821144   TRAIN LOSS_6  18.80000176450308
# EPOCH  3934  | TRAIN LOSS_1  14.400000204465773   TRAIN LOSS_2  13.600002512955353   TRAIN LOSS_3  16.000000735180485   TRAIN LOSS_4  16.400000042688212   TRAIN LOSS_5  17.199999987818487   TRAIN LOSS_6  18.800001764063346
# EPOCH  3935  | TRAIN LOSS_1  14.400000204423154   TRAIN LOSS_2  13.600002511423963   TRAIN LOSS_3  16.000000735002036   TRAIN LOSS_4  16.400000042678396   TRAIN LOSS_5  17.19999998781583   TRAIN LOSS_6  18.80000176362382
# EPOCH  3936  | TRAIN LOSS_1  14.40000020438056   TRAIN LOSS_2  13.600002509894711   TRAIN LOSS_3  16.000000734823693   TRAIN LOSS_4  16.400000042668594   TRAIN LOSS_5  17.199999987813175   TRAIN LOSS_6  18.8000017631845
# EPOCH  3937  | TRAIN LOSS_1  14.40000020433799   TRAIN LOSS_2  13.600002508367595   TRAIN LOSS_3  16.000000734645464   TRAIN LOSS_4  16.40000004265879   TRAIN LOSS_5  17.199999987810514   TRAIN LOSS_6  18.800001762745396
# EPOCH  3938  | TRAIN LOSS_1  14.400000204295443   TRAIN LOSS_2  13.60000250684261   TRAIN LOSS_3  16.000000734467342   TRAIN LOSS_4  16.40000004264899   TRAIN LOSS_5  17.199999987807853   TRAIN LOSS_6  18.800001762306497
# EPOCH  3939  | TRAIN LOSS_1  14.400000204252919   TRAIN LOSS_2  13.600002505319756   TRAIN LOSS_3  16.000000734289323   TRAIN LOSS_4  16.4000000426392   TRAIN LOSS_5  17.199999987805192   TRAIN LOSS_6  18.800001761867808
# EPOCH  3940  | TRAIN LOSS_1  14.400000204210418   TRAIN LOSS_2  13.600002503799024   TRAIN LOSS_3  16.000000734111417   TRAIN LOSS_4  16.40000004262941   TRAIN LOSS_5  17.19999998780253   TRAIN LOSS_6  18.800001761429325
# EPOCH  3941  | TRAIN LOSS_1  14.400000204167942   TRAIN LOSS_2  13.60000250228041   TRAIN LOSS_3  16.000000733933618   TRAIN LOSS_4  16.40000004261963   TRAIN LOSS_5  17.199999987799867   TRAIN LOSS_6  18.800001760991055
# EPOCH  3942  | TRAIN LOSS_1  14.40000020412549   TRAIN LOSS_2  13.60000250076391   TRAIN LOSS_3  16.000000733755925   TRAIN LOSS_4  16.400000042609854   TRAIN LOSS_5  17.199999987797202   TRAIN LOSS_6  18.80000176055299
# EPOCH  3943  | TRAIN LOSS_1  14.40000020408306   TRAIN LOSS_2  13.600002499249522   TRAIN LOSS_3  16.00000073357834   TRAIN LOSS_4  16.400000042600077   TRAIN LOSS_5  17.199999987794534   TRAIN LOSS_6  18.800001760115137
# EPOCH  3944  | TRAIN LOSS_1  14.400000204040655   TRAIN LOSS_2  13.600002497737236   TRAIN LOSS_3  16.000000733400864   TRAIN LOSS_4  16.40000004259031   TRAIN LOSS_5  17.19999998779187   TRAIN LOSS_6  18.80000175967749
# EPOCH  3945  | TRAIN LOSS_1  14.400000203998271   TRAIN LOSS_2  13.600002496227054   TRAIN LOSS_3  16.000000733223494   TRAIN LOSS_4  16.400000042580544   TRAIN LOSS_5  17.1999999877892   TRAIN LOSS_6  18.80000175924005
# EPOCH  3946  | TRAIN LOSS_1  14.400000203955912   TRAIN LOSS_2  13.600002494718968   TRAIN LOSS_3  16.000000733046228   TRAIN LOSS_4  16.400000042570785   TRAIN LOSS_5  17.199999987786533   TRAIN LOSS_6  18.80000175880282
# EPOCH  3947  | TRAIN LOSS_1  14.400000203913574   TRAIN LOSS_2  13.600002493212969   TRAIN LOSS_3  16.000000732869076   TRAIN LOSS_4  16.400000042561032   TRAIN LOSS_5  17.199999987783862   TRAIN LOSS_6  18.8000017583658
# EPOCH  3948  | TRAIN LOSS_1  14.400000203871262   TRAIN LOSS_2  13.60000249170906   TRAIN LOSS_3  16.000000732692026   TRAIN LOSS_4  16.40000004255128   TRAIN LOSS_5  17.19999998778119   TRAIN LOSS_6  18.800001757928978
# EPOCH  3949  | TRAIN LOSS_1  14.400000203828972   TRAIN LOSS_2  13.600002490207237   TRAIN LOSS_3  16.000000732515083   TRAIN LOSS_4  16.400000042541542   TRAIN LOSS_5  17.199999987778515   TRAIN LOSS_6  18.800001757492375
# EPOCH  3950  | TRAIN LOSS_1  14.400000203786703   TRAIN LOSS_2  13.600002488707489   TRAIN LOSS_3  16.000000732338247   TRAIN LOSS_4  16.400000042531797   TRAIN LOSS_5  17.19999998777584   TRAIN LOSS_6  18.800001757055973
# EPOCH  3951  | TRAIN LOSS_1  14.40000020374446   TRAIN LOSS_2  13.600002487209817   TRAIN LOSS_3  16.00000073216152   TRAIN LOSS_4  16.40000004252206   TRAIN LOSS_5  17.199999987773165   TRAIN LOSS_6  18.80000175661978
# EPOCH  3952  | TRAIN LOSS_1  14.400000203702243   TRAIN LOSS_2  13.600002485714214   TRAIN LOSS_3  16.000000731984898   TRAIN LOSS_4  16.400000042512332   TRAIN LOSS_5  17.19999998777049   TRAIN LOSS_6  18.800001756183793
# EPOCH  3953  | TRAIN LOSS_1  14.400000203660046   TRAIN LOSS_2  13.600002484220676   TRAIN LOSS_3  16.00000073180838   TRAIN LOSS_4  16.400000042502604   TRAIN LOSS_5  17.199999987767814   TRAIN LOSS_6  18.800001755748013
# EPOCH  3954  | TRAIN LOSS_1  14.400000203617873   TRAIN LOSS_2  13.6000024827292   TRAIN LOSS_3  16.000000731631978   TRAIN LOSS_4  16.400000042492884   TRAIN LOSS_5  17.199999987765132   TRAIN LOSS_6  18.800001755312444
# EPOCH  3955  | TRAIN LOSS_1  14.40000020357572   TRAIN LOSS_2  13.60000248123978   TRAIN LOSS_3  16.00000073145567   TRAIN LOSS_4  16.400000042483168   TRAIN LOSS_5  17.199999987762453   TRAIN LOSS_6  18.80000175487708
# EPOCH  3956  | TRAIN LOSS_1  14.400000203533594   TRAIN LOSS_2  13.600002479752414   TRAIN LOSS_3  16.000000731279474   TRAIN LOSS_4  16.400000042473458   TRAIN LOSS_5  17.199999987759774   TRAIN LOSS_6  18.800001754441915
# EPOCH  3957  | TRAIN LOSS_1  14.40000020349149   TRAIN LOSS_2  13.600002478267095   TRAIN LOSS_3  16.000000731103384   TRAIN LOSS_4  16.40000004246375   TRAIN LOSS_5  17.19999998775709   TRAIN LOSS_6  18.800001754006963
# EPOCH  3958  | TRAIN LOSS_1  14.400000203449412   TRAIN LOSS_2  13.600002476783823   TRAIN LOSS_3  16.0000007309274   TRAIN LOSS_4  16.400000042454046   TRAIN LOSS_5  17.199999987754406   TRAIN LOSS_6  18.800001753572214
# EPOCH  3959  | TRAIN LOSS_1  14.400000203407354   TRAIN LOSS_2  13.600002475302585   TRAIN LOSS_3  16.00000073075152   TRAIN LOSS_4  16.400000042444347   TRAIN LOSS_5  17.19999998775172   TRAIN LOSS_6  18.800001753137675
# EPOCH  3960  | TRAIN LOSS_1  14.400000203365318   TRAIN LOSS_2  13.600002473823386   TRAIN LOSS_3  16.000000730575746   TRAIN LOSS_4  16.40000004243466   TRAIN LOSS_5  17.199999987749035   TRAIN LOSS_6  18.80000175270334
# EPOCH  3961  | TRAIN LOSS_1  14.400000203323305   TRAIN LOSS_2  13.600002472346215   TRAIN LOSS_3  16.00000073040008   TRAIN LOSS_4  16.400000042424967   TRAIN LOSS_5  17.19999998774635   TRAIN LOSS_6  18.80000175226921
# EPOCH  3962  | TRAIN LOSS_1  14.400000203281317   TRAIN LOSS_2  13.600002470871075   TRAIN LOSS_3  16.000000730224517   TRAIN LOSS_4  16.400000042415282   TRAIN LOSS_5  17.19999998774366   TRAIN LOSS_6  18.80000175183529
# EPOCH  3963  | TRAIN LOSS_1  14.40000020323935   TRAIN LOSS_2  13.600002469397955   TRAIN LOSS_3  16.00000073004906   TRAIN LOSS_4  16.400000042405605   TRAIN LOSS_5  17.199999987740973   TRAIN LOSS_6  18.80000175140157
# EPOCH  3964  | TRAIN LOSS_1  14.400000203197408   TRAIN LOSS_2  13.600002467926856   TRAIN LOSS_3  16.000000729873708   TRAIN LOSS_4  16.40000004239593   TRAIN LOSS_5  17.19999998773828   TRAIN LOSS_6  18.800001750968054
# EPOCH  3965  | TRAIN LOSS_1  14.40000020315549   TRAIN LOSS_2  13.600002466457767   TRAIN LOSS_3  16.00000072969846   TRAIN LOSS_4  16.40000004238626   TRAIN LOSS_5  17.199999987735588   TRAIN LOSS_6  18.800001750534747
# EPOCH  3966  | TRAIN LOSS_1  14.400000203113592   TRAIN LOSS_2  13.600002464990691   TRAIN LOSS_3  16.000000729523318   TRAIN LOSS_4  16.400000042376597   TRAIN LOSS_5  17.199999987732895   TRAIN LOSS_6  18.800001750101647
# EPOCH  3967  | TRAIN LOSS_1  14.400000203071718   TRAIN LOSS_2  13.600002463525621   TRAIN LOSS_3  16.000000729348283   TRAIN LOSS_4  16.400000042366937   TRAIN LOSS_5  17.1999999877302   TRAIN LOSS_6  18.800001749668745
# EPOCH  3968  | TRAIN LOSS_1  14.400000203029867   TRAIN LOSS_2  13.600002462062552   TRAIN LOSS_3  16.000000729173347   TRAIN LOSS_4  16.40000004235728   TRAIN LOSS_5  17.199999987727505   TRAIN LOSS_6  18.800001749236053
# EPOCH  3969  | TRAIN LOSS_1  14.40000020298804   TRAIN LOSS_2  13.600002460601479   TRAIN LOSS_3  16.000000728998522   TRAIN LOSS_4  16.40000004234763   TRAIN LOSS_5  17.199999987724812   TRAIN LOSS_6  18.800001748803563
# EPOCH  3970  | TRAIN LOSS_1  14.400000202946234   TRAIN LOSS_2  13.600002459142399   TRAIN LOSS_3  16.0000007288238   TRAIN LOSS_4  16.400000042337986   TRAIN LOSS_5  17.199999987722112   TRAIN LOSS_6  18.80000174837128
# EPOCH  3971  | TRAIN LOSS_1  14.400000202904451   TRAIN LOSS_2  13.60000245768531   TRAIN LOSS_3  16.000000728649177   TRAIN LOSS_4  16.400000042328344   TRAIN LOSS_5  17.199999987719416   TRAIN LOSS_6  18.800001747939202
# EPOCH  3972  | TRAIN LOSS_1  14.40000020286269   TRAIN LOSS_2  13.600002456230206   TRAIN LOSS_3  16.000000728474667   TRAIN LOSS_4  16.40000004231871   TRAIN LOSS_5  17.199999987716716   TRAIN LOSS_6  18.800001747507324
# EPOCH  3973  | TRAIN LOSS_1  14.400000202820957   TRAIN LOSS_2  13.60000245477708   TRAIN LOSS_3  16.000000728300257   TRAIN LOSS_4  16.400000042309077   TRAIN LOSS_5  17.199999987714012   TRAIN LOSS_6  18.800001747075655
# EPOCH  3974  | TRAIN LOSS_1  14.400000202779243   TRAIN LOSS_2  13.600002453325933   TRAIN LOSS_3  16.000000728125947   TRAIN LOSS_4  16.400000042299446   TRAIN LOSS_5  17.199999987711312   TRAIN LOSS_6  18.800001746644185
# EPOCH  3975  | TRAIN LOSS_1  14.40000020273755   TRAIN LOSS_2  13.600002451876758   TRAIN LOSS_3  16.00000072795175   TRAIN LOSS_4  16.400000042289825   TRAIN LOSS_5  17.199999987708605   TRAIN LOSS_6  18.80000174621292
# EPOCH  3976  | TRAIN LOSS_1  14.400000202695882   TRAIN LOSS_2  13.600002450429553   TRAIN LOSS_3  16.000000727777653   TRAIN LOSS_4  16.400000042280205   TRAIN LOSS_5  17.1999999877059   TRAIN LOSS_6  18.80000174578186
# EPOCH  3977  | TRAIN LOSS_1  14.400000202654237   TRAIN LOSS_2  13.600002448984313   TRAIN LOSS_3  16.000000727603656   TRAIN LOSS_4  16.400000042270594   TRAIN LOSS_5  17.199999987703194   TRAIN LOSS_6  18.800001745351004
# EPOCH  3978  | TRAIN LOSS_1  14.400000202612613   TRAIN LOSS_2  13.60000244754103   TRAIN LOSS_3  16.000000727429768   TRAIN LOSS_4  16.400000042260984   TRAIN LOSS_5  17.199999987700487   TRAIN LOSS_6  18.800001744920344
# EPOCH  3979  | TRAIN LOSS_1  14.400000202571016   TRAIN LOSS_2  13.600002446099705   TRAIN LOSS_3  16.00000072725598   TRAIN LOSS_4  16.40000004225138   TRAIN LOSS_5  17.19999998769778   TRAIN LOSS_6  18.800001744489897
# EPOCH  3980  | TRAIN LOSS_1  14.400000202529435   TRAIN LOSS_2  13.60000244466033   TRAIN LOSS_3  16.000000727082295   TRAIN LOSS_4  16.40000004224178   TRAIN LOSS_5  17.199999987695072   TRAIN LOSS_6  18.80000174405965
# EPOCH  3981  | TRAIN LOSS_1  14.400000202487883   TRAIN LOSS_2  13.600002443222909   TRAIN LOSS_3  16.000000726908716   TRAIN LOSS_4  16.400000042232186   TRAIN LOSS_5  17.199999987692358   TRAIN LOSS_6  18.8000017436296
# EPOCH  3982  | TRAIN LOSS_1  14.400000202446346   TRAIN LOSS_2  13.60000244178743   TRAIN LOSS_3  16.00000072673524   TRAIN LOSS_4  16.400000042222594   TRAIN LOSS_5  17.199999987689647   TRAIN LOSS_6  18.800001743199758
# EPOCH  3983  | TRAIN LOSS_1  14.40000020240484   TRAIN LOSS_2  13.600002440353887   TRAIN LOSS_3  16.00000072656187   TRAIN LOSS_4  16.400000042213012   TRAIN LOSS_5  17.199999987686933   TRAIN LOSS_6  18.800001742770117
# EPOCH  3984  | TRAIN LOSS_1  14.400000202363353   TRAIN LOSS_2  13.600002438922285   TRAIN LOSS_3  16.0000007263886   TRAIN LOSS_4  16.40000004220343   TRAIN LOSS_5  17.19999998768422   TRAIN LOSS_6  18.80000174234068
# EPOCH  3985  | TRAIN LOSS_1  14.400000202321888   TRAIN LOSS_2  13.600002437492615   TRAIN LOSS_3  16.000000726215426   TRAIN LOSS_4  16.400000042193856   TRAIN LOSS_5  17.199999987681505   TRAIN LOSS_6  18.800001741911448
# EPOCH  3986  | TRAIN LOSS_1  14.400000202280447   TRAIN LOSS_2  13.60000243606487   TRAIN LOSS_3  16.000000726042366   TRAIN LOSS_4  16.40000004218428   TRAIN LOSS_5  17.199999987678787   TRAIN LOSS_6  18.800001741482415
# EPOCH  3987  | TRAIN LOSS_1  14.400000202239024   TRAIN LOSS_2  13.600002434639052   TRAIN LOSS_3  16.000000725869405   TRAIN LOSS_4  16.400000042174714   TRAIN LOSS_5  17.19999998767607   TRAIN LOSS_6  18.80000174105358
# EPOCH  3988  | TRAIN LOSS_1  14.400000202197628   TRAIN LOSS_2  13.600002433215156   TRAIN LOSS_3  16.000000725696545   TRAIN LOSS_4  16.400000042165154   TRAIN LOSS_5  17.19999998767335   TRAIN LOSS_6  18.80000174062495
# EPOCH  3989  | TRAIN LOSS_1  14.400000202156255   TRAIN LOSS_2  13.600002431793175   TRAIN LOSS_3  16.000000725523787   TRAIN LOSS_4  16.400000042155593   TRAIN LOSS_5  17.19999998767063   TRAIN LOSS_6  18.800001740196524
# EPOCH  3990  | TRAIN LOSS_1  14.400000202114905   TRAIN LOSS_2  13.600002430373104   TRAIN LOSS_3  16.000000725351136   TRAIN LOSS_4  16.40000004214604   TRAIN LOSS_5  17.19999998766791   TRAIN LOSS_6  18.800001739768298
# EPOCH  3991  | TRAIN LOSS_1  14.400000202073574   TRAIN LOSS_2  13.600002428954943   TRAIN LOSS_3  16.00000072517858   TRAIN LOSS_4  16.40000004213649   TRAIN LOSS_5  17.199999987665187   TRAIN LOSS_6  18.80000173934027
# EPOCH  3992  | TRAIN LOSS_1  14.400000202032269   TRAIN LOSS_2  13.600002427538687   TRAIN LOSS_3  16.000000725006135   TRAIN LOSS_4  16.400000042126948   TRAIN LOSS_5  17.199999987662462   TRAIN LOSS_6  18.80000173891245
# EPOCH  3993  | TRAIN LOSS_1  14.40000020199098   TRAIN LOSS_2  13.60000242612433   TRAIN LOSS_3  16.000000724833786   TRAIN LOSS_4  16.40000004211741   TRAIN LOSS_5  17.199999987659737   TRAIN LOSS_6  18.800001738484827
# EPOCH  3994  | TRAIN LOSS_1  14.400000201949718   TRAIN LOSS_2  13.600002424711874   TRAIN LOSS_3  16.00000072466154   TRAIN LOSS_4  16.400000042107873   TRAIN LOSS_5  17.199999987657012   TRAIN LOSS_6  18.800001738057407
# EPOCH  3995  | TRAIN LOSS_1  14.40000020190848   TRAIN LOSS_2  13.600002423301309   TRAIN LOSS_3  16.0000007244894   TRAIN LOSS_4  16.400000042098345   TRAIN LOSS_5  17.199999987654284   TRAIN LOSS_6  18.800001737630183
# EPOCH  3996  | TRAIN LOSS_1  14.400000201867261   TRAIN LOSS_2  13.600002421892631   TRAIN LOSS_3  16.000000724317356   TRAIN LOSS_4  16.400000042088816   TRAIN LOSS_5  17.199999987651555   TRAIN LOSS_6  18.800001737203164
# EPOCH  3997  | TRAIN LOSS_1  14.400000201826066   TRAIN LOSS_2  13.600002420485842   TRAIN LOSS_3  16.000000724145416   TRAIN LOSS_4  16.4000000420793   TRAIN LOSS_5  17.199999987648823   TRAIN LOSS_6  18.800001736776345
# EPOCH  3998  | TRAIN LOSS_1  14.400000201784895   TRAIN LOSS_2  13.600002419080932   TRAIN LOSS_3  16.000000723973578   TRAIN LOSS_4  16.40000004206978   TRAIN LOSS_5  17.199999987646095   TRAIN LOSS_6  18.800001736349728
# EPOCH  3999  | TRAIN LOSS_1  14.400000201743742   TRAIN LOSS_2  13.6000024176779   TRAIN LOSS_3  16.00000072380184   TRAIN LOSS_4  16.40000004206027   TRAIN LOSS_5  17.19999998764336   TRAIN LOSS_6  18.800001735923306
# EPOCH  4000  | TRAIN LOSS_1  14.400000201702614   TRAIN LOSS_2  13.600002416276741   TRAIN LOSS_3  16.000000723630205   TRAIN LOSS_4  16.40000004205076   TRAIN LOSS_5  17.199999987640627   TRAIN LOSS_6  18.800001735497087
# EPOCH  4001  | TRAIN LOSS_1  14.40000020166151   TRAIN LOSS_2  13.600002414877451   TRAIN LOSS_3  16.000000723458676   TRAIN LOSS_4  16.400000042041256   TRAIN LOSS_5  17.19999998763789   TRAIN LOSS_6  18.80000173507107
# EPOCH  4002  | TRAIN LOSS_1  14.400000201620424   TRAIN LOSS_2  13.60000241348003   TRAIN LOSS_3  16.00000072328724   TRAIN LOSS_4  16.40000004203176   TRAIN LOSS_5  17.19999998763516   TRAIN LOSS_6  18.80000173464525
# EPOCH  4003  | TRAIN LOSS_1  14.400000201579365   TRAIN LOSS_2  13.60000241208447   TRAIN LOSS_3  16.000000723115907   TRAIN LOSS_4  16.400000042022263   TRAIN LOSS_5  17.199999987632417   TRAIN LOSS_6  18.80000173421963
# EPOCH  4004  | TRAIN LOSS_1  14.400000201538324   TRAIN LOSS_2  13.600002410690768   TRAIN LOSS_3  16.000000722944677   TRAIN LOSS_4  16.400000042012778   TRAIN LOSS_5  17.19999998762968   TRAIN LOSS_6  18.80000173379421
# EPOCH  4005  | TRAIN LOSS_1  14.40000020149731   TRAIN LOSS_2  13.600002409298924   TRAIN LOSS_3  16.000000722773546   TRAIN LOSS_4  16.400000042003292   TRAIN LOSS_5  17.199999987626942   TRAIN LOSS_6  18.80000173336899
# EPOCH  4006  | TRAIN LOSS_1  14.400000201456312   TRAIN LOSS_2  13.600002407908928   TRAIN LOSS_3  16.00000072260252   TRAIN LOSS_4  16.400000041993813   TRAIN LOSS_5  17.199999987624203   TRAIN LOSS_6  18.800001732943972
# EPOCH  4007  | TRAIN LOSS_1  14.400000201415342   TRAIN LOSS_2  13.600002406520781   TRAIN LOSS_3  16.000000722431587   TRAIN LOSS_4  16.400000041984335   TRAIN LOSS_5  17.19999998762146   TRAIN LOSS_6  18.800001732519153
# EPOCH  4008  | TRAIN LOSS_1  14.400000201374388   TRAIN LOSS_2  13.600002405134475   TRAIN LOSS_3  16.00000072226076   TRAIN LOSS_4  16.400000041974867   TRAIN LOSS_5  17.199999987618718   TRAIN LOSS_6  18.800001732094525
# EPOCH  4009  | TRAIN LOSS_1  14.40000020133346   TRAIN LOSS_2  13.600002403750011   TRAIN LOSS_3  16.00000072209004   TRAIN LOSS_4  16.4000000419654   TRAIN LOSS_5  17.19999998761597   TRAIN LOSS_6  18.800001731670104
# EPOCH  4010  | TRAIN LOSS_1  14.400000201292553   TRAIN LOSS_2  13.600002402367384   TRAIN LOSS_3  16.00000072191941   TRAIN LOSS_4  16.400000041955938   TRAIN LOSS_5  17.199999987613225   TRAIN LOSS_6  18.800001731245878
# EPOCH  4011  | TRAIN LOSS_1  14.400000201251668   TRAIN LOSS_2  13.600002400986586   TRAIN LOSS_3  16.000000721748883   TRAIN LOSS_4  16.40000004194648   TRAIN LOSS_5  17.199999987610475   TRAIN LOSS_6  18.800001730821855
# EPOCH  4012  | TRAIN LOSS_1  14.400000201210807   TRAIN LOSS_2  13.600002399607618   TRAIN LOSS_3  16.00000072157846   TRAIN LOSS_4  16.400000041937027   TRAIN LOSS_5  17.199999987607733   TRAIN LOSS_6  18.800001730398023
# EPOCH  4013  | TRAIN LOSS_1  14.400000201169965   TRAIN LOSS_2  13.600002398230476   TRAIN LOSS_3  16.00000072140813   TRAIN LOSS_4  16.400000041927576   TRAIN LOSS_5  17.19999998760498   TRAIN LOSS_6  18.800001729974394
# EPOCH  4014  | TRAIN LOSS_1  14.400000201129146   TRAIN LOSS_2  13.600002396855155   TRAIN LOSS_3  16.000000721237903   TRAIN LOSS_4  16.400000041918137   TRAIN LOSS_5  17.19999998760223   TRAIN LOSS_6  18.800001729550964
# EPOCH  4015  | TRAIN LOSS_1  14.400000201088352   TRAIN LOSS_2  13.60000239548165   TRAIN LOSS_3  16.000000721067778   TRAIN LOSS_4  16.400000041908697   TRAIN LOSS_5  17.199999987599476   TRAIN LOSS_6  18.80000172912773
# EPOCH  4016  | TRAIN LOSS_1  14.400000201047579   TRAIN LOSS_2  13.60000239410996   TRAIN LOSS_3  16.000000720897752   TRAIN LOSS_4  16.40000004189926   TRAIN LOSS_5  17.199999987596726   TRAIN LOSS_6  18.800001728704693
# EPOCH  4017  | TRAIN LOSS_1  14.400000201006824   TRAIN LOSS_2  13.600002392740084   TRAIN LOSS_3  16.00000072072782   TRAIN LOSS_4  16.400000041889832   TRAIN LOSS_5  17.19999998759397   TRAIN LOSS_6  18.800001728281856
# EPOCH  4018  | TRAIN LOSS_1  14.400000200966094   TRAIN LOSS_2  13.600002391372007   TRAIN LOSS_3  16.000000720558   TRAIN LOSS_4  16.400000041880404   TRAIN LOSS_5  17.199999987591216   TRAIN LOSS_6  18.800001727859218
# EPOCH  4019  | TRAIN LOSS_1  14.400000200925385   TRAIN LOSS_2  13.600002390005738   TRAIN LOSS_3  16.000000720388265   TRAIN LOSS_4  16.400000041870985   TRAIN LOSS_5  17.19999998758846   TRAIN LOSS_6  18.800001727436772
# EPOCH  4020  | TRAIN LOSS_1  14.4000002008847   TRAIN LOSS_2  13.600002388641268   TRAIN LOSS_3  16.00000072021864   TRAIN LOSS_4  16.400000041861567   TRAIN LOSS_5  17.199999987585702   TRAIN LOSS_6  18.800001727014525
# EPOCH  4021  | TRAIN LOSS_1  14.400000200844033   TRAIN LOSS_2  13.600002387278593   TRAIN LOSS_3  16.00000072004911   TRAIN LOSS_4  16.40000004185216   TRAIN LOSS_5  17.19999998758294   TRAIN LOSS_6  18.800001726592477
# EPOCH  4022  | TRAIN LOSS_1  14.400000200803394   TRAIN LOSS_2  13.60000238591771   TRAIN LOSS_3  16.00000071987968   TRAIN LOSS_4  16.40000004184275   TRAIN LOSS_5  17.19999998758018   TRAIN LOSS_6  18.800001726170628
# EPOCH  4023  | TRAIN LOSS_1  14.40000020076277   TRAIN LOSS_2  13.600002384558616   TRAIN LOSS_3  16.00000071971035   TRAIN LOSS_4  16.400000041833344   TRAIN LOSS_5  17.19999998757742   TRAIN LOSS_6  18.800001725748977
# EPOCH  4024  | TRAIN LOSS_1  14.400000200722172   TRAIN LOSS_2  13.600002383201309   TRAIN LOSS_3  16.000000719541116   TRAIN LOSS_4  16.400000041823947   TRAIN LOSS_5  17.199999987574657   TRAIN LOSS_6  18.800001725327515
# EPOCH  4025  | TRAIN LOSS_1  14.400000200681593   TRAIN LOSS_2  13.60000238184578   TRAIN LOSS_3  16.000000719371986   TRAIN LOSS_4  16.400000041814554   TRAIN LOSS_5  17.199999987571893   TRAIN LOSS_6  18.800001724906256
# EPOCH  4026  | TRAIN LOSS_1  14.400000200641037   TRAIN LOSS_2  13.600002380492032   TRAIN LOSS_3  16.00000071920295   TRAIN LOSS_4  16.400000041805164   TRAIN LOSS_5  17.19999998756913   TRAIN LOSS_6  18.800001724485192
# EPOCH  4027  | TRAIN LOSS_1  14.400000200600505   TRAIN LOSS_2  13.600002379140056   TRAIN LOSS_3  16.000000719034013   TRAIN LOSS_4  16.400000041795774   TRAIN LOSS_5  17.19999998756636   TRAIN LOSS_6  18.800001724064323
# EPOCH  4028  | TRAIN LOSS_1  14.40000020055999   TRAIN LOSS_2  13.600002377789849   TRAIN LOSS_3  16.000000718865174   TRAIN LOSS_4  16.400000041786395   TRAIN LOSS_5  17.199999987563594   TRAIN LOSS_6  18.80000172364365
# EPOCH  4029  | TRAIN LOSS_1  14.4000002005195   TRAIN LOSS_2  13.600002376441413   TRAIN LOSS_3  16.000000718696437   TRAIN LOSS_4  16.40000004177702   TRAIN LOSS_5  17.199999987560822   TRAIN LOSS_6  18.80000172322318
# EPOCH  4030  | TRAIN LOSS_1  14.400000200479031   TRAIN LOSS_2  13.600002375094737   TRAIN LOSS_3  16.000000718527797   TRAIN LOSS_4  16.400000041767647   TRAIN LOSS_5  17.19999998755805   TRAIN LOSS_6  18.800001722802897
# EPOCH  4031  | TRAIN LOSS_1  14.40000020043858   TRAIN LOSS_2  13.600002373749826   TRAIN LOSS_3  16.000000718359253   TRAIN LOSS_4  16.400000041758283   TRAIN LOSS_5  17.19999998755528   TRAIN LOSS_6  18.800001722382813
# EPOCH  4032  | TRAIN LOSS_1  14.400000200398157   TRAIN LOSS_2  13.600002372406667   TRAIN LOSS_3  16.00000071819081   TRAIN LOSS_4  16.400000041748918   TRAIN LOSS_5  17.19999998755251   TRAIN LOSS_6  18.800001721962925
# EPOCH  4033  | TRAIN LOSS_1  14.400000200357756   TRAIN LOSS_2  13.600002371065264   TRAIN LOSS_3  16.000000718022466   TRAIN LOSS_4  16.40000004173956   TRAIN LOSS_5  17.199999987549738   TRAIN LOSS_6  18.800001721543232
# EPOCH  4034  | TRAIN LOSS_1  14.400000200317374   TRAIN LOSS_2  13.60000236972561   TRAIN LOSS_3  16.00000071785422   TRAIN LOSS_4  16.400000041730205   TRAIN LOSS_5  17.19999998754696   TRAIN LOSS_6  18.80000172112374
# EPOCH  4035  | TRAIN LOSS_1  14.400000200277011   TRAIN LOSS_2  13.6000023683877   TRAIN LOSS_3  16.000000717686067   TRAIN LOSS_4  16.400000041720855   TRAIN LOSS_5  17.19999998754418   TRAIN LOSS_6  18.800001720704437
# EPOCH  4036  | TRAIN LOSS_1  14.40000020023667   TRAIN LOSS_2  13.600002367051536   TRAIN LOSS_3  16.000000717518017   TRAIN LOSS_4  16.40000004171151   TRAIN LOSS_5  17.199999987541407   TRAIN LOSS_6  18.80000172028533
# EPOCH  4037  | TRAIN LOSS_1  14.400000200196356   TRAIN LOSS_2  13.600002365717108   TRAIN LOSS_3  16.000000717350062   TRAIN LOSS_4  16.40000004170217   TRAIN LOSS_5  17.199999987538625   TRAIN LOSS_6  18.800001719866415
# EPOCH  4038  | TRAIN LOSS_1  14.400000200156057   TRAIN LOSS_2  13.60000236438442   TRAIN LOSS_3  16.000000717182203   TRAIN LOSS_4  16.400000041692834   TRAIN LOSS_5  17.199999987535847   TRAIN LOSS_6  18.8000017194477
# EPOCH  4039  | TRAIN LOSS_1  14.400000200115784   TRAIN LOSS_2  13.60000236305346   TRAIN LOSS_3  16.000000717014444   TRAIN LOSS_4  16.400000041683505   TRAIN LOSS_5  17.19999998753307   TRAIN LOSS_6  18.800001719029176
# EPOCH  4040  | TRAIN LOSS_1  14.400000200075533   TRAIN LOSS_2  13.600002361724231   TRAIN LOSS_3  16.000000716846785   TRAIN LOSS_4  16.400000041674176   TRAIN LOSS_5  17.199999987530283   TRAIN LOSS_6  18.80000171861085
# EPOCH  4041  | TRAIN LOSS_1  14.400000200035299   TRAIN LOSS_2  13.600002360396726   TRAIN LOSS_3  16.000000716679217   TRAIN LOSS_4  16.400000041664853   TRAIN LOSS_5  17.199999987527498   TRAIN LOSS_6  18.800001718192718
# EPOCH  4042  | TRAIN LOSS_1  14.400000199995091   TRAIN LOSS_2  13.600002359070945   TRAIN LOSS_3  16.000000716511753   TRAIN LOSS_4  16.400000041655534   TRAIN LOSS_5  17.199999987524713   TRAIN LOSS_6  18.80000171777478
# EPOCH  4043  | TRAIN LOSS_1  14.4000001999549   TRAIN LOSS_2  13.600002357746884   TRAIN LOSS_3  16.00000071634438   TRAIN LOSS_4  16.40000004164622   TRAIN LOSS_5  17.199999987521927   TRAIN LOSS_6  18.800001717357034
# EPOCH  4044  | TRAIN LOSS_1  14.400000199914734   TRAIN LOSS_2  13.600002356424534   TRAIN LOSS_3  16.000000716177105   TRAIN LOSS_4  16.40000004163691   TRAIN LOSS_5  17.199999987519142   TRAIN LOSS_6  18.800001716939484
# EPOCH  4045  | TRAIN LOSS_1  14.400000199874588   TRAIN LOSS_2  13.6000023551039   TRAIN LOSS_3  16.000000716009932   TRAIN LOSS_4  16.400000041627603   TRAIN LOSS_5  17.199999987516353   TRAIN LOSS_6  18.80000171652213
# EPOCH  4046  | TRAIN LOSS_1  14.400000199834466   TRAIN LOSS_2  13.60000235378497   TRAIN LOSS_3  16.00000071584285   TRAIN LOSS_4  16.400000041618306   TRAIN LOSS_5  17.19999998751356   TRAIN LOSS_6  18.800001716104966
# EPOCH  4047  | TRAIN LOSS_1  14.400000199794363   TRAIN LOSS_2  13.60000235246775   TRAIN LOSS_3  16.000000715675874   TRAIN LOSS_4  16.400000041609008   TRAIN LOSS_5  17.199999987510772   TRAIN LOSS_6  18.800001715687998
# EPOCH  4048  | TRAIN LOSS_1  14.40000019975428   TRAIN LOSS_2  13.600002351152227   TRAIN LOSS_3  16.000000715508985   TRAIN LOSS_4  16.400000041599718   TRAIN LOSS_5  17.199999987507976   TRAIN LOSS_6  18.80000171527122
# EPOCH  4049  | TRAIN LOSS_1  14.400000199714222   TRAIN LOSS_2  13.600002349838405   TRAIN LOSS_3  16.000000715342193   TRAIN LOSS_4  16.400000041590427   TRAIN LOSS_5  17.199999987505187   TRAIN LOSS_6  18.800001714854638
# EPOCH  4050  | TRAIN LOSS_1  14.400000199674185   TRAIN LOSS_2  13.60000234852628   TRAIN LOSS_3  16.000000715175503   TRAIN LOSS_4  16.400000041581148   TRAIN LOSS_5  17.199999987502387   TRAIN LOSS_6  18.80000171443825
# EPOCH  4051  | TRAIN LOSS_1  14.400000199634164   TRAIN LOSS_2  13.600002347215844   TRAIN LOSS_3  16.000000715008902   TRAIN LOSS_4  16.400000041571868   TRAIN LOSS_5  17.19999998749959   TRAIN LOSS_6  18.800001714022052
# EPOCH  4052  | TRAIN LOSS_1  14.400000199594169   TRAIN LOSS_2  13.600002345907097   TRAIN LOSS_3  16.000000714842404   TRAIN LOSS_4  16.400000041562592   TRAIN LOSS_5  17.199999987496795   TRAIN LOSS_6  18.80000171360605
# EPOCH  4053  | TRAIN LOSS_1  14.400000199554196   TRAIN LOSS_2  13.600002344600034   TRAIN LOSS_3  16.000000714676   TRAIN LOSS_4  16.400000041553326   TRAIN LOSS_5  17.199999987493996   TRAIN LOSS_6  18.80000171319024
# EPOCH  4054  | TRAIN LOSS_1  14.400000199514242   TRAIN LOSS_2  13.600002343294653   TRAIN LOSS_3  16.00000071450969   TRAIN LOSS_4  16.400000041544057   TRAIN LOSS_5  17.199999987491196   TRAIN LOSS_6  18.800001712774623
# EPOCH  4055  | TRAIN LOSS_1  14.40000019947431   TRAIN LOSS_2  13.600002341990953   TRAIN LOSS_3  16.00000071434348   TRAIN LOSS_4  16.400000041534796   TRAIN LOSS_5  17.199999987488393   TRAIN LOSS_6  18.8000017123592
# EPOCH  4056  | TRAIN LOSS_1  14.400000199434396   TRAIN LOSS_2  13.600002340688926   TRAIN LOSS_3  16.000000714177364   TRAIN LOSS_4  16.40000004152554   TRAIN LOSS_5  17.19999998748559   TRAIN LOSS_6  18.800001711943967
# EPOCH  4057  | TRAIN LOSS_1  14.400000199394508   TRAIN LOSS_2  13.60000233938857   TRAIN LOSS_3  16.000000714011342   TRAIN LOSS_4  16.40000004151629   TRAIN LOSS_5  17.19999998748279   TRAIN LOSS_6  18.800001711528928
# EPOCH  4058  | TRAIN LOSS_1  14.40000019935464   TRAIN LOSS_2  13.600002338089883   TRAIN LOSS_3  16.000000713845417   TRAIN LOSS_4  16.400000041507038   TRAIN LOSS_5  17.199999987479984   TRAIN LOSS_6  18.80000171111408
# EPOCH  4059  | TRAIN LOSS_1  14.400000199314793   TRAIN LOSS_2  13.600002336792864   TRAIN LOSS_3  16.000000713679587   TRAIN LOSS_4  16.400000041497798   TRAIN LOSS_5  17.199999987477177   TRAIN LOSS_6  18.800001710699426
# EPOCH  4060  | TRAIN LOSS_1  14.400000199274967   TRAIN LOSS_2  13.600002335497503   TRAIN LOSS_3  16.00000071351385   TRAIN LOSS_4  16.40000004148856   TRAIN LOSS_5  17.19999998747437   TRAIN LOSS_6  18.800001710284963
# EPOCH  4061  | TRAIN LOSS_1  14.400000199235157   TRAIN LOSS_2  13.600002334203802   TRAIN LOSS_3  16.000000713348214   TRAIN LOSS_4  16.400000041479323   TRAIN LOSS_5  17.199999987471564   TRAIN LOSS_6  18.80000170987069
# EPOCH  4062  | TRAIN LOSS_1  14.400000199195375   TRAIN LOSS_2  13.600002332911757   TRAIN LOSS_3  16.00000071318267   TRAIN LOSS_4  16.400000041470093   TRAIN LOSS_5  17.19999998746875   TRAIN LOSS_6  18.80000170945661
# EPOCH  4063  | TRAIN LOSS_1  14.400000199155613   TRAIN LOSS_2  13.600002331621365   TRAIN LOSS_3  16.000000713017222   TRAIN LOSS_4  16.400000041460867   TRAIN LOSS_5  17.19999998746594   TRAIN LOSS_6  18.80000170904272
# EPOCH  4064  | TRAIN LOSS_1  14.40000019911587   TRAIN LOSS_2  13.600002330332623   TRAIN LOSS_3  16.000000712851868   TRAIN LOSS_4  16.400000041451644   TRAIN LOSS_5  17.199999987463126   TRAIN LOSS_6  18.800001708629022
# EPOCH  4065  | TRAIN LOSS_1  14.40000019907615   TRAIN LOSS_2  13.600002329045523   TRAIN LOSS_3  16.00000071268661   TRAIN LOSS_4  16.40000004144243   TRAIN LOSS_5  17.199999987460313   TRAIN LOSS_6  18.800001708215518
# EPOCH  4066  | TRAIN LOSS_1  14.40000019903645   TRAIN LOSS_2  13.60000232776007   TRAIN LOSS_3  16.000000712521445   TRAIN LOSS_4  16.400000041433216   TRAIN LOSS_5  17.199999987457495   TRAIN LOSS_6  18.800001707802203
# EPOCH  4067  | TRAIN LOSS_1  14.400000198996773   TRAIN LOSS_2  13.600002326476254   TRAIN LOSS_3  16.00000071235638   TRAIN LOSS_4  16.400000041424008   TRAIN LOSS_5  17.19999998745468   TRAIN LOSS_6  18.80000170738908
# EPOCH  4068  | TRAIN LOSS_1  14.400000198957116   TRAIN LOSS_2  13.600002325194078   TRAIN LOSS_3  16.0000007121914   TRAIN LOSS_4  16.400000041414803   TRAIN LOSS_5  17.199999987451864   TRAIN LOSS_6  18.800001706976147
# EPOCH  4069  | TRAIN LOSS_1  14.400000198917477   TRAIN LOSS_2  13.600002323913529   TRAIN LOSS_3  16.000000712026527   TRAIN LOSS_4  16.4000000414056   TRAIN LOSS_5  17.199999987449043   TRAIN LOSS_6  18.800001706563403
# EPOCH  4070  | TRAIN LOSS_1  14.400000198877862   TRAIN LOSS_2  13.600002322634612   TRAIN LOSS_3  16.00000071186174   TRAIN LOSS_4  16.400000041396407   TRAIN LOSS_5  17.199999987446226   TRAIN LOSS_6  18.80000170615085
# EPOCH  4071  | TRAIN LOSS_1  14.400000198838265   TRAIN LOSS_2  13.600002321357323   TRAIN LOSS_3  16.00000071169705   TRAIN LOSS_4  16.40000004138722   TRAIN LOSS_5  17.1999999874434   TRAIN LOSS_6  18.800001705738488
# EPOCH  4072  | TRAIN LOSS_1  14.400000198798693   TRAIN LOSS_2  13.600002320081657   TRAIN LOSS_3  16.000000711532458   TRAIN LOSS_4  16.40000004137803   TRAIN LOSS_5  17.19999998744058   TRAIN LOSS_6  18.800001705326316
# EPOCH  4073  | TRAIN LOSS_1  14.40000019875914   TRAIN LOSS_2  13.600002318807615   TRAIN LOSS_3  16.000000711367953   TRAIN LOSS_4  16.40000004136885   TRAIN LOSS_5  17.199999987437756   TRAIN LOSS_6  18.80000170491434
# EPOCH  4074  | TRAIN LOSS_1  14.400000198719605   TRAIN LOSS_2  13.600002317535186   TRAIN LOSS_3  16.000000711203548   TRAIN LOSS_4  16.400000041359668   TRAIN LOSS_5  17.19999998743493   TRAIN LOSS_6  18.80000170450255
# EPOCH  4075  | TRAIN LOSS_1  14.400000198680095   TRAIN LOSS_2  13.600002316264371   TRAIN LOSS_3  16.00000071103923   TRAIN LOSS_4  16.4000000413505   TRAIN LOSS_5  17.199999987432104   TRAIN LOSS_6  18.800001704090946
# EPOCH  4076  | TRAIN LOSS_1  14.400000198640607   TRAIN LOSS_2  13.60000231499517   TRAIN LOSS_3  16.000000710875014   TRAIN LOSS_4  16.40000004134133   TRAIN LOSS_5  17.199999987429276   TRAIN LOSS_6  18.800001703679534
# EPOCH  4077  | TRAIN LOSS_1  14.400000198601134   TRAIN LOSS_2  13.600002313727575   TRAIN LOSS_3  16.000000710710886   TRAIN LOSS_4  16.40000004133216   TRAIN LOSS_5  17.199999987426445   TRAIN LOSS_6  18.800001703268315
# EPOCH  4078  | TRAIN LOSS_1  14.400000198561688   TRAIN LOSS_2  13.600002312461584   TRAIN LOSS_3  16.000000710546857   TRAIN LOSS_4  16.400000041323   TRAIN LOSS_5  17.199999987423617   TRAIN LOSS_6  18.80000170285728
# EPOCH  4079  | TRAIN LOSS_1  14.40000019852226   TRAIN LOSS_2  13.600002311197196   TRAIN LOSS_3  16.000000710382917   TRAIN LOSS_4  16.400000041313845   TRAIN LOSS_5  17.199999987420785   TRAIN LOSS_6  18.80000170244644
# EPOCH  4080  | TRAIN LOSS_1  14.400000198482852   TRAIN LOSS_2  13.600002309934407   TRAIN LOSS_3  16.000000710219076   TRAIN LOSS_4  16.400000041304693   TRAIN LOSS_5  17.199999987417954   TRAIN LOSS_6  18.80000170203579
# EPOCH  4081  | TRAIN LOSS_1  14.400000198443465   TRAIN LOSS_2  13.600002308673211   TRAIN LOSS_3  16.000000710055325   TRAIN LOSS_4  16.400000041295545   TRAIN LOSS_5  17.19999998741512   TRAIN LOSS_6  18.800001701625323
# EPOCH  4082  | TRAIN LOSS_1  14.400000198404097   TRAIN LOSS_2  13.60000230741361   TRAIN LOSS_3  16.000000709891665   TRAIN LOSS_4  16.4000000412864   TRAIN LOSS_5  17.199999987412284   TRAIN LOSS_6  18.80000170121505
# EPOCH  4083  | TRAIN LOSS_1  14.400000198364756   TRAIN LOSS_2  13.600002306155599   TRAIN LOSS_3  16.000000709728106   TRAIN LOSS_4  16.40000004127726   TRAIN LOSS_5  17.19999998740945   TRAIN LOSS_6  18.800001700804962
# EPOCH  4084  | TRAIN LOSS_1  14.400000198325433   TRAIN LOSS_2  13.600002304899173   TRAIN LOSS_3  16.00000070956463   TRAIN LOSS_4  16.400000041268125   TRAIN LOSS_5  17.199999987406606   TRAIN LOSS_6  18.800001700395065
# EPOCH  4085  | TRAIN LOSS_1  14.400000198286127   TRAIN LOSS_2  13.600002303644327   TRAIN LOSS_3  16.000000709401256   TRAIN LOSS_4  16.400000041259   TRAIN LOSS_5  17.199999987403768   TRAIN LOSS_6  18.800001699985355
# EPOCH  4086  | TRAIN LOSS_1  14.400000198246843   TRAIN LOSS_2  13.600002302391067   TRAIN LOSS_3  16.00000070923797   TRAIN LOSS_4  16.400000041249868   TRAIN LOSS_5  17.19999998740093   TRAIN LOSS_6  18.800001699575837
# EPOCH  4087  | TRAIN LOSS_1  14.400000198207582   TRAIN LOSS_2  13.60000230113938   TRAIN LOSS_3  16.00000070907478   TRAIN LOSS_4  16.400000041240748   TRAIN LOSS_5  17.199999987398087   TRAIN LOSS_6  18.800001699166504
# EPOCH  4088  | TRAIN LOSS_1  14.400000198168339   TRAIN LOSS_2  13.600002299889269   TRAIN LOSS_3  16.000000708911678   TRAIN LOSS_4  16.40000004123163   TRAIN LOSS_5  17.19999998739524   TRAIN LOSS_6  18.80000169875736
# EPOCH  4089  | TRAIN LOSS_1  14.40000019812912   TRAIN LOSS_2  13.600002298640728   TRAIN LOSS_3  16.000000708748672   TRAIN LOSS_4  16.400000041222516   TRAIN LOSS_5  17.199999987392395   TRAIN LOSS_6  18.800001698348407
# EPOCH  4090  | TRAIN LOSS_1  14.400000198089922   TRAIN LOSS_2  13.600002297393758   TRAIN LOSS_3  16.000000708585763   TRAIN LOSS_4  16.400000041213406   TRAIN LOSS_5  17.199999987389553   TRAIN LOSS_6  18.80000169793964
# EPOCH  4091  | TRAIN LOSS_1  14.400000198050742   TRAIN LOSS_2  13.600002296148352   TRAIN LOSS_3  16.000000708422938   TRAIN LOSS_4  16.4000000412043   TRAIN LOSS_5  17.199999987386708   TRAIN LOSS_6  18.800001697531055
# EPOCH  4092  | TRAIN LOSS_1  14.400000198011579   TRAIN LOSS_2  13.600002294904504   TRAIN LOSS_3  16.00000070826021   TRAIN LOSS_4  16.400000041195202   TRAIN LOSS_5  17.19999998738386   TRAIN LOSS_6  18.800001697122664
# EPOCH  4093  | TRAIN LOSS_1  14.400000197972442   TRAIN LOSS_2  13.60000229366222   TRAIN LOSS_3  16.000000708097577   TRAIN LOSS_4  16.400000041186104   TRAIN LOSS_5  17.19999998738101   TRAIN LOSS_6  18.800001696714464
# EPOCH  4094  | TRAIN LOSS_1  14.400000197933323   TRAIN LOSS_2  13.60000229242149   TRAIN LOSS_3  16.000000707935033   TRAIN LOSS_4  16.400000041177012   TRAIN LOSS_5  17.199999987378156   TRAIN LOSS_6  18.800001696306445
# EPOCH  4095  | TRAIN LOSS_1  14.40000019789423   TRAIN LOSS_2  13.600002291182312   TRAIN LOSS_3  16.000000707772582   TRAIN LOSS_4  16.40000004116792   TRAIN LOSS_5  17.199999987375303   TRAIN LOSS_6  18.800001695898615
# EPOCH  4096  | TRAIN LOSS_1  14.40000019785515   TRAIN LOSS_2  13.600002289944689   TRAIN LOSS_3  16.000000707610226   TRAIN LOSS_4  16.40000004115884   TRAIN LOSS_5  17.19999998737245   TRAIN LOSS_6  18.800001695490973
# EPOCH  4097  | TRAIN LOSS_1  14.400000197816095   TRAIN LOSS_2  13.600002288708609   TRAIN LOSS_3  16.000000707447956   TRAIN LOSS_4  16.40000004114976   TRAIN LOSS_5  17.199999987369598   TRAIN LOSS_6  18.800001695083516
# EPOCH  4098  | TRAIN LOSS_1  14.40000019777706   TRAIN LOSS_2  13.600002287474075   TRAIN LOSS_3  16.000000707285785   TRAIN LOSS_4  16.40000004114069   TRAIN LOSS_5  17.19999998736674   TRAIN LOSS_6  18.800001694676247
# EPOCH  4099  | TRAIN LOSS_1  14.400000197738043   TRAIN LOSS_2  13.600002286241079   TRAIN LOSS_3  16.0000007071237   TRAIN LOSS_4  16.400000041131616   TRAIN LOSS_5  17.199999987363885   TRAIN LOSS_6  18.800001694269163
# EPOCH  4100  | TRAIN LOSS_1  14.400000197699049   TRAIN LOSS_2  13.600002285009623   TRAIN LOSS_3  16.000000706961707   TRAIN LOSS_4  16.40000004112255   TRAIN LOSS_5  17.199999987361025   TRAIN LOSS_6  18.800001693862274
# EPOCH  4101  | TRAIN LOSS_1  14.400000197660074   TRAIN LOSS_2  13.600002283779705   TRAIN LOSS_3  16.00000070679981   TRAIN LOSS_4  16.40000004111349   TRAIN LOSS_5  17.199999987358165   TRAIN LOSS_6  18.800001693455563
# ...
# EPOCH  8813  | TRAIN LOSS_1  14.4000001120482   TRAIN LOSS_2  13.600000763797615   TRAIN LOSS_3  16.000000361899147   TRAIN LOSS_4  16.400000020745175   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.80000077242339
# EPOCH  8814  | TRAIN LOSS_1  14.40000011203916   TRAIN LOSS_2  13.600000763704774   TRAIN LOSS_3  16.00000036186414   TRAIN LOSS_4  16.4000000207431   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.80000077232933
# EPOCH  8815  | TRAIN LOSS_1  14.400000112030119   TRAIN LOSS_2  13.600000763611956   TRAIN LOSS_3  16.000000361829137   TRAIN LOSS_4  16.400000020741025   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000772235286
# EPOCH  8816  | TRAIN LOSS_1  14.40000011202108   TRAIN LOSS_2  13.600000763519166   TRAIN LOSS_3  16.000000361794143   TRAIN LOSS_4  16.40000002073895   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000772141267
# EPOCH  8817  | TRAIN LOSS_1  14.400000112012043   TRAIN LOSS_2  13.600000763426399   TRAIN LOSS_3  16.000000361759156   TRAIN LOSS_4  16.400000020736872   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000772047266
# EPOCH  8818  | TRAIN LOSS_1  14.400000112003008   TRAIN LOSS_2  13.600000763333659   TRAIN LOSS_3  16.00000036172418   TRAIN LOSS_4  16.400000020734797   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000771953286
# EPOCH  8819  | TRAIN LOSS_1  14.400000111993975   TRAIN LOSS_2  13.600000763240942   TRAIN LOSS_3  16.000000361689207   TRAIN LOSS_4  16.400000020732726   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000771859324
# EPOCH  8820  | TRAIN LOSS_1  14.400000111984943   TRAIN LOSS_2  13.600000763148254   TRAIN LOSS_3  16.00000036165424   TRAIN LOSS_4  16.40000002073065   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000771765387
# EPOCH  8821  | TRAIN LOSS_1  14.400000111975917   TRAIN LOSS_2  13.60000076305559   TRAIN LOSS_3  16.000000361619282   TRAIN LOSS_4  16.400000020728577   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000771671463
# EPOCH  8822  | TRAIN LOSS_1  14.40000011196688   TRAIN LOSS_2  13.60000076296295   TRAIN LOSS_3  16.000000361584334   TRAIN LOSS_4  16.400000020726505   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.80000077157757
# EPOCH  8823  | TRAIN LOSS_1  14.400000111957857   TRAIN LOSS_2  13.600000762870337   TRAIN LOSS_3  16.00000036154939   TRAIN LOSS_4  16.400000020724434   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.80000077148369
# EPOCH  8824  | TRAIN LOSS_1  14.400000111948833   TRAIN LOSS_2  13.600000762777748   TRAIN LOSS_3  16.000000361514456   TRAIN LOSS_4  16.400000020722363   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000771389833
# EPOCH  8825  | TRAIN LOSS_1  14.400000111939812   TRAIN LOSS_2  13.600000762685188   TRAIN LOSS_3  16.00000036147953   TRAIN LOSS_4  16.40000002072029   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000771295995
# EPOCH  8826  | TRAIN LOSS_1  14.400000111930789   TRAIN LOSS_2  13.600000762592648   TRAIN LOSS_3  16.00000036144461   TRAIN LOSS_4  16.400000020718217   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000771202182
# EPOCH  8827  | TRAIN LOSS_1  14.400000111921774   TRAIN LOSS_2  13.600000762500136   TRAIN LOSS_3  16.000000361409693   TRAIN LOSS_4  16.40000002071615   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000771108383
# EPOCH  8828  | TRAIN LOSS_1  14.400000111912751   TRAIN LOSS_2  13.600000762407651   TRAIN LOSS_3  16.000000361374784   TRAIN LOSS_4  16.40000002071408   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.80000077101461
# EPOCH  8829  | TRAIN LOSS_1  14.400000111903736   TRAIN LOSS_2  13.60000076231519   TRAIN LOSS_3  16.000000361339886   TRAIN LOSS_4  16.40000002071201   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000770920853
# EPOCH  8830  | TRAIN LOSS_1  14.400000111894721   TRAIN LOSS_2  13.600000762222754   TRAIN LOSS_3  16.000000361304995   TRAIN LOSS_4  16.400000020709943   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000770827122
# EPOCH  8831  | TRAIN LOSS_1  14.400000111885708   TRAIN LOSS_2  13.600000762130344   TRAIN LOSS_3  16.000000361270114   TRAIN LOSS_4  16.40000002070787   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.80000077073341
# EPOCH  8832  | TRAIN LOSS_1  14.400000111876697   TRAIN LOSS_2  13.60000076203796   TRAIN LOSS_3  16.000000361235237   TRAIN LOSS_4  16.400000020705804   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000770639716
# EPOCH  8833  | TRAIN LOSS_1  14.400000111867692   TRAIN LOSS_2  13.600000761945598   TRAIN LOSS_3  16.000000361200367   TRAIN LOSS_4  16.400000020703736   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000770546042
# EPOCH  8834  | TRAIN LOSS_1  14.40000011185868   TRAIN LOSS_2  13.600000761853263   TRAIN LOSS_3  16.0000003611655   TRAIN LOSS_4  16.40000002070167   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.80000077045239
# EPOCH  8835  | TRAIN LOSS_1  14.400000111849678   TRAIN LOSS_2  13.600000761760953   TRAIN LOSS_3  16.00000036113065   TRAIN LOSS_4  16.4000000206996   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000770358757
# EPOCH  8836  | TRAIN LOSS_1  14.400000111840674   TRAIN LOSS_2  13.600000761668671   TRAIN LOSS_3  16.0000003610958   TRAIN LOSS_4  16.400000020697536   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000770265147
# EPOCH  8837  | TRAIN LOSS_1  14.40000011183167   TRAIN LOSS_2  13.60000076157641   TRAIN LOSS_3  16.000000361060962   TRAIN LOSS_4  16.40000002069547   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000770171557
# EPOCH  8838  | TRAIN LOSS_1  14.400000111822672   TRAIN LOSS_2  13.600000761484177   TRAIN LOSS_3  16.000000361026128   TRAIN LOSS_4  16.400000020693405   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000770077986
# EPOCH  8839  | TRAIN LOSS_1  14.400000111813672   TRAIN LOSS_2  13.600000761391968   TRAIN LOSS_3  16.0000003609913   TRAIN LOSS_4  16.40000002069134   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000769984436
# EPOCH  8840  | TRAIN LOSS_1  14.400000111804673   TRAIN LOSS_2  13.600000761299786   TRAIN LOSS_3  16.000000360956484   TRAIN LOSS_4  16.400000020689276   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000769890907
# EPOCH  8841  | TRAIN LOSS_1  14.40000011179568   TRAIN LOSS_2  13.600000761207628   TRAIN LOSS_3  16.00000036092167   TRAIN LOSS_4  16.40000002068721   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.8000007697974
# EPOCH  8842  | TRAIN LOSS_1  14.400000111786687   TRAIN LOSS_2  13.600000761115496   TRAIN LOSS_3  16.00000036088687   TRAIN LOSS_4  16.400000020685148   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000769703907
# EPOCH  8843  | TRAIN LOSS_1  14.400000111777691   TRAIN LOSS_2  13.600000761023386   TRAIN LOSS_3  16.000000360852074   TRAIN LOSS_4  16.400000020683084   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000769610442
# EPOCH  8844  | TRAIN LOSS_1  14.400000111768701   TRAIN LOSS_2  13.600000760931303   TRAIN LOSS_3  16.000000360817282   TRAIN LOSS_4  16.400000020681023   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000769516995
# EPOCH  8845  | TRAIN LOSS_1  14.400000111759715   TRAIN LOSS_2  13.600000760839247   TRAIN LOSS_3  16.0000003607825   TRAIN LOSS_4  16.40000002067896   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.80000076942357
# EPOCH  8846  | TRAIN LOSS_1  14.400000111750725   TRAIN LOSS_2  13.600000760747216   TRAIN LOSS_3  16.000000360747723   TRAIN LOSS_4  16.4000000206769   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.80000076933016
# EPOCH  8847  | TRAIN LOSS_1  14.400000111741743   TRAIN LOSS_2  13.60000076065521   TRAIN LOSS_3  16.00000036071296   TRAIN LOSS_4  16.400000020674835   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.80000076923677
# EPOCH  8848  | TRAIN LOSS_1  14.40000011173276   TRAIN LOSS_2  13.600000760563224   TRAIN LOSS_3  16.000000360678197   TRAIN LOSS_4  16.400000020672774   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000769143406
# EPOCH  8849  | TRAIN LOSS_1  14.400000111723779   TRAIN LOSS_2  13.60000076047127   TRAIN LOSS_3  16.000000360643444   TRAIN LOSS_4  16.400000020670713   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.80000076905006
# EPOCH  8850  | TRAIN LOSS_1  14.4000001117148   TRAIN LOSS_2  13.600000760379336   TRAIN LOSS_3  16.000000360608702   TRAIN LOSS_4  16.400000020668656   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000768956735
# EPOCH  8851  | TRAIN LOSS_1  14.400000111705822   TRAIN LOSS_2  13.600000760287433   TRAIN LOSS_3  16.00000036057396   TRAIN LOSS_4  16.400000020666596   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000768863434
# EPOCH  8852  | TRAIN LOSS_1  14.400000111696846   TRAIN LOSS_2  13.60000076019555   TRAIN LOSS_3  16.00000036053923   TRAIN LOSS_4  16.400000020664535   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000768770147
# EPOCH  8853  | TRAIN LOSS_1  14.40000011168787   TRAIN LOSS_2  13.600000760103692   TRAIN LOSS_3  16.000000360504508   TRAIN LOSS_4  16.40000002066248   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000768676885
# EPOCH  8854  | TRAIN LOSS_1  14.400000111678896   TRAIN LOSS_2  13.600000760011861   TRAIN LOSS_3  16.00000036046979   TRAIN LOSS_4  16.40000002066042   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000768583637
# EPOCH  8855  | TRAIN LOSS_1  14.400000111669929   TRAIN LOSS_2  13.600000759920055   TRAIN LOSS_3  16.00000036043508   TRAIN LOSS_4  16.40000002065836   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000768490413
# EPOCH  8856  | TRAIN LOSS_1  14.400000111660955   TRAIN LOSS_2  13.600000759828273   TRAIN LOSS_3  16.000000360400378   TRAIN LOSS_4  16.400000020656304   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.80000076839721
# EPOCH  8857  | TRAIN LOSS_1  14.400000111651988   TRAIN LOSS_2  13.600000759736517   TRAIN LOSS_3  16.000000360365682   TRAIN LOSS_4  16.400000020654247   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000768304027
# EPOCH  8858  | TRAIN LOSS_1  14.400000111643024   TRAIN LOSS_2  13.600000759644786   TRAIN LOSS_3  16.000000360330997   TRAIN LOSS_4  16.400000020652193   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000768210868
# EPOCH  8859  | TRAIN LOSS_1  14.400000111634057   TRAIN LOSS_2  13.60000075955308   TRAIN LOSS_3  16.00000036029632   TRAIN LOSS_4  16.400000020650133   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000768117723
# EPOCH  8860  | TRAIN LOSS_1  14.400000111625095   TRAIN LOSS_2  13.600000759461398   TRAIN LOSS_3  16.000000360261645   TRAIN LOSS_4  16.40000002064808   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.8000007680246
# EPOCH  8861  | TRAIN LOSS_1  14.400000111616137   TRAIN LOSS_2  13.600000759369744   TRAIN LOSS_3  16.000000360226977   TRAIN LOSS_4  16.400000020646026   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.8000007679315
# EPOCH  8862  | TRAIN LOSS_1  14.400000111607175   TRAIN LOSS_2  13.600000759278112   TRAIN LOSS_3  16.000000360192317   TRAIN LOSS_4  16.40000002064397   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.80000076783842
# EPOCH  8863  | TRAIN LOSS_1  14.40000011159822   TRAIN LOSS_2  13.600000759186505   TRAIN LOSS_3  16.000000360157667   TRAIN LOSS_4  16.400000020641915   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000767745356
# EPOCH  8864  | TRAIN LOSS_1  14.400000111589264   TRAIN LOSS_2  13.600000759094922   TRAIN LOSS_3  16.000000360123025   TRAIN LOSS_4  16.400000020639858   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000767652314
# EPOCH  8865  | TRAIN LOSS_1  14.400000111580306   TRAIN LOSS_2  13.600000759003368   TRAIN LOSS_3  16.000000360088386   TRAIN LOSS_4  16.40000002063781   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000767559297
# EPOCH  8866  | TRAIN LOSS_1  14.400000111571359   TRAIN LOSS_2  13.600000758911836   TRAIN LOSS_3  16.000000360053757   TRAIN LOSS_4  16.400000020635755   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000767466294
# EPOCH  8867  | TRAIN LOSS_1  14.40000011156241   TRAIN LOSS_2  13.600000758820329   TRAIN LOSS_3  16.000000360019136   TRAIN LOSS_4  16.400000020633705   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000767373316
# EPOCH  8868  | TRAIN LOSS_1  14.400000111553458   TRAIN LOSS_2  13.600000758728848   TRAIN LOSS_3  16.000000359984522   TRAIN LOSS_4  16.40000002063165   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000767280356
# EPOCH  8869  | TRAIN LOSS_1  14.40000011154451   TRAIN LOSS_2  13.600000758637389   TRAIN LOSS_3  16.00000035994991   TRAIN LOSS_4  16.400000020629598   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000767187417
# EPOCH  8870  | TRAIN LOSS_1  14.400000111535565   TRAIN LOSS_2  13.600000758545956   TRAIN LOSS_3  16.00000035991531   TRAIN LOSS_4  16.400000020627548   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.8000007670945
# EPOCH  8871  | TRAIN LOSS_1  14.400000111526623   TRAIN LOSS_2  13.60000075845455   TRAIN LOSS_3  16.00000035988072   TRAIN LOSS_4  16.400000020625498   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.8000007670016
# EPOCH  8872  | TRAIN LOSS_1  14.40000011151768   TRAIN LOSS_2  13.60000075836317   TRAIN LOSS_3  16.000000359846133   TRAIN LOSS_4  16.400000020623445   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000766908717
# EPOCH  8873  | TRAIN LOSS_1  14.40000011150874   TRAIN LOSS_2  13.600000758271813   TRAIN LOSS_3  16.000000359811555   TRAIN LOSS_4  16.4000000206214   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.80000076681586
# EPOCH  8874  | TRAIN LOSS_1  14.400000111499802   TRAIN LOSS_2  13.600000758180476   TRAIN LOSS_3  16.000000359776983   TRAIN LOSS_4  16.40000002061935   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000766723024
# EPOCH  8875  | TRAIN LOSS_1  14.400000111490863   TRAIN LOSS_2  13.600000758089172   TRAIN LOSS_3  16.00000035974242   TRAIN LOSS_4  16.4000000206173   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000766630202
# EPOCH  8876  | TRAIN LOSS_1  14.400000111481933   TRAIN LOSS_2  13.600000757997886   TRAIN LOSS_3  16.00000035970786   TRAIN LOSS_4  16.400000020615252   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000766537405
# EPOCH  8877  | TRAIN LOSS_1  14.400000111472995   TRAIN LOSS_2  13.600000757906631   TRAIN LOSS_3  16.000000359673308   TRAIN LOSS_4  16.400000020613202   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.80000076644463
# EPOCH  8878  | TRAIN LOSS_1  14.400000111464063   TRAIN LOSS_2  13.600000757815394   TRAIN LOSS_3  16.00000035963877   TRAIN LOSS_4  16.400000020611152   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000766351868
# EPOCH  8879  | TRAIN LOSS_1  14.400000111455137   TRAIN LOSS_2  13.600000757724189   TRAIN LOSS_3  16.00000035960423   TRAIN LOSS_4  16.40000002060911   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000766259135
# EPOCH  8880  | TRAIN LOSS_1  14.400000111446207   TRAIN LOSS_2  13.600000757633003   TRAIN LOSS_3  16.0000003595697   TRAIN LOSS_4  16.40000002060706   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000766166416
# EPOCH  8881  | TRAIN LOSS_1  14.40000011143728   TRAIN LOSS_2  13.600000757541844   TRAIN LOSS_3  16.000000359535182   TRAIN LOSS_4  16.400000020605017   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.80000076607372
# EPOCH  8882  | TRAIN LOSS_1  14.400000111428355   TRAIN LOSS_2  13.60000075745071   TRAIN LOSS_3  16.000000359500667   TRAIN LOSS_4  16.400000020602967   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000765981043
# EPOCH  8883  | TRAIN LOSS_1  14.400000111419434   TRAIN LOSS_2  13.6000007573596   TRAIN LOSS_3  16.000000359466164   TRAIN LOSS_4  16.40000002060092   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000765888385
# EPOCH  8884  | TRAIN LOSS_1  14.400000111410511   TRAIN LOSS_2  13.600000757268514   TRAIN LOSS_3  16.00000035943166   TRAIN LOSS_4  16.40000002059888   TRAIN LOSS_5  15.999999999999996   TRAIN LOSS_6  18.800000765795748

# %%
i = range(n_epoch)
plt.plot(i, Loss_1)
plt.plot(i, Loss_2)
plt.plot(i, Loss_3)
plt.plot(i, Loss_4)
plt.plot(i, Loss_5)
plt.plot(i, Loss_6)
plt.legend(['Network_1', 'Network_2', 'Network_3', 'Network_4', 'Network_5', 'Network_6'])
plt.xlabel('epoch')
plt.ylabel('Mean squared error(tanh)')
plt.yscale("log")
plt.show()

# %%
i = range(n_epoch)
plt.plot(i, Loss_1)
plt.plot(i, Loss_2)
plt.plot(i, Loss_3)
plt.plot(i, Loss_4)
plt.plot(i, Loss_5)
plt.plot(i, Loss_6)
plt.legend(['Network_1', 'Network_2', 'Network_3', 'Network_4', 'Network_5', 'Network_6'])
plt.xlabel('epoch')
plt.ylabel('Mean squared error(tanh)')
#plt.yscale("log")
plt.ylim(0.001,0.008)
plt.show()

# %%
#出力が定義されたSLと等しいかの確認
print('レプリカ1の出力と正解のオーバーラップ',spin_overlap(np.sign(y_1[0]),SL))
print('レプリカ2の出力と正解のオーバーラップ',spin_overlap(np.sign(y_2[0]),SL))
print('レプリカ3の出力と正解のオーバーラップ',spin_overlap(np.sign(y_3[0]),SL))
print('レプリカ4の出力と正解のオーバーラップ',spin_overlap(np.sign(y_4[0]),SL))
print('レプリカ5の出力と正解のオーバーラップ',spin_overlap(np.sign(y_5[0]),SL))
print('レプリカ6の出力と正解のオーバーラップ',spin_overlap(np.sign(y_6[0]),SL))
# Out:
# レプリカ1の出力と正解のオーバーラップ 1.0
# レプリカ2の出力と正解のオーバーラップ 1.0
# レプリカ3の出力と正解のオーバーラップ 1.0
# レプリカ4の出力と正解のオーバーラップ 1.0
# レプリカ5の出力と正解のオーバーラップ 1.0
# レプリカ6の出力と正解のオーバーラップ 1.0

# %%
#オーダーパラメータ
#レプリカ1と2
q_12_S0 = spin_overlap(S0,S0)
q_12_S1 = spin_overlap(y_1[1],y_2[1])
q_12_S2 = spin_overlap(y_1[2],y_2[2])
q_12_S3 = spin_overlap(y_1[3],y_2[3])
q_12_S4 = spin_overlap(y_1[4],y_2[4])
q_12_SL = spin_overlap(SL,SL)

Q_12_1 = bond_overlap(w_1[0],w_2[0])
Q_12_2 = bond_overlap(w_1[1],w_2[1])
Q_12_3 = bond_overlap(w_1[2],w_2[2])
Q_12_4 = bond_overlap(w_1[3],w_2[3])
Q_12_5 = bond_overlap(w_1[4],w_2[4])

#レプリカ1と3
q_13_S0 = spin_overlap(S0,S0)
q_13_S1 = spin_overlap(y_1[1],y_3[1])
q_13_S2 = spin_overlap(y_1[2],y_3[2])
q_13_S3 = spin_overlap(y_1[3],y_3[3])
q_13_S4 = spin_overlap(y_1[4],y_3[4])
q_13_SL = spin_overlap(SL,SL)

Q_13_1 = bond_overlap(w_1[0],w_3[0])
Q_13_2 = bond_overlap(w_1[1],w_3[1])
Q_13_3 = bond_overlap(w_1[2],w_3[2])
Q_13_4 = bond_overlap(w_1[3],w_3[3])
Q_13_5 = bond_overlap(w_1[4],w_3[4])

#レプリカ1と4
q_14_S0 = spin_overlap(S0,S0)
q_14_S1 = spin_overlap(y_1[1],y_4[1])
q_14_S2 = spin_overlap(y_1[2],y_4[2])
q_14_S3 = spin_overlap(y_1[3],y_4[3])
q_14_S4 = spin_overlap(y_1[4],y_4[4])
q_14_SL = spin_overlap(SL,SL)

Q_14_1 = bond_overlap(w_1[0],w_4[0])
Q_14_2 = bond_overlap(w_1[1],w_4[1])
Q_14_3 = bond_overlap(w_1[2],w_4[2])
Q_14_4 = bond_overlap(w_1[3],w_4[3])
Q_14_5 = bond_overlap(w_1[4],w_4[4])

#レプリカ1と5
q_15_S0 = spin_overlap(S0,S0)
q_15_S1 = spin_overlap(y_1[1],y_5[1])
q_15_S2 = spin_overlap(y_1[2],y_5[2])
q_15_S3 = spin_overlap(y_1[3],y_5[3])
q_15_S4 = spin_overlap(y_1[4],y_5[4])
q_15_SL = spin_overlap(SL,SL)

Q_15_1 = bond_overlap(w_1[0],w_5[0])
Q_15_2 = bond_overlap(w_1[1],w_5[1])
Q_15_3 = bond_overlap(w_1[2],w_5[2])
Q_15_4 = bond_overlap(w_1[3],w_5[3])
Q_15_5 = bond_overlap(w_1[4],w_5[4])

#レプリカ1と6
q_16_S0 = spin_overlap(S0,S0)
q_16_S1 = spin_overlap(y_1[1],y_6[1])
q_16_S2 = spin_overlap(y_1[2],y_6[2])
q_16_S3 = spin_overlap(y_1[3],y_6[3])
q_16_S4 = spin_overlap(y_1[4],y_6[4])
q_16_SL = spin_overlap(SL,SL)

Q_16_1 = bond_overlap(w_1[0],w_6[0])
Q_16_2 = bond_overlap(w_1[1],w_6[1])
Q_16_3 = bond_overlap(w_1[2],w_6[2])
Q_16_4 = bond_overlap(w_1[3],w_6[3])
Q_16_5 = bond_overlap(w_1[4],w_6[4])

#レプリカ2と3
q_23_S0 = spin_overlap(S0,S0)
q_23_S1 = spin_overlap(y_2[1],y_5[1])
q_23_S2 = spin_overlap(y_2[2],y_5[2])
q_23_S3 = spin_overlap(y_2[3],y_5[3])
q_23_S4 = spin_overlap(y_2[4],y_5[4])
q_23_SL = spin_overlap(SL,SL)

Q_23_1 = bond_overlap(w_2[0],w_3[0])
Q_23_2 = bond_overlap(w_2[1],w_3[1])
Q_23_3 = bond_overlap(w_2[2],w_3[2])
Q_23_4 = bond_overlap(w_2[3],w_3[3])
Q_23_5 = bond_overlap(w_2[4],w_3[4])

#レプリカ2と4
q_24_S0 = spin_overlap(S0,S0)
q_24_S1 = spin_overlap(y_2[1],y_4[1])
q_24_S2 = spin_overlap(y_2[2],y_4[2])
q_24_S3 = spin_overlap(y_2[3],y_4[3])
q_24_S4 = spin_overlap(y_2[4],y_4[4])
q_24_SL = spin_overlap(SL,SL)

Q_24_1 = bond_overlap(w_2[0],w_4[0])
Q_24_2 = bond_overlap(w_2[1],w_4[1])
Q_24_3 = bond_overlap(w_2[2],w_4[2])
Q_24_4 = bond_overlap(w_2[3],w_4[3])
Q_24_5 = bond_overlap(w_2[4],w_4[4])

#レプリカ2と5
q_25_S0 = spin_overlap(S0,S0)
q_25_S1 = spin_overlap(y_2[1],y_5[1])
q_25_S2 = spin_overlap(y_2[2],y_5[2])
q_25_S3 = spin_overlap(y_2[3],y_5[3])
q_25_S4 = spin_overlap(y_2[4],y_5[4])
q_25_SL = spin_overlap(SL,SL)

Q_25_1 = bond_overlap(w_2[0],w_5[0])
Q_25_2 = bond_overlap(w_2[1],w_5[1])
Q_25_3 = bond_overlap(w_2[2],w_5[2])
Q_25_4 = bond_overlap(w_2[3],w_5[3])
Q_25_5 = bond_overlap(w_2[4],w_5[4])

#レプリカ2と6
q_26_S0 = spin_overlap(S0,S0)
q_26_S1 = spin_overlap(y_2[1],y_6[1])
q_26_S2 = spin_overlap(y_2[2],y_6[2])
q_26_S3 = spin_overlap(y_2[3],y_6[3])
q_26_S4 = spin_overlap(y_2[4],y_6[4])
q_26_SL = spin_overlap(SL,SL)

Q_26_1 = bond_overlap(w_2[0],w_6[0])
Q_26_2 = bond_overlap(w_2[1],w_6[1])
Q_26_3 = bond_overlap(w_2[2],w_6[2])
Q_26_4 = bond_overlap(w_2[3],w_6[3])
Q_26_5 = bond_overlap(w_2[4],w_6[4])

#レプリカ3と4
q_34_S0 = spin_overlap(S0,S0)
q_34_S1 = spin_overlap(y_3[1],y_4[1])
q_34_S2 = spin_overlap(y_3[2],y_4[2])
q_34_S3 = spin_overlap(y_3[3],y_4[3])
q_34_S4 = spin_overlap(y_3[4],y_4[4])
q_34_SL = spin_overlap(SL,SL)

Q_34_1 = bond_overlap(w_3[0],w_4[0])
Q_34_2 = bond_overlap(w_3[1],w_4[1])
Q_34_3 = bond_overlap(w_3[2],w_4[2])
Q_34_4 = bond_overlap(w_3[3],w_4[3])
Q_34_5 = bond_overlap(w_3[4],w_4[4])

#レプリカ3と5
q_35_S0 = spin_overlap(S0,S0)
q_35_S1 = spin_overlap(y_3[1],y_5[1])
q_35_S2 = spin_overlap(y_3[2],y_5[2])
q_35_S3 = spin_overlap(y_3[3],y_5[3])
q_35_S4 = spin_overlap(y_3[4],y_5[4])
q_35_SL = spin_overlap(SL,SL)

Q_35_1 = bond_overlap(w_3[0],w_5[0])
Q_35_2 = bond_overlap(w_3[1],w_5[1])
Q_35_3 = bond_overlap(w_3[2],w_5[2])
Q_35_4 = bond_overlap(w_3[3],w_5[3])
Q_35_5 = bond_overlap(w_3[4],w_5[4])

#レプリカ3と6
q_36_S0 = spin_overlap(S0,S0)
q_36_S1 = spin_overlap(y_3[1],y_6[1])
q_36_S2 = spin_overlap(y_3[2],y_6[2])
q_36_S3 = spin_overlap(y_3[3],y_6[3])
q_36_S4 = spin_overlap(y_3[4],y_6[4])
q_36_SL = spin_overlap(SL,SL)

Q_36_1 = bond_overlap(w_3[0],w_6[0])
Q_36_2 = bond_overlap(w_3[1],w_6[1])
Q_36_3 = bond_overlap(w_3[2],w_6[2])
Q_36_4 = bond_overlap(w_3[3],w_6[3])
Q_36_5 = bond_overlap(w_3[4],w_6[4])

#レプリカ4と5
q_45_S0 = spin_overlap(S0,S0)
q_45_S1 = spin_overlap(y_4[1],y_5[1])
q_45_S2 = spin_overlap(y_4[2],y_5[2])
q_45_S3 = spin_overlap(y_4[3],y_5[3])
q_45_S4 = spin_overlap(y_4[4],y_5[4])
q_45_SL = spin_overlap(SL,SL)

Q_45_1 = bond_overlap(w_4[0],w_5[0])
Q_45_2 = bond_overlap(w_4[1],w_5[1])
Q_45_3 = bond_overlap(w_4[2],w_5[2])
Q_45_4 = bond_overlap(w_4[3],w_5[3])
Q_45_5 = bond_overlap(w_4[4],w_5[4])

#レプリカ4と6
q_46_S0 = spin_overlap(S0,S0)
q_46_S1 = spin_overlap(y_4[1],y_6[1])
q_46_S2 = spin_overlap(y_4[2],y_6[2])
q_46_S3 = spin_overlap(y_4[3],y_6[3])
q_46_S4 = spin_overlap(y_4[4],y_6[4])
q_46_SL = spin_overlap(SL,SL)

Q_46_1 = bond_overlap(w_4[0],w_6[0])
Q_46_2 = bond_overlap(w_4[1],w_6[1])
Q_46_3 = bond_overlap(w_4[2],w_6[2])
Q_46_4 = bond_overlap(w_4[3],w_6[3])
Q_46_5 = bond_overlap(w_4[4],w_6[4])

#レプリカ5と6
q_56_S0 = spin_overlap(S0,S0)
q_56_S1 = spin_overlap(y_5[1],y_6[1])
q_56_S2 = spin_overlap(y_5[2],y_6[2])
q_56_S3 = spin_overlap(y_5[3],y_6[3])
q_56_S4 = spin_overlap(y_5[4],y_6[4])
q_56_SL = spin_overlap(SL,SL)

Q_56_1 = bond_overlap(w_5[0],w_6[0])
Q_56_2 = bond_overlap(w_5[1],w_6[1])
Q_56_3 = bond_overlap(w_5[2],w_6[2])
Q_56_4 = bond_overlap(w_5[3],w_6[3])
Q_56_5 = bond_overlap(w_5[4],w_6[4])

# %%
q_12 = np.array([q_12_S0, q_12_S1, q_12_S2,
     q_12_S3, q_12_S4, q_12_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_12)
plt.xlabel('Layer')
plt.ylabel('q_12')
plt.show()
print(q_12)
# Out:
# [1.         0.08666667 0.1        0.02666667 0.09333333 1.        ]

# %%
q_13 = np.array([q_13_S0, q_13_S1, q_13_S2,
     q_13_S3, q_13_S4, q_13_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_13)
plt.xlabel('Layer')
plt.ylabel('q_13')
plt.show()
print(q_13)
# Out:
# [1.         0.06666667 0.02666667 0.06       0.04666667 1.        ]

# %%
q_14 = np.array([q_14_S0, q_14_S1, q_14_S2,
     q_14_S3, q_14_S4, q_14_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_14)
plt.xlabel('Layer')
plt.ylabel('q_14')
plt.show()
print(q_14)
# Out:
# [1.         0.02       0.08       0.08666667 0.03333333 1.        ]

# %%
q_15 = np.array([q_15_S0, q_15_S1, q_15_S2,
     q_15_S3, q_15_S4, q_15_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_15)
plt.xlabel('Layer')
plt.ylabel('q_15')
plt.show()
print(q_15)
# Out:
# [1.         0.06       0.14666667 0.15333333 0.04       1.        ]

# %%
q_16 = np.array([q_16_S0, q_16_S1, q_16_S2,
     q_16_S3, q_16_S4, q_16_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_16)
plt.xlabel('Layer')
plt.ylabel('q_16')
plt.show()
print(q_16)
# Out:
# [1.         0.04666667 0.02       0.         0.04666667 1.        ]

# %%
q_23 = np.array([q_23_S0, q_23_S1, q_23_S2,
     q_23_S3, q_23_S4, q_23_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_23)
plt.xlabel('Layer')
plt.ylabel('q_23')
plt.show()
print(q_23)
# Out:
# [1.         0.05333333 0.06       0.12666667 0.10666667 1.        ]

# %%
q_24 = np.array([q_24_S0, q_24_S1, q_24_S2,
     q_24_S3, q_24_S4, q_24_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_24)
plt.xlabel('Layer')
plt.ylabel('q_24')
plt.show()
print(q_24)
# Out:
# [1.         0.05333333 0.00666667 0.00666667 0.1        1.        ]

# %%
q_25 = np.array([q_25_S0, q_25_S1, q_25_S2,
     q_25_S3, q_25_S4, q_25_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_25)
plt.xlabel('Layer')
plt.ylabel('q_25')
plt.show()
print(q_25)
# Out:
# [1.         0.05333333 0.06       0.12666667 0.10666667 1.        ]

# %%
q_26 = np.array([q_26_S0, q_26_S1, q_26_S2,
     q_26_S3, q_26_S4, q_26_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_26)
plt.xlabel('Layer')
plt.ylabel('q_26')
plt.show()
print(q_26)
# Out:
# [1.         0.04       0.21333333 0.06666667 0.03333333 1.        ]

# %%
q_34 = np.array([q_34_S0, q_34_S1, q_34_S2,
     q_34_S3, q_34_S4, q_34_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_34)
plt.xlabel('Layer')
plt.ylabel('q_34')
plt.show()
print(q_34)
# Out:
# [1.         0.07333333 0.05333333 0.01333333 0.         1.        ]

# %%
q_35 = np.array([q_35_S0, q_35_S1, q_35_S2,
     q_35_S3, q_35_S4, q_35_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_35)
plt.xlabel('Layer')
plt.ylabel('q_35')
plt.show()
print(q_35)
# Out:
# [1.         0.00666667 0.02666667 0.04       0.02       1.        ]

# %%
q_36 = np.array([q_36_S0, q_36_S1, q_36_S2,
     q_36_S3, q_36_S4, q_36_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_36)
plt.xlabel('Layer')
plt.ylabel('q_36')
plt.show()
print(q_36)
# Out:
# [1.         0.04666667 0.14       0.11333333 0.01333333 1.        ]

# %%
q_45 = np.array([q_45_S0, q_45_S1, q_45_S2,
     q_45_S3, q_45_S4, q_45_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_45)
plt.xlabel('Layer')
plt.ylabel('q_45')
plt.show()
print(q_45)
# Out:
# [1.         0.01333333 0.         0.13333333 0.02       1.        ]

# %%
q_46 = np.array([q_46_S0, q_46_S1, q_46_S2,
     q_46_S3, q_46_S4, q_46_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_46)
plt.xlabel('Layer')
plt.ylabel('q_46')
plt.show()
print(q_46)
# Out:
# [1.         0.01333333 0.00666667 0.11333333 0.14666667 1.        ]

# %%
q_56 = np.array([q_56_S0, q_56_S1, q_56_S2,
     q_56_S3, q_56_S4, q_56_SL])
i = [0,1,2,3,4,5]
plt.plot(i, q_56)
plt.xlabel('Layer')
plt.ylabel('q_56')
plt.show()
print(q_56)
# Out:
# [1.         0.02666667 0.02       0.07333333 0.03333333 1.        ]

# %%
Q_12 = np.array([Q_12_1, Q_12_2, Q_12_3,
     Q_12_4, Q_12_5])
i = [1,2,3,4,5]
plt.plot(i, Q_12)
plt.xlabel('Layer')
plt.ylabel('Q_12')
plt.show()
print(Q_12)
# Out:
# [0.06617694 0.23129633 0.04879238 0.01955232 0.01429602]

# %%
Q_13 = np.array([Q_13_1, Q_13_2, Q_13_3,
     Q_13_4, Q_13_5])
i = [1,2,3,4,5]
plt.plot(i, Q_13)
plt.xlabel('Layer')
plt.ylabel('Q_13')
plt.show()
print(Q_13)
# Out:
# [0.04269577 0.00297485 0.04315523 0.0329222  0.08717303]

# %%
Q_14 = np.array([Q_14_1, Q_14_2, Q_14_3,
     Q_14_4, Q_14_5])
i = [1,2,3,4,5]
plt.plot(i, Q_14)
plt.xlabel('Layer')
plt.ylabel('Q_14')
plt.show()
print(Q_14)
# Out:
# [0.09920239 0.02252919 0.20092393 0.23104201 0.00570652]

# %%
Q_15 = np.array([Q_15_1, Q_15_2, Q_15_3,
     Q_15_4, Q_15_5])
i = [1,2,3,4,5]
plt.plot(i, Q_15)
plt.xlabel('Layer')
plt.ylabel('Q_15')
plt.show()
print(Q_15)
# Out:
# [0.05572086 0.00253261 0.15240048 0.04018854 0.08501701]

# %%
Q_16 = np.array([Q_16_1, Q_16_2, Q_16_3,
     Q_16_4, Q_16_5])
i = [1,2,3,4,5]
plt.plot(i, Q_16)
plt.xlabel('Layer')
plt.ylabel('Q_16')
plt.show()
print(Q_16)
# Out:
# [0.03166537 0.04255603 0.02429219 0.11976283 0.07892692]

# %%
Q_23 = np.array([Q_23_1, Q_23_2, Q_23_3,
     Q_23_4, Q_23_5])
i = [1,2,3,4,5]
plt.plot(i, Q_23)
plt.xlabel('Layer')
plt.ylabel('Q_23')
plt.show()
print(Q_23)
# Out:
# [0.12897685 0.0009553  0.0069201  0.04338809 0.19763519]

# %%
Q_24 = np.array([Q_24_1, Q_24_2, Q_24_3,
     Q_24_4, Q_24_5])
i = [1,2,3,4,5]
plt.plot(i, Q_24)
plt.xlabel('Layer')
plt.ylabel('Q_24')
plt.show()
print(Q_24)
# Out:
# [0.15849802 0.12037248 0.08659961 0.07007181 0.10107246]

# %%
Q_25 = np.array([Q_25_1, Q_25_2, Q_25_3,
     Q_25_4, Q_25_5])
i = [1,2,3,4,5]
plt.plot(i, Q_25)
plt.xlabel('Layer')
plt.ylabel('Q_25')
plt.show()
print(Q_25)
# Out:
# [0.08005245 0.03445401 0.06579017 0.00734418 0.16353233]

# %%
Q_26 = np.array([Q_26_1, Q_26_2, Q_26_3,
     Q_26_4, Q_26_5])
i = [1,2,3,4,5]
plt.plot(i, Q_26)
plt.xlabel('Layer')
plt.ylabel('Q_26')
plt.show()
print(Q_26)
# Out:
# [0.04494566 0.23103203 0.19693626 0.00231334 0.03719066]

# %%
Q_34 = np.array([Q_34_1, Q_34_2, Q_34_3,
     Q_34_4, Q_34_5])
i = [1,2,3,4,5]
plt.plot(i, Q_34)
plt.xlabel('Layer')
plt.ylabel('Q_34')
plt.show()
print(Q_34)
# Out:
# [0.05497776 0.00737374 0.04091991 0.03675542 0.09822255]

# %%
Q_35 = np.array([Q_35_1, Q_35_2, Q_35_3,
     Q_35_4, Q_35_5])
i = [1,2,3,4,5]
plt.plot(i, Q_35)
plt.xlabel('Layer')
plt.ylabel('Q_35')
plt.show()
print(Q_35)
# Out:
# [0.00552794 0.04240723 0.06874019 0.0250031  0.0257061 ]

# %%
Q_36 = np.array([Q_36_1, Q_36_2, Q_36_3,
     Q_36_4, Q_36_5])
i = [1,2,3,4,5]
plt.plot(i, Q_36)
plt.xlabel('Layer')
plt.ylabel('Q_36')
plt.show()
print(Q_36)
# Out:
# [0.0237996  0.12536709 0.00343276 0.0290179  0.02619305]

# %%
Q_45 = np.array([Q_45_1, Q_45_2, Q_45_3,
     Q_45_4, Q_45_5])
i = [1,2,3,4,5]
plt.plot(i, Q_45)
plt.xlabel('Layer')
plt.ylabel('Q_45')
plt.show()
print(Q_45)
# Out:
# [0.11741994 0.2219718  0.14377269 0.15865516 0.04392492]

# %%
Q_46 = np.array([Q_46_1, Q_46_2, Q_46_3,
     Q_46_4, Q_46_5])
i = [1,2,3,4,5]
plt.plot(i, Q_46)
plt.xlabel('Layer')
plt.ylabel('Q_46')
plt.show()
print(Q_46)
# Out:
# [0.00929039 0.11135552 0.01628506 0.06088678 0.08774835]

# %%
Q_56 = np.array([Q_56_1, Q_56_2, Q_56_3,
     Q_56_4, Q_56_5])
i = [1,2,3,4,5]
plt.plot(i, Q_56)
plt.xlabel('Layer')
plt.ylabel('Q_56')
plt.show()
print(Q_56)
# Out:
# [0.11523719 0.08923959 0.03176776 0.04564427 0.07304119]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_12)
plt.xlabel('Layer')
plt.ylabel('q_12')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_12)
plt.xlabel('Layer')
plt.ylabel('Q_12')

plt.legend(['spin','bond'])
plt.show()

print('q_12 ',q_12)
print('Q_12 ',Q_12)
# Out:
# q_12  [1.         0.08666667 0.1        0.02666667 0.09333333 1.        ]
# Q_12  [0.06617694 0.23129633 0.04879238 0.01955232 0.01429602]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_12)
plt.xlabel('Layer')
plt.ylabel('q_12')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_12)
plt.xlabel('Layer')
plt.ylabel('Q_12')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_13)
plt.xlabel('Layer')
plt.ylabel('q_13')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_13)
plt.xlabel('Layer')
plt.ylabel('Q_13')

plt.legend(['spin','bond'])
plt.show()

print('q_13 ',q_13)
print('Q_13 ',Q_13)
# Out:
# q_13  [1.         0.06666667 0.02666667 0.06       0.04666667 1.        ]
# Q_13  [0.04269577 0.00297485 0.04315523 0.0329222  0.08717303]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_13)
plt.xlabel('Layer')
plt.ylabel('q_13')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_13)
plt.xlabel('Layer')
plt.ylabel('Q_13')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_14)
plt.xlabel('Layer')
plt.ylabel('q_14')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_14)
plt.xlabel('Layer')
plt.ylabel('Q_14')

plt.legend(['spin','bond'])
plt.show()

print('q_14 ',q_14)
print('Q_14 ',Q_14)
# Out:
# q_14  [1.         0.02       0.08       0.08666667 0.03333333 1.        ]
# Q_14  [0.09920239 0.02252919 0.20092393 0.23104201 0.00570652]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_14)
plt.xlabel('Layer')
plt.ylabel('q_14')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_14)
plt.xlabel('Layer')
plt.ylabel('Q_14')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_15)
plt.xlabel('Layer')
plt.ylabel('q_15')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_15)
plt.xlabel('Layer')
plt.ylabel('Q_15')

plt.legend(['spin','bond'])
plt.show()

print('q_15 ',q_15)
print('Q_15 ',Q_15)
# Out:
# q_15  [1.         0.06       0.14666667 0.15333333 0.04       1.        ]
# Q_15  [0.05572086 0.00253261 0.15240048 0.04018854 0.08501701]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_15)
plt.xlabel('Layer')
plt.ylabel('q_15')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_15)
plt.xlabel('Layer')
plt.ylabel('Q_15')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_16)
plt.xlabel('Layer')
plt.ylabel('q_16')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_16)
plt.xlabel('Layer')
plt.ylabel('Q_16')

plt.legend(['spin','bond'])
plt.show()

print('q_16 ',q_16)
print('Q_16 ',Q_16)
# Out:
# q_16  [1.         0.04666667 0.02       0.         0.04666667 1.        ]
# Q_16  [0.03166537 0.04255603 0.02429219 0.11976283 0.07892692]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_16)
plt.xlabel('Layer')
plt.ylabel('q_16')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_16)
plt.xlabel('Layer')
plt.ylabel('Q_16')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_23)
plt.xlabel('Layer')
plt.ylabel('q_23')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_23)
plt.xlabel('Layer')
plt.ylabel('Q_23')

plt.legend(['spin','bond'])
plt.show()

print('q_23 ',q_23)
print('Q_23 ',Q_23)
# Out:
# q_23  [1.         0.05333333 0.06       0.12666667 0.10666667 1.        ]
# Q_23  [0.12897685 0.0009553  0.0069201  0.04338809 0.19763519]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_23)
plt.xlabel('Layer')
plt.ylabel('q_23')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_23)
plt.xlabel('Layer')
plt.ylabel('Q_23')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_24)
plt.xlabel('Layer')
plt.ylabel('q_24')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_24)
plt.xlabel('Layer')
plt.ylabel('Q_24')

plt.legend(['spin','bond'])
plt.show()

print('q_24 ',q_24)
print('Q_24 ',Q_24)
# Out:
# q_24  [1.         0.05333333 0.00666667 0.00666667 0.1        1.        ]
# Q_24  [0.15849802 0.12037248 0.08659961 0.07007181 0.10107246]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_24)
plt.xlabel('Layer')
plt.ylabel('q_24')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_24)
plt.xlabel('Layer')
plt.ylabel('Q_24')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_25)
plt.xlabel('Layer')
plt.ylabel('q_25')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_25)
plt.xlabel('Layer')
plt.ylabel('Q_25')

plt.legend(['spin','bond'])
plt.show()

print('q_25 ',q_25)
print('Q_25 ',Q_25)
# Out:
# q_25  [1.         0.05333333 0.06       0.12666667 0.10666667 1.        ]
# Q_25  [0.08005245 0.03445401 0.06579017 0.00734418 0.16353233]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_25)
plt.xlabel('Layer')
plt.ylabel('q_25')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_25)
plt.xlabel('Layer')
plt.ylabel('Q_25')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_26)
plt.xlabel('Layer')
plt.ylabel('q_26')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_26)
plt.xlabel('Layer')
plt.ylabel('Q_26')

plt.legend(['spin','bond'])
plt.show()

print('q_26 ',q_26)
print('Q_26 ',Q_26)
# Out:
# q_26  [1.         0.04       0.21333333 0.06666667 0.03333333 1.        ]
# Q_26  [0.04494566 0.23103203 0.19693626 0.00231334 0.03719066]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_26)
plt.xlabel('Layer')
plt.ylabel('q_26')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_26)
plt.xlabel('Layer')
plt.ylabel('Q_26')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_34)
plt.xlabel('Layer')
plt.ylabel('q_34')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_34)
plt.xlabel('Layer')
plt.ylabel('Q_34')

plt.legend(['spin','bond'])
plt.show()

print('q_34 ',q_34)
print('Q_34 ',Q_34)
# Out:
# q_34  [1.         0.07333333 0.05333333 0.01333333 0.         1.        ]
# Q_34  [0.05497776 0.00737374 0.04091991 0.03675542 0.09822255]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_34)
plt.xlabel('Layer')
plt.ylabel('q_34')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_34)
plt.xlabel('Layer')
plt.ylabel('Q_34')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_35)
plt.xlabel('Layer')
plt.ylabel('q_35')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_35)
plt.xlabel('Layer')
plt.ylabel('Q_35')

plt.legend(['spin','bond'])
plt.show()

print('q_35 ',q_35)
print('Q_35 ',Q_35)
# Out:
# q_35  [1.         0.00666667 0.02666667 0.04       0.02       1.        ]
# Q_35  [0.00552794 0.04240723 0.06874019 0.0250031  0.0257061 ]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_35)
plt.xlabel('Layer')
plt.ylabel('q_35')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_35)
plt.xlabel('Layer')
plt.ylabel('Q_35')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_36)
plt.xlabel('Layer')
plt.ylabel('q_36')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_36)
plt.xlabel('Layer')
plt.ylabel('Q_36')

plt.legend(['spin','bond'])
plt.show()

print('q_36 ',q_36)
print('Q_36 ',Q_36)
# Out:
# q_36  [1.         0.04666667 0.14       0.11333333 0.01333333 1.        ]
# Q_36  [0.0237996  0.12536709 0.00343276 0.0290179  0.02619305]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_36)
plt.xlabel('Layer')
plt.ylabel('q_36')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_36)
plt.xlabel('Layer')
plt.ylabel('Q_36')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_45)
plt.xlabel('Layer')
plt.ylabel('q_45')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_45)
plt.xlabel('Layer')
plt.ylabel('Q_45')

plt.legend(['spin','bond'])
plt.show()

print('q_45 ',q_45)
print('Q_45 ',Q_45)
# Out:
# q_45  [1.         0.01333333 0.         0.13333333 0.02       1.        ]
# Q_45  [0.11741994 0.2219718  0.14377269 0.15865516 0.04392492]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_45)
plt.xlabel('Layer')
plt.ylabel('q_45')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_45)
plt.xlabel('Layer')
plt.ylabel('Q_45')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_46)
plt.xlabel('Layer')
plt.ylabel('q_46')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_46)
plt.xlabel('Layer')
plt.ylabel('Q_46')

plt.legend(['spin','bond'])
plt.show()

print('q_46 ',q_46)
print('Q_46 ',Q_46)
# Out:
# q_46  [1.         0.01333333 0.00666667 0.11333333 0.14666667 1.        ]
# Q_46  [0.00929039 0.11135552 0.01628506 0.06088678 0.08774835]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_46)
plt.xlabel('Layer')
plt.ylabel('q_46')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_46)
plt.xlabel('Layer')
plt.ylabel('Q_46')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_56)
plt.xlabel('Layer')
plt.ylabel('q_56')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_56)
plt.xlabel('Layer')
plt.ylabel('Q_56')

plt.legend(['spin','bond'])
plt.show()

print('q_56 ',q_56)
print('Q_56 ',Q_56)
# Out:
# q_56  [1.         0.02666667 0.02       0.07333333 0.03333333 1.        ]
# Q_56  [0.11523719 0.08923959 0.03176776 0.04564427 0.07304119]

# %%
i = [0,1,2,3,4,5]
plt.plot(i, q_56)
plt.xlabel('Layer')
plt.ylabel('q_56')

i = [0.5,1.5,2.5,3.5,4.5]
plt.plot(i, Q_56)
plt.xlabel('Layer')
plt.ylabel('Q_56')

plt.legend(['spin','bond'])

plt.ylim(0,0.5)
plt.show()

# %%
#q = (q_12 + q_13 + q_14 + q_15 + q_16 + q_23 + q_24 + q_25 + q_26 + q_34 + q_35 + q_36 + q_45 + q_46 + q_56) / 15
#Q = (Q_12 + Q_13 + Q_14 + Q_15 + Q_16 + Q_23 + Q_24 + Q_25 + Q_26 + Q_34 + Q_35 + Q_36 + Q_45 + Q_46 + Q_56) / 15
#print(q)
#print(Q)

# %%
#i = [0,1,2,3,4,5]
#plt.plot(i, q)
#plt.xlabel('Layer')
#plt.ylabel('q')

#i = [0.5,1.5,2.5,3.5,4.5]
#plt.plot(i, Q)
#plt.xlabel('Layer')
#plt.ylabel('Q')

#plt.legend(['spin','bond'])
#plt.show()

# %%
#i = [0,1,2,3,4,5]
#plt.plot(i, q)
#plt.xlabel('Layer')
#plt.ylabel('q')

#i = [0.5,1.5,2.5,3.5,4.5]
#plt.plot(i, Q)
#plt.xlabel('Layer')
#plt.ylabel('Q')

#plt.legend(['spin','bond'])

#plt.ylim(0,0.5)
#plt.show()
